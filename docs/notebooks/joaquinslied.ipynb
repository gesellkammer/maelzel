# %% [markdown]
# # Die Seefahrer
#
# von Joaquin

# %%
from maelzel.core import *

# %%
m1 = Chain([
    "4E/8",
    "4E/8",
    "4E/8",
    "4F/8",
    "4A/8",
    "4A/8",
    "4A/8",
    "4F/4",
    "5E/8",
    "5D/8",
    "5C/8",
    
    "4A/8",
    "4G/8",
    "4A/8",
    "4B/8",
    "4E/8",
    "4E/8",
    "4D/8",
    "4E/8",
    "4D/8",
    "4E/8",
    
    "4F/8",
    "4F/8",
    "4F/4",
    "4F/4",
    "5D/8",
    "5C/8",
    "4A/8",
    "4G/8",
    "4B/8",
    "5D/8",
    "5C/8",
    
    "4A/8",
    "4G/8",
    "4F/8",
    "4D/8",
    Rest(1),
    "4E/8",
    "4A/8",
    "4B/8",
    "4A/8",
    "5D/8",
    "5D/8",
    
    
        
])
m1
m2 = m1.timeShift(1).timeScale(1.)
m3 = m1.timeShift(2).timeScale(1.)
#m3 = m1.transpose(8)
#m2 = m1.transpose(4)
# sc = Score([m3, m2, m1])
sc = Score([m1, m2, m3])
sc
# Out:
# ~~~~ Node(1/1,
#   «0.000:0.500 4E»
#   «0.500:1.000 4E»
# ) Node(1/1,
#   «1.000:1.500 4E»
#   «1.500:2.000 4F»
# ) 1 4
# ~~~~~~~ too  many crossed beats
# ~~~~ Node(1/1,
#   «1.000:1.500 4E»
#   «1.500:2.000 4F»
# ) Node(1/1,
#   «2.000:2.500 4A»
#   «2.500:3.000 4A»
# ) 1 4
# ~~~~~~~ too  many crossed beats
# ~~~~ Node(1/1,
#   «2.000:2.500 4A»
#   «2.500:3.000 4A»
# ) Node(1/1,
#   «3.000:3.500 4A»
#   «3.500:4.000 4F tiedNext»
# ) 1 4
# ~~~~~~~ too  many crossed beats
# ~~~~ Node(1/1,
#   «0.000:0.500 4F tiedPrev»
#   «0.500:1.000 5E»
# ) Node(1/1,
#   «1.000:1.500 5D»
#   «1.500:2.000 5C»
# ) 1 4
# ~~~~~~~ too  many crossed beats
# ~~~~ Node(1/1,
#   «1.000:1.500 5D»
#   «1.500:2.000 5C»
# ) Node(1/1,
#   «2.000:2.500 4A»
#   «2.500:3.000 4G»
# ) 1 4
# ~~~~~~~ too  many crossed beats
# ~~~~ Node(1/1,
#   «2.000:2.500 4A»
#   «2.500:3.000 4G»
# ) Node(1/1,
#   «3.000:3.500 4A»
#   «3.500:4.000 4B»
# ) 1 4
# ~~~~~~~ too  many crossed beats
# ~~~~ Node(1/1,
#   «0.000:0.500 4E»
# ...

# %%
setScoreStruct(tempo=200)

# %%
sc.play(instr='gm-oboe', sustain=0.1, fade=0)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=126)
#     Synth(𝍪 preset:gm-oboe:501.038, p4=0 idataidx_:5=15 inumbps:6=3 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0 ifadeout:12=0 ipchintrp_:13=0 ifadekind:14=1 p15=0 p16=64 ...)
#     Synth(𝍪 preset:gm-oboe:501.0381, p4=0 idataidx_:5=15 inumbps:6=3 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0 ifadeout:12=0 ipchintrp_:13=0 ifadekind:14=1 p15=0 p16=64 ...)
#     Synth(𝍪 preset:gm-oboe:501.0382, p4=0 idataidx_:5=15 inumbps:6=3 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0 ifadeout:12=0 ipchintrp_:13=0 ifadekind:14=1 p15=0 p16=64 ...)
#     Synth(𝍪 preset:gm-oboe:501.0383, p4=0 idataidx_:5=15 inumbps:6=3 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0 ifadeout:12=0 ipchintrp_:13=0 ifadekind:14=1 p15=0 p16=65 ...)
# ...

# %%
presetManager.definedPresets()
# Out:
# ['simplesin',
#  'sin',
#  'tri',
#  'saw',
#  'sqr',
#  'pulse',
#  '.sing',
#  'gm-piano',
#  'gm-clarinet',
#  'gm-oboe',
#  'gm-flute',
#  'gm-violin',
#  'gm-reedorgan',
#  '.piano',
#  'accordion',
#  'sing',
#  'piano']
