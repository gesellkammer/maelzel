# %%
from maelzel.core import *
# Out:
# csoundengine.magic extension loaded
# Magics available: %csound, %%csound, %%definstr

# %%
# Test play fade

# %%
n = Note("5C", dur=1, start=1)
n
# Out:
# 5C:1♩:start=1

# %%
n.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset.sin:1001.0003, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=-1 ifade0:11=0.02 ifade1:12=0.02 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=72 ...)

# %%
n.play(fade=(0.1, 0.5))
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset.sin:1001.0004, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=-1 ifade0:11=0.1 ifade1:12=0.5 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=72 ...)

# %%
click = Chain([Note(80, dur=0.25, start=i) for i in range(10)])
click
# Out:
# Chain([5G#:0.25♩:start=0, 5G#:0.25♩:start=1, 5G#:0.25♩:start=2, 5G#:0.25♩:start=3, 5G#:0.25♩:start=4, 5G#:0.25♩:start=5, 5G#:0.25♩:start=6, 5G#:0.25♩:start=7, 5G#:0.25♩:start=8, 5G#:0.25♩:start=9, …])

# %%
click.play(fade=(0, 0))
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=10)
#     Synth(𝍪 preset.sin:1001.0013, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=-1 ifade0:11=0.0001 ifade1:12=0 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=80 ...)
#     Synth(𝍪 preset.sin:1001.0014, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=-1 ifade0:11=0.0001 ifade1:12=0 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=80 ...)
#     Synth(𝍪 preset.sin:1001.0015, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=-1 ifade0:11=0.0001 ifade1:12=0 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=80 ...)
#     Synth(𝍪 preset.sin:1001.0016, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=-1 ifade0:11=0.0001 ifade1:12=0 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=80 ...)
# ...

# %%
v0 = Voice([click])
v1 = Voice([n])

v0.setPlay(position=0)
v1.setPlay(position=1)
# Out:
# Voice([5C:1♩:start=1])

# %%
s = Score([v0, v1])
s.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=11)
#     Synth(𝍪 preset.sin:1001.0023, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=0 ifade0:11=0.02 ifade1:12=0.02 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=80 ...)
#     Synth(𝍪 preset.sin:1001.0024, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=0 ifade0:11=0.02 ifade1:12=0.02 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=80 ...)
#     Synth(𝍪 preset.sin:1001.0025, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=0 ifade0:11=0.02 ifade1:12=0.02 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=80 ...)
#     Synth(𝍪 preset.sin:1001.0026, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=0 ifade0:11=0.02 ifade1:12=0.02 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=80 ...)
# ...

# %%
with play.OfflineRenderer() as r:
    s.play()
r
# Out:
# INFO:maelzel.core:Rendering to /home/em/.local/share/maelzel/recordings/rec-2022-03-17T20:56:34.029.wav
# <strong>OfflineRenderer</strong>(outfile=<code style="color:#9090FF">"/home/em/.local/share/maelzel/recordings/rec-2022-03-17T20:56:34.029.wav"</code>)<br><b>Sample</b>(duration=<code>9.27</code>, sr=<code>44100</code>, numchannels=<code>2</code>)<br>
#         <img style="display:inline; padding:10px;
# margin-top:14px;
# width:1375.0"
#              src="data:image/png;base64,..."/><br>
#                 <audio controls style="width: 100%; max-width: 1200px;" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
! sonic-visualiser $r.outfile
# Out:
# SV loading template file :/templates/Waveform and Melodic Range Spectrogram.svt
# MainWindowBase::openSessionTemplate(file::/templates/Waveform and Melodic Range Spectrogram.svt)
# Document::releaseModel(<none>)
# Document::releaseModel(<none>)
#
# Adding model #1 to playsource
# m_writeBuffers size = 0
# target channel count = 2
# ResamplerWrapper: Initial source rate 0 and channels 2
# ResamplerWrapper::reconstructResampler: Creating resampler with initial source rate 44100, buffer size 10240, channel count 2
# AudioCallbackPlaySource: Source sample rate changed to 44100, updating resampler wrapper
# ResamplerWrapper: Source rate changing from 0 to 44100
# ResamplerWrapper::changeApplicationSampleRate: Note: Source rate is equal to target rate, won't be resampling
# MainWindowBase::audioChannelCountIncreased
# createAudioIO: Preferred implementation = ""
# createAudioIO: Preferred playback device = ""
# createAudioIO: Preferred record device = ""
# Document::releaseModel(<none>)
# ...
