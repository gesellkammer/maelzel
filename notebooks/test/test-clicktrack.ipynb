# %%
from maelzel.core import *
cfg = getConfig()

# %%
cfg['show.measureLabelStyle'] = 'fontsize=9'
cfg['quant.complexity'] = 'medium'

# %%
struct = ScoreStruct("""
4/16+7/32, q=60, ticks=(1, 7/8)
5/16+4/16, ticks=5/4 1
2, 3/4
3?, 4/4, q=96
(2+3)/8
3/4, label="foo"
.
2/4
7/8, ticks=1 1 1/2! 1/2 1/2

""")
struct
# Out:
# ScoreStruct([4/16+7/32@60, 5/16+4/16, 3/4, 4/4@96, 5/8, 3/4, 3/4, 2/4, 7/8])

# %%
click = struct.clickTrack()
click
# Out:
# Score(1 voices)

# %%
click.play()
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 512 sample-frame blocks
# reading 4096-byte blks of shorts from adc:ALC257 Analog: (RAW)
# writing 1024 sample blks of 64-bit floats to dac:ALC257 Analog:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=26)
#     Synth(‖ preset:.click=401.0002 start=.179 dur=1 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0003 start=1.179 dur=.875 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0004 start=2.054 dur=1.25 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0005 start=3.304 dur=1 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
# ...

# %%
click.play(countin=3)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=29)
#     Synth(‖ preset:.click=401.0202 start=126.637 dur=1 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0203 start=127.637 dur=1 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0204 start=128.637 dur=1 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0205 start=129.637 dur=1 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0206 start=130.637 dur=.875 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0207 start=131.512 dur=1.25 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0208 start=132.762 dur=1 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
# ...

# %%
qs = click.quantizedScore()
qs.show()

# %%
qs2 = qs.tempoTransform(F(5, 4))
qs2.show()

# %%
qs2 = qs.tempoTransform(2)
qs2.show()

# %%
qs.tempoTransform(2)
# Out:
# Part #0
#   Measure #0
#     Timesig: 4/16+7/32 (𝅘𝅥=60)
#     Node ratio: 1/1, offset=0, end=15/8, dur=15/8, symbolicdur=15/8
#       «5C:1♩»
#       «5G:7/8♩»
#   Measure #1
#     Timesig: 5/16+4/16
#     Node ratio: 1/1, offset=0, end=9/4, dur=9/4, symbolicdur=9/4
#       «5C~:1♩ properties={'.forwardTies': {0}}»
#       «~5C:1/4♩ properties={'.backwardTies': {0}}»
#       «5G:1♩»
#   Measure #2
#     Timesig: 3/4
#     Node ratio: 1/1, offset=0, end=3, dur=3, symbolicdur=3
#       «5C:1♩»
#       «5G:1♩»
#       «5G:1♩»
#   Measure #3
#     Timesig: 4/4 (𝅘𝅥=96)
#     Node ratio: 1/1, offset=0, end=4, dur=4, symbolicdur=4
#       «5C:1♩»
#       «5G:1♩»
#       «5G:1♩»
#       «5G:1♩»
#   Measure #4
#     Timesig: 5/8
#     Node ratio: 1/1, offset=0, end=5/2, dur=5/2, symbolicdur=5/2
#       «5C:1♩»
#       «5G:3/2♩»
#   Measure #5
#     Timesig: 3/4
#     Node ratio: 1/1, offset=0, end=3, dur=3, symbolicdur=3
#       «5C:1♩»
#       «5G:1♩»
#       «5G:1♩»
#   Measure #6
# ...

# %%
click.tempoTransform(factor=2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/.virtualenvs/maelzel/lib/python3.13/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~/dev/python/maelzel/maelzel/core/mobj.py:1232, in MObj._repr_html_(self)
#    1230 html = rf'<code style="white-space: pre-line; font-size:0.9em;">{txt}</code><br>'
#    1231 if cfg['jupyterReprShow']:
# -> 1232     img64, img = self._htmlImage()
#    1233     html += '<br>' + img
#    1234 return html
#
# File ~/dev/python/maelzel/maelzel/core/mobj.py:1217, in MObj._htmlImage(self, scaleFactor)
#    1206 def _htmlImage(self, scaleFactor: float = 0.) -> tuple[bytes, str]:
#    1207     """
# ...
