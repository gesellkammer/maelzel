# %%
from maelzel.core import *
from maelzel import scoring
import logging
#logger = logging.getLogger("maelzel")
#logger.setLevel("DEBUG")
cfg = getConfig()

# %%
left = Voice([
    "4C:1/3",
    "5E-33:1/3",
    "4G+13:1/3+1/23"
])
left
# Out:
# Voice([4C:1/3♩, 5E-33:1/3♩, 4G+13:~3/8♩])

# %%
p = left.quantizedPart()
p.dump()
p.dump(tree=False)
# Out:
# Measure #0
#   Timesig: 4/4, beats: 1, 1, 1, 1 (𝅘𝅥=60)
#   Node ratio: ¹⁄₁, offset=0, end=4, dur=4, symbolicdur=4 ⌈
#     Node ratio: ³⁄₂, offset=0, end=1, dur=1, symbolicdur=1 ⌈
#       4C!⋮1/3♩⋮0:0.333⋮³⁄₂: 1/2 = 𝅘𝅥𝅮
#       5E-33!⋮1/3♩⋮0.333:0.667⋮³⁄₂: 1/2 = 𝅘𝅥𝅮
#       4G+13!~⋮1/3♩⋮0.667:1⋮³⁄₂: 1/2 = 𝅘𝅥𝅮
#     ⌋
#     Node ratio: ⁵⁄₄, offset=1, end=2, dur=1, symbolicdur=1 ⌈
#       Node ratio: ⁹⁄₈, offset=1, end=6/5, dur=1/5, symbolicdur=1/4 ⌈
#         ~4G+13!⋮2/45♩⋮1:1.044⋮⁵⁄₄⁹⁄₈: 1/16 = 𝅘𝅥𝅱
#         r⋮7/45♩⋮1.044:1.2⋮⁵⁄₄⁹⁄₈: 7/32 = 𝅘𝅥𝅰··
#       ⌋
#       r⋮4/5♩⋮1.2:2⋮⁵⁄₄: 1 = 𝅘𝅥
#     ⌋
#     r⋮2♩⋮2:4: 2 = 𝅗𝅥
#   ⌋
# Measure #0
#   Timesig: 4/4, beats: 1, 1, 1, 1 (𝅘𝅥=60)
#   QuantizedBeat(divisions=(3,), assignedSlots=[0, 1, 2], beatDuration=1, beatOffset=0, quantizationError=0)
#     4C⋮1/3♩⋮0:0.333⋮³⁄₂ 	sym. dur: 1/2
#     5E-33⋮1/3♩⋮0.333:0.667⋮³⁄₂ 	sym. dur: 1/2
#     4G+13~⋮1/3♩⋮0.667:1⋮³⁄₂ 	sym. dur: 1/2
#   QuantizedBeat(divisions=(9, 1, 1, 1, 1), assignedSlots=[0, 2], beatDuration=1, beatOffset=1, quantizationError=0.0709)
#     ~4G+13⋮2/45♩⋮1:1.044⋮⁵⁄₄⁹⁄₈ 	sym. dur: 1/16
#     r⋮7/45♩⋮1.044:1.2⋮⁵⁄₄⁹⁄₈ 	sym. dur: 7/32
#     r⋮1/5♩⋮1.2:1.4⋮⁵⁄₄ 	sym. dur: 1/4
#     r⋮1/5♩⋮1.4:1.6⋮⁵⁄₄ 	sym. dur: 1/4
#     r⋮1/5♩⋮1.6:1.8⋮⁵⁄₄ 	sym. dur: 1/4
#     r⋮1/5♩⋮1.8:2⋮⁵⁄₄ 	sym. dur: 1/4
#   QuantizedBeat(divisions=(1,), assignedSlots=[0], beatDuration=1, beatOffset=2, quantizationError=0)
#     r⋮1♩⋮2:3 	sym. dur: 1
#   QuantizedBeat(divisions=(1,), assignedSlots=[0], beatDuration=1, beatOffset=3, quantizationError=0)
#     r⋮1♩⋮3:4 	sym. dur: 1

# %%
import bpf4 as bpf
dur = 12
left2 = left.cycle(totaldur=dur)

timecurve = bpf.linear(0, 1, dur, 2)
transposition = bpf.halfcos(0, 0, dur, -4)

items2 = [item.clone(dur=item.dur * timecurve(item.absOffset()), pitch=item.pitch+transposition(item.absOffset()))
          for item in left2.items]

left3 = Chain(items2)
left3 = left3.quantizePitch(0.25)

cfg = CoreConfig(quantComplexity='low', active=True)

for i in range(int(left3.dur)):
    left3.addBreak(i)
left3.show()

# %%
F(1,2)*F(5, 4)
# Out:
# Fraction(5, 8)

# %%
left3.play(sustain=0.5)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=35)
#     Synth(‖ preset:.piano=401.0142 start=131.438 dur=.833 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=60 p21=0.515178 p22=0.333333 p23=60 …)
#     Synth(‖ preset:.piano=401.0143 start=131.771 dur=.843 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=75.75 p21=0.515178 p22=0.342593 p23=75.75 …)
#     Synth(‖ preset:.piano=401.0144 start=132.114 dur=.896 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=67 p21=0.515178 p22=0.395833 p23=67 …)
#     Synth(‖ preset:.piano=401.0145 start=132.51 dur=.862 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=60 p21=0.515178 p22=0.362269 p23=60 …)
#     Synth(‖ preset:.piano=401.0146 start=132.872 dur=.872 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=75.5 p21=0.515178 p22=0.371528 p23=75.5 …)
#     Synth(‖ preset:.piano=401.0147 start=133.244 dur=.928 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=67 p21=0.515178 p22=0.428385 p23=67 …)
#     Synth(‖ preset:.piano=401.0148 start=133.672 dur=.891 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=59.75 p21=0.515178 p22=0.391204 p23=59.75 …)
#     Synth(‖ preset:.piano=401.0149 start=134.063 dur=.9 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=75.25 p21=0.515178 p22=0.400463 p23=75.25 …)
#     Synth(‖ preset:.piano=401.015 start=134.464 dur=.961 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=66.75 p21=0.515178 p22=0.460938 p23=66.75 …)
#     Synth(‖ preset:.piano=401.0151 start=134.925 dur=.92 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=59.25 p21=0.515178 p22=0.420139 p23=59.25 …)
#     Synth(‖ preset:.piano=401.0152 start=135.345 dur=.929 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=75 p21=0.515178 p22=0.429398 p23=75 …)
#     Synth(‖ preset:.piano=401.0153 start=135.774 dur=.993 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=66.25 p21=0.515178 p22=0.49349 p23=66.25 …)
#     Synth(‖ preset:.piano=401.0154 start=136.268 dur=.949 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=59 p21=0.515178 p22=0.449074 p23=59 …)
#     Synth(‖ preset:.piano=401.0155 start=136.717 dur=.958 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=74.5 p21=0.515178 p22=0.458333 p23=74.5 …)
#     Synth(‖ preset:.piano=401.0156 start=137.175 dur=1.026 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=65.75 p21=0.515178 p22=0.526042 p23=65.75 …)
#     Synth(‖ preset:.piano=401.0157 start=137.701 dur=.978 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=58.5 p21=0.515178 p22=0.478009 p23=58.5 …)
#     Synth(‖ preset:.piano=401.0158 start=138.179 dur=.987 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=74 p21=0.515178 p22=0.487269 p23=74 …)
#     Synth(‖ preset:.piano=401.0159 start=138.666 dur=1.059 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=65.25 p21=0.515178 p22=0.558594 p23=65.25 …)
#     Synth(‖ preset:.piano=401.016 start=139.225 dur=1.007 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=57.75 p21=0.515178 p22=0.506944 p23=57.75 …)
#     Synth(‖ preset:.piano=401.0161 start=139.732 dur=1.016 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=73.25 p21=0.515178 p22=0.516204 p23=73.25 …)
#     Synth(‖ preset:.piano=401.0162 start=140.248 dur=1.091 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=64.75 p21=0.515178 p22=0.591146 p23=64.75 …)
#     Synth(‖ preset:.piano=401.0163 start=140.839 dur=1.036 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=57.25 p21=0.515178 p22=0.53588 p23=57.25 …)
#     Synth(‖ preset:.piano=401.0164 start=141.375 dur=1.045 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=72.75 p21=0.515178 p22=0.545139 p23=72.75 …)
#     Synth(‖ preset:.piano=401.0165 start=141.92 dur=1.124 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=64.25 p21=0.515178 p22=0.623698 p23=64.25 …)
#     Synth(‖ preset:.piano=401.0166 start=142.544 dur=1.065 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=56.75 p21=0.515178 p22=0.564815 p23=56.75 …)
#     Synth(‖ preset:.piano=401.0167 start=143.109 dur=1.074 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=72.5 p21=0.515178 p22=0.574074 p23=72.5 …)
#     Synth(‖ preset:.piano=401.0168 start=143.683 dur=1.156 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=63.75 p21=0.515178 p22=0.65625 p23=63.75 …)
#     Synth(‖ preset:.piano=401.0169 start=144.339 dur=1.094 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=56.5 p21=0.515178 p22=0.59375 p23=56.5 …)
#     Synth(‖ preset:.piano=401.017 start=144.933 dur=1.103 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=72 p21=0.515178 p22=0.603009 p23=72 …)
#     Synth(‖ preset:.piano=401.0171 start=145.536 dur=1.189 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=63.5 p21=0.515178 p22=0.688802 p23=63.5 …)
#     Synth(‖ preset:.piano=401.0172 start=146.225 dur=1.123 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=56.25 p21=0.515178 p22=0.622685 p23=56.25 …)
#     Synth(‖ preset:.piano=401.0173 start=146.847 dur=1.132 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=71.75 p21=0.515178 p22=0.631944 p23=71.75 …)
#     Synth(‖ preset:.piano=401.0174 start=147.479 dur=1.221 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=63.25 p21=0.515178 p22=0.721354 p23=63.25 …)
#     Synth(‖ preset:.piano=401.0175 start=148.201 dur=1.152 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=56 p21=0.515178 p22=0.65162 p23=56 …)
#     Synth(‖ preset:.piano=401.0176 start=148.852 dur=1.161 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=71.75 p21=0.515178 p22=0.66088 p23=71.75 …)
