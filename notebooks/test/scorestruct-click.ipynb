# %%
from maelzel.core import *
from maelzel import scorestruct as st

# %%
w = getWorkspace()
s = w.audioSession()
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 512 sample-frame blocks
# reading 4096-byte blks of shorts from adc:ALC257 Analog: (RAW)
# writing 1024 sample blks of 64-bit floats to dac:ALC257 Analog:
# SECTION 1:

# %%
s.testAudio(dur=8, verbose=False)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# Synth(‖ .testAudio=401.0002 start=1.225 dur=8 imode=0 iperiod=1 igain=0.1 iverbose=0)

# %%
sco = ScoreStruct("""
3/4, q=120
5/8
3/8
7/16
7/16(3+4)
2/4+5/8(3+2)
""")

# %%
sco
# Out:
# ScoreStruct([3/4@120, 5/8, 3/8, 7/16, 7/16, 2/4+5/8])

# %%
track = sco.clickTrack()
track
# Out:
# Score(1 voices)

# %%
track.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=14)
#     Synth(‖ preset:.click=402.0099 start=79.241 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.01 start=79.741 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0101 start=80.241 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0102 start=80.741 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0103 start=81.241 dur=.75 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0104 start=81.991 dur=.75 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0105 start=82.741 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
# ...

# %%
track.play(countin=3, countinPitch="5F#")
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=17)
#     Synth(‖ preset:.click=402.0113 start=110.622 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0114 start=111.122 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0115 start=111.622 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0116 start=112.122 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0117 start=112.622 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0118 start=113.122 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0119 start=113.622 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
# ...

# %%
v = Voice("""
4C:0.5
4D:1.5
4E:1/3
4F:1/3
4E:1/3
3C:0.5
3D:0.5
3E:0.5
3F:0.5
3G:0.5

4C:0.5
4D:1.5
4E:1/3
4F:1/3
4E:1/3
3C:0.5
3D:0.5
3E:0.5
3F:0.5
3G:0.5

""")
s = Score([v], scorestruct=sco)
s
# Out:
# Score(1 voices)

# %%
with play():
    s.play(delay=(1, 0))
    track.play(countin=3)

# %%
s.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=20)
#     Synth(‖ preset:sin=403.0102 start=203.23 dur=.25 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.453317 p20=0.25 p21=60 …)
#     Synth(‖ preset:sin=403.0103 start=203.48 dur=.75 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=62 p19=0.453317 p20=0.75 p21=62 …)
#     Synth(‖ preset:sin=403.0104 start=204.23 dur=.167 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=64 p19=0.453317 p20=0.166667 p21=64 …)
# ...

# %%
sco = ScoreStruct("""
3/4, q=120
""")

v = Voice("""
4C:0.5
4D:1.5
4E:1/3
4F:1/3
4E:1/3
3C:0.5
3D:0.5
3E:0.5
3F:0.5
3G:0.5

4C:0.5
4D:1.5
4E:1/3
4F:1/3
4E:1/3
3C:0.5
3D:0.5
3E:0.5
3F:0.5
3G:0.5

""")
s = Score([v])
# s = Score([v],scorestruct=sco)
# s[0].addBreak((2, 2))
s
# Out:
# Score(1 voices)

# %%
s.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=20)
#     Synth(‖ preset:sin=403.0162 start=1614.814 dur=.25 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.453317 p20=0.25 p21=60 …)
#     Synth(‖ preset:sin=403.0163 start=1615.064 dur=.75 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=62 p19=0.453317 p20=0.75 p21=62 …)
#     Synth(‖ preset:sin=403.0164 start=1615.814 dur=.167 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=64 p19=0.453317 p20=0.166667 p21=64 …)
# ...
