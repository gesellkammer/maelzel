# %%
from maelzel.core import *
from maelzel import scorestruct as st

# %%
w = getWorkspace()
s = w.audioSession()
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 512 sample-frame blocks
# reading 4096-byte blks of shorts from adc:ALC257 Analog: (RAW)
# writing 1024 sample blks of 64-bit floats to dac:ALC257 Analog:
# SECTION 1:

# %%
s.testAudio(dur=8, verbose=False)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# Synth(‖ .testAudio=401.0002 start=1.043 dur=8 imode=0 iperiod=1 igain=0.1 iverbose=0)

# %%
sco = ScoreStruct("""
3/4, q=120
5/8
3/8
7/16
7/16(3+4)
2/4+5/8(3+2)
""")

# %%
sco
# Out:
# ScoreStruct([3/4@120, 5/8, 3/8, 7/16, 7/16, 2/4+5/8])

# %%
track = sco.clickTrack()
track
# Out:
# Score(1 voices)

# %%
track.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=14)
#     Synth(‖ preset:.click=401.0002 start=2.906 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0003 start=3.406 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0004 start=3.906 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0005 start=4.406 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0006 start=4.906 dur=.75 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0007 start=5.656 dur=.75 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0008 start=6.406 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0009 start=6.906 dur=.375 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.001 start=7.281 dur=.375 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0011 start=7.656 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0012 start=8.156 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0013 start=8.656 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0014 start=9.156 dur=.75 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0015 start=9.906 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)

# %%
track.play(countin=1, countinPitch="8F#")
# Out:
# [SynthEvent(delay=0, dur=0.5, instr=.click, gain=1, chan=1, fade=(0, 0), position=0.5, bps=｢0 114 -5.8; 0.5 114 -5.8｣), SynthEvent(delay=0.5, dur=0.5, instr=.click, gain=1, chan=1, fade=(0, 0), position=0.5, bps=｢0 114 -5.8; 0.5 114 -5.8｣), SynthEvent(delay=1, dur=0.5, instr=.click, gain=1, chan=1, fade=(0, 0), position=0.5, bps=｢0 114 -5.8; 0.5 114 -5.8｣)]
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=17)
#     Synth(‖ preset:.click=402.0016 start=17.417 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0017 start=17.917 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0018 start=18.417 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0019 start=18.917 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.002 start=19.417 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0021 start=19.917 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0022 start=20.417 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0023 start=20.917 dur=.75 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0024 start=21.667 dur=.75 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0025 start=22.417 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0026 start=22.917 dur=.375 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0027 start=23.292 dur=.375 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0028 start=23.667 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0029 start=24.167 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.003 start=24.667 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0031 start=25.167 dur=.75 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=402.0032 start=25.917 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)

# %%
v = Voice("""
4C:0.5
4D:1.5
4E:1/3
4F:1/3
4E:1/3
3C:0.5
3D:0.5
3E:0.5
3F:0.5
3G:0.5

4C:0.5
4D:1.5
4E:1/3
4F:1/3
4E:1/3
3C:0.5
3D:0.5
3E:0.5
3F:0.5
3G:0.5

""")
s = Score([v], scorestruct=sco)
s
# Out:
# Score(1 voices)

# %%
with play():
    s.play(delay=(1, 0))
    track.play(countin=1)
# Out:
# [SynthEvent(delay=0, dur=0.5, instr=.click, gain=1, chan=1, fade=(0, 0), position=0.5, bps=｢0 102 -5.8; 0.5 102 -5.8｣), SynthEvent(delay=0.5, dur=0.5, instr=.click, gain=1, chan=1, fade=(0, 0), position=0.5, bps=｢0 102 -5.8; 0.5 102 -5.8｣), SynthEvent(delay=1, dur=0.5, instr=.click, gain=1, chan=1, fade=(0, 0), position=0.5, bps=｢0 102 -5.8; 0.5 102 -5.8｣)]
#  *** rtjack: JACK sample rate changed		   overall amps:  0.71451  0.71053
# 	   overall samples out of range:        0        0
# 0 errors in performance
# 2286595 1024 sample blks of 64-bit floats written to dac:ALC257 Analog:
