# %%
from maelzel.core import *
s = Score([
    Voice(r'''
      3F+,3A:1.25
      4C+:1:mf
      4Db:0.5
      4D-:1:gliss
      6Gb-!,4A:ff
      1C:1
    '''),
    
    Voice(r'''
      3F+,3A:1.25
      4C+:1:mf
      4Db:0.5:pp
      4D-:1:gliss
      6Gb-!,4A:ff
      1C:1
    ''').timeShift(0.5).transpose(-2.5)
])
s.show()
s.play(instr=".piano")
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=15)
#     Synth(‖ preset:.piano=402.0002 start=35.47 dur=1.25 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=53.5 p21=0.364286 p22=1.25 p23=53.5 …)
#     Synth(‖ preset:.piano=402.0003 start=35.47 dur=1.25 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=57 p21=0.364286 p22=1.25 p23=57 …)
#     Synth(‖ preset:.piano=402.0004 start=36.72 dur=1 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=60.5 p21=0.343838 p22=1 p23=60.5 …)
# ...

# %%
from maelzel.core import *
v = Voice(r'''  
      3F:1.25
      4C:1
      4Db:0.5
      4D:1
''')
v
# Out:
# Voice([3F:5/4♩, 4C:1♩, 4C♯:1/2♩, 4D:1♩])

# %%
v.timeShift(0.5)
# Out:
# Voice([3F:5/4♩:offset=0.5, 4C:1♩:offset=1.75, 4C♯:1/2♩:offset=2.75, 4D:1♩:offset=3.25])

# %%
v2 = v.copy()
v2._changed() 
v2.timeShiftInPlace(0.5)
# v2.removeRedundantOffsets()
v2
# Out:
# Voice([3F:5/4♩:offset=0.5, 4C:1♩:offset=1.75, 4C♯:1/2♩:offset=2.75, 4D:1♩:offset=3.25])

# %%
v.timeShiftInPlace(0.5)

# %%
v
# Out:
# Voice([3F:5/4♩:offset=0.5, 4C:1♩:offset=1.75, 4C♯:1/2♩:offset=2.75, 4D:1♩:offset=3.25])
