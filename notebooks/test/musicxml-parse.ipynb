# %%
from maelzel.core import musicxml
from maelzel.core import *
from maelzel.core import symbols
import xml.etree.ElementTree as ET
from IPython.display import display
from maelzel import scoring

# %%
# xmltext = open("/home/em/Downloads/xmlsamples/Telemann.musicxml").read()
# xmltext = open("/home/em/Downloads/xmlsamples/ActorPreludeSample.musicxml").read()
# xmltext = open("/home/em/Downloads/comma_pump_min.xml").read()
# xmltext = open("/home/em/dev/musicxml-testsuite/31a-Directions.xml").read()
# xmltext = open("/home/em/dev/musicxml-testsuite/32a-Notations.xml").read()
# xmltext = open("/home/em/dev/musicxml-testsuite/33a-Spanners.xml").read()
# xmltext = open("/home/em/Documents/MuseScore4/Scores/gliss-spanner.musicxml").read()

# xmltext = open("/home/em/Downloads/xmlsamples/MozaChloSample.musicxml", ).read()
# xmltext = open("/home/em/dev/musicxml-testsuite/51b-Header-Quotes.xml").read()
# path = "/home/em/Downloads/xmlsamples/MozaChloSample.musicxml"
path = "/home/em/Downloads/xmlsamples/MozaChloSample.musicxml"

# %%
sco = musicxml.parseMusicxmlFile(path, fixSpelling=True)
# sco = musicxml.parseMusicxml(xmltext, fixSpelling=True)
# sco.scorestruct.addRehearsalMark(2, 'B')
#display(sco.scorestruct)
# sco.dump()
# sco.write('~/tmp/foo.ly')
# r = sco.render()
# r.score.dump()
# sco.write('~/tmp/foo.ly')
sco
# Out:
# Score(voices=[Voice([Rest:3♩:start=0, Rest:1♩:start=3, Rest:4♩:start=4, Rest:4♩:start=8, Rest:4♩:start=12, Rest:4♩:start=16, Rest:4♩:start=20, Rest:2♩:start=24, Rest:1♩:start=26, 4G:0.5♩:start=27, …], start=0.0), Voice([Rest:3♩:start=0, 4G:0.5♩:start=3, 4Ab:0.5♩:start=3.5, 4Bb:1♩:start=4, 4Bb:1♩:start=5, 4Bb:1♩:start=6, 4Bb:1♩:start=7, 4Bb:1♩:start=8, 5Eb:1♩:start=9, Rest:2♩:start=10, …], start=0.0), Voice([Rest:3♩:start=0, Rest:1♩:start=3, 3Eb:0.5♩:start=4, 3Bb:0.5♩:start=4.5, 3G:0.5♩:start=5, 3Bb:0.5♩:start=5.5, 3D:0.5♩:start=6, 3Ab:0.5♩:start=6.5, 3F:0.5♩:start=7, 3Ab:0.5♩:start=7.5, …], start=0.0)])

# %%
sco.play()
# Out:
# --Csound version 6.18 (double samples) Aug 23 2022
# [commit: a691b9fb3a19ff27df8df4cb44b9c6be0d558fbc]
# libsndfile-1.0.31
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# reading 1024-byte blks of shorts from adc:system:capture (RAW)
# writing 512 sample blks of 64-bit floats to dac:system:playback
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=233)
#     Synth(𝍪 preset._piano:1001.0002, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=-1 ifade0:11=0.02 ifade1:12=0.02 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=67 ...)
#     Synth(𝍪 preset._piano:1001.0003, p4=0 idataidx_:5=15 inumbps:6=2 ibplen:7=3 igain_:8=1 ichan_:9=1 ipos:10=-1 ifade0:11=0.02 ifade1:12=0.02 ipchintrp_:13=0 ifadekind_:14=1 p15=0 p16=68 ...)
# ...

# %%
sco.write('~/tmp/foo.ly')
sco[0].dump()
# Out:
# <code></code><strong>Voice</strong> &nbsp;start: <code><span style="color:#9090FF">0.0</span></code>, label: <code><span style="color:#9090FF">Piano/1</span></code><br><code>  <span style="color:#BBBBBB;font-size:80%">start dur    name      gliss dyn  playargs</span></code><br><code>  <span style="color:#9090FF;font-size:80%">0     2      6C#       False None None</code></span></code><br><code>      <span style="color:#8080E0;font-size:80%">[Articulation(kind=arpeggio)]</span></code><br><code>  <span style="color:#9090FF;font-size:80%">2     0.25   6D        False None None</code></span></code><br><code>      <span style="color:#8080E0;font-size:80%">[Slur(kind=start, uuid=u7mfpksj, linetype=solid)]</span></code><br><code>  <span style="color:#9090FF;font-size:80%">2.25  0.25   6C#       False None None</code></span></code><br><code>      <span style="color:#8080E0;font-size:80%">[Slur(kind=end, uuid=u7mfpksj, linetype=solid)]</span></code><br><code>  <span style="color:#9090FF;font-
# ...

# %%
sco.render().score[0].dump()
# Out:
# Measure #0
# Timesig: 2/2 (quarter=60.0)
# EMPTY
# Measure #1
# Timesig: 2/2 (quarter=60.0)
# EMPTY
# Measure #2
# Timesig: 2/2 (quarter=60.0)
# EMPTY
# Measure #3
# Timesig: 2/2 (quarter=60.0)
# EMPTY
# Measure #4
# Timesig: 2/2 (quarter=60.0)
# EMPTY
# Measure #5
# Timesig: 2/2 (quarter=60.0)
# EMPTY
# Measure #6
# Timesig: 2/2 (quarter=60.0)
#   Ratio (1, 1)
#     «0.000:3.000 rest properties={'resetEnharmonicSlots': True}»
#     «3.000:3.500 4G f attachments=[Text(text=Wenn, placement=below)]»
#     «3.500:4.000 4Ab attachments=[Text(text=die, placement=below)]»
# Measure #7
# Timesig: 2/2 (quarter=60.0)
#   Ratio (1, 1)
#     «0.000:1.000 4Bb attachments=[Text(text=Lieb’, placement=below)] properties={'resetEnharmonicSlots': True}»
#   Ratio (1, 1)
#     «1.000:2.000 4Bb attachments=[Text(text=aus, placement=below)]»
#   Ratio (1, 1)
#     «2.000:3.000 4Bb attachments=[Text(text=dei, placement=below)]»
#   Ratio (1, 1)
# ...
