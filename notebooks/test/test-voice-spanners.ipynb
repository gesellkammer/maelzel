# %%
from maelzel.core import *

ch = Voice(r"""
r:3/8
d4:1
e4:1
""")
# ch.addSpanner('beam', 0, 1)
# ch.splitAt(1, nomerge=True)
# ch.eventAt(1, split=True).addText('foo')
# ch.addSpanner('beam', 2, 3)
ch.write("~/tmp/beam4.ly")
ch.show()
# Out:
# best clefs:  ('treble',)
# best clefs:  ('treble',)

# %%
from maelzel.core import *

ch = Voice(r"""
r:3/8
d4:1
e4:1
""")
ch.addSpanner('beam', 0, 1)
# ch.splitAt(1, nomerge=True)
# ch.eventAt(1, split=True).addText('foo')
ch.addSpanner('beam', 2, 3)
# ch.write("~/tmp/beam4.ly")
# ch.show()

# %%
ch.unquantizedScore()
# Out:
# best clefs:  ('treble',)

# %%
ch
# Out:
# best clefs:  ('treble',)
# Voice([R:3/8♩, 4D:1♩, 4E:1♩])

# %%
from maelzel.core import *

ch = Voice(r"""
r:3/8
d2:1
e5:1
""")
ch.addSpanner('slur', ch[1], ch[2])

# %%
ch.show(voiceMaxStaves=1)
