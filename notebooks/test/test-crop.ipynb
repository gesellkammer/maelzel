# %%
from maelzel.core import *
# from maelzel.core.synthevent import SynthEvent

# %%
sc = Chain([Note(m, 0.25) for m in range(60, 72)], offset=0)
sc.append(Chain([Note(m, 0.5) for m in range(60, 72)]))
sc.show()
# sc.play()

# %%
sc2 = sc.cropped((0, 2.25), (1, 1.1))
sc2.show()
sc2.dump()
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 2.25, offset: 2.25, dur: 2.85</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset  dur     name gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  (0,2.25)  2.25   ✓       0.25    4A   -     -    -                   -</span></code><br><code><span style="color:#9090FF;font-size:85%">  (0,2.5)   2.5    ✓       0.25    4A#  -     -    -                   -</span></code><br><code><span style="color:#9090FF;font-size:85%">  (0,2.75)  2.75   ✓       0.25    4B   -     -    -                   -</span></code><br><code><span style="font-size: 85%">  <b>Chain</b> - beat: 3, offset: 0.75, dur: 2.1</span></code><br><code><span style="color:#BBBBBB;font-size:85%">    location  beat   offset  dur     name gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">    (0,3)     3      -       0.5     4C   -     -    -                   -</span></code><br><code><span style="color:#9090FF;font-size:85%">    (0,3.5)   3.5    -       0.5     4C#  -     -    -                   -</span></code><br><code><span style="color:#9090FF;font-size:85%">    (1,0)     4      -       0.5     4D   -     -    -                   -</span></code><br><code><span style="color:#9090FF;font-size:85%">    (1,0.5)   4.5    -       0.5     4D#  -     -    -                   -</span></code><br><code><span style="color:#9090FF;font-size:85%">    (1,1)     5      -       0.1     4E   -     -    -                   -</span></code>

# %%
struct = ScoreStruct(r'''
2/4, 60
2/4, 120
3/4, 72
''')
struct.activate()
# Out:
# ScoreStruct([2/4@60, 2/4@120, 3/4@72])

# %%
sc = Chain([Note(m+0.25, 0.25) for m in range(60, 72)], offset=1)
sc.append(Chain([Note(m, 0.5) for m in range(60, 72)]))
sc.show()

# %%
sc2 = sc.cropped(1.5, (3, F(1,12)))
sc2
# Out:
# Chain([4D↑:1/4♩:offset=0, 4D♯↑:1/4♩:offset=0.25, 4E↑:1/4♩:offset=0.5, 4F↑:1/4♩:offset=0.75, 4G♭↑:1/4♩:offset=1, 4G↑:1/4♩:offset=1.25, 4G♯↑:1/4♩:offset=1.5, 4A↑:1/4♩:offset=1.75, 4B♭↑:1/4♩:offset=2, 4B↑:1/4♩:offset=2.25, …], offset=3/2)

# %%
defSoundfont(name='crot', path='/home/em/Lib/snd/sf2/crotales-bowed.sf2', reverb=True)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Preset: crot
#     routing=False, properties={'sfpath': '/home/em/Lib/snd/sf2/crotales-bowed.sf2', 'ampDivisor': 0, 'sfbank': 0,
# 'sfpresetnum': 0, 'sfpreset': 'crotales-bowed', 'reverbInstr': '.zitarev'}
#   init: i__SfTable__ sfloadonce "/home/em/Lib/snd/sf2/crotales-bowed.sf2"
#
#   |ktransp=0.0, ipitchlag=0.1, ivel=-1, kwet=0.0|
#   ipresetidx sfpresetindex "/home/em/Lib/snd/sf2/crotales-bowed.sf2", 0, 0
#   iamp0_ = p(idataidx_ + 2)
#   inote0_ = round(p(idataidx_ + 1))
#   kpitch2 = lag:k(kpitch + ktransp, ipitchlag)
#   iampdiv_ = 16384
#   if ivel < 0 then
#       ivel _linexp dbamp(iamp0_), 2.6, -72, 0, 1, 127
#   endif
#   aout1, aout2 sfplay ivel, inote0_, kamp/iampdiv_, mtof:k(kpitch2), ipresetidx, 1
#   kpos = kpos == -1 ? 0.5 : kpos
#   a_outL, a_outR = panstereo(aout1, aout2, kpos)
#   if kwet > 0 then
#       chnmix a_outL * kwet, ".zitarev.1"
#       chnmix a_outR * kwet, ".zitarev.2"
#       kdry = 1 - kwet
#       a_outL *= kdry
#       a_outR *= kdry
#   endif
#   outch ichan, a_outL, ichan + 1, a_outR
#
#   epilogue:
#     turnoffWhenSilent aout1

# %%
sc2.play(instr='crot')
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 512 sample-frame blocks
# reading 4096-byte blks of shorts from adc:ALC257 Analog: (RAW)
# writing 1024 sample blks of 64-bit floats to dac:ALC257 Analog:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=17)
#     Synth(‖ preset:crot=401.0002 start=1.706 dur=.25 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=62.25 p21=0.453317 p22=0.25 p23=62.25 …)
#     Synth(‖ preset:crot=401.0003 start=1.956 dur=.25 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=63.25 p21=0.453317 p22=0.25 p23=63.25 …)
#     Synth(‖ preset:crot=401.0004 start=2.206 dur=.125 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=64.25 p21=0.453317 p22=0.125 p23=64.25 …)
#     Synth(‖ preset:crot=401.0005 start=2.331 dur=.125 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=65.25 p21=0.453317 p22=0.125 p23=65.25 …)
#     Synth(‖ preset:crot=401.0006 start=2.456 dur=.125 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=66.25 p21=0.453317 p22=0.125 p23=66.25 …)
#     Synth(‖ preset:crot=401.0007 start=2.581 dur=.125 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=67.25 p21=0.453317 p22=0.125 p23=67.25 …)
#     Synth(‖ preset:crot=401.0008 start=2.706 dur=.125 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=68.25 p21=0.453317 p22=0.125 p23=68.25 …)
#     Synth(‖ preset:crot=401.0009 start=2.831 dur=.125 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=69.25 p21=0.453317 p22=0.125 p23=69.25 …)
#     Synth(‖ preset:crot=401.001 start=2.956 dur=.125 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=70.25 p21=0.453317 p22=0.125 p23=70.25 …)
#     Synth(‖ preset:crot=401.0011 start=3.081 dur=.125 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=71.25 p21=0.453317 p22=0.125 p23=71.25 …)
#     Synth(‖ preset:crot=401.0012 start=3.206 dur=.417 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=60 p21=0.453317 p22=0.416667 p23=60 …)
#     Synth(‖ preset:crot=401.0013 start=3.623 dur=.417 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=61 p21=0.453317 p22=0.416667 p23=61 …)
#     Synth(‖ preset:crot=401.0014 start=4.039 dur=.417 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=62 p21=0.453317 p22=0.416667 p23=62 …)
#     Synth(‖ preset:crot=401.0015 start=4.456 dur=.417 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=63 p21=0.453317 p22=0.416667 p23=63 …)
#     Synth(‖ preset:crot=401.0016 start=4.873 dur=.417 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=64 p21=0.453317 p22=0.416667 p23=64 …)
#     Synth(‖ preset:crot=401.0017 start=5.289 dur=.417 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=65 p21=0.453317 p22=0.416667 p23=65 …)
#     Synth(‖ preset:crot=401.0018 start=5.706 dur=.069 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=66 p21=0.453317 p22=0.0694444 p23=66 …)

# %%
chain = Chain([
            "4C:0.5",
            "4D",
            Chain(["4E:0.5"], offset=2)
            ], offset=1)

# %%
chain.eventsWithOffset()
# Out:
# [(4C:0.5♩, Fraction(1, 1)), (4D:1♩, Fraction(3, 2)), (4E:0.5♩, Fraction(3, 1))]

# %%
chain = Chain([
     Chain("4E:0.5", offset=2), 
     "4C:0.5",
     "4D"])

# %%
note = chain.firstEvent()
note.dump()
note
# Out:
# 4E:0.5♩
# 4E:0.5♩

# %%
note.offset
