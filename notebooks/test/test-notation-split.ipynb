# %%
from maelzel.core import *

# %%
left = Voice([
    "4C:1/3",
    "5E-33:1/3",
    "4G+13:1/3+1/24"
])
left
# Out:
# Voice([4C:1/3♩, 5E-33:1/3♩, 4G+13:3/8♩])

# %%
qs = left.quantizedScore()

# %%
qs.parts[0].measures[0].tree.splitNotationAtOffset(F(1, 2))
qs.show()

# %%
qs.parts[0].measures[0].tree.splitNotationAtOffset(F(1, 3)*F(1,4))
qs.show()

# %%
# This should raise an exception, since the given offset is not part of the quantization
qs = left.quantizedScore()
qs.parts[0].measures[0].tree.splitNotationAtOffset(F(1, 5))
qs.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 # This should raise an exception, since the given offset is not part of the quantization
#       2 qs = left.quantizedScore()
# ----> 3 qs.parts[0].measures[0].tree.splitNotationAtOffset(F(1, 5))
#       4 qs.show()
#
# File ~/dev/python/maelzel/maelzel/scoring/node.py:1050, in Node.splitNotationAtOffset(self, offset, tie, mergeable, beatstruct)
#    1048 elif item.qoffset < offset < item.end:
#    1049     if isinstance(item, Node):
# -> 1050         return item.splitNotationAtOffset(offset, tie=tie, beatstruct=beatstruct)
#    1051     left, right = item.splitAtOffset(offset, tie=tie)
#    1052     if not mergeable:
#
# File ~/dev/python/maelzel/maelzel/scoring/node.py:1061, in Node.splitNotationAtOffset(self, offset, tie, mergeable, beatstruct)
#    1059     out.append(left)
#    1060 else:
# -> 1061     leftparts = Node.breakIrregularDurationInNode(left, beatstruct=beatstruct)
#    1062     items.extend(leftparts)
#    1063     out.extend(leftparts)
#
# File ~/dev/python/maelzel/maelzel/scoring/node.py:1254, in Node.breakIrregularDurationInNode(n, beatstruct)
#    1252 beat = next((b for b in beatstruct if b.offset <= n.qoffset and n.end <= b.end), None)
#    1253 assert beat is not None, f"Could not find beat for {n}, beats={beatstruct}"
# -> 1254 parts = n._breakIrregularDurationInBeat(beatDur=beat.duration, beatDivision=beat.division, beatOffset=beat.offset)
#    1255 assert parts is not None
#    1256 return parts
#
# File ~/dev/python/maelzel/maelzel/scoring/notation.py:1206, in Notation._breakIrregularDurationInBeat(self, beatDur, beatDivision, beatOffset)
#    1203     beatDivision = beatDivision[0]
#    1205 if isinstance(beatDivision, int):
# -> 1206     return _breakIrregularDurationInSimpleDivision(self, beatDur=beatDur, div=beatDivision, beatOffset=beatOffset)
#    1208 # beat is not subdivided regularly. check if n extends over subdivision
#    1209 numDivisions = len(beatDivision)
#
# File ~/dev/python/maelzel/maelzel/scoring/notation.py:2448, in _breakIrregularDurationInSimpleDivision(n, beatDur, div, beatOffset, minPartDuration)
#    2445 nslots = n.duration/slotdur
#    2447 if nslots.denominator != 1:
# -> 2448     raise ValueError(f"Duration is not quantized with given division.\n  {n=}, {div=}, {slotdur=}, {nslots=}")
#    2450 if nslots.numerator in quantdata.regularDurations:
#    2451     return None
#
# ValueError: Duration is not quantized with given division.
#   n=«4C~:1/5♩ 1,3/2», div=3, slotdur=Fraction(1, 3), nslots=Fraction(3, 5)
