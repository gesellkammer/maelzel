# %%
from maelzel.core import *
# logger.parent.setLevel("DEBUG")

# %%
ch = Chain(r'''
4D:0.5
4Ab:1/8
4G:3/4
4D:1/4
4A:1/2
4F:1/4
4D:1/2
4Gb:1/2
4Bb:3/4

''')
ch
# Out:
# Chain([4D:1/2♩, 4G♯:1/8♩, 4G:3/4♩, 4D:1/4♩, 4A:1/2♩, 4F:1/4♩, 4D:1/2♩, 4F♯:1/2♩, 4A♯:3/4♩])

# %%
import random

# %%
pitches = "4C 4D 4E 4F 4G 4Ab 4Bb".split()
durs = [F(1), F(7, 8), F(3, 8), F(1, 2), F(1, 4), F(1, 8), F(3, 4)]
ch = Chain([Note(random.choice(pitches), dur=random.choice(durs)) for _ in range(100)])
#for beat in range(20):
#    ch.addBreak(beat)
    
ch
# Out:
# Chain([4F:3/8♩, 4C:1/2♩, 4G♯:1♩, 4E:7/8♩, 4F:1/2♩, 4C:1♩, 4D:3/8♩, 4D:1/8♩, 4E:3/8♩, 4G:3/4♩, …])

# %%
ch = Chain(r'''
4D:2/3
4Ab:2/3
4G:1/3
4D:1/6
4A:1/2
4F:1/4
4D:1/2
4Gb:1/2
4Bb:3/4

''')
ch
# Out:
# [maelzel.scoring.quant:quant.py:1809:_nodesCanMerge:DEBUG] Merging Node(3/2, dur=1 «4D 2/3♩ 1,3/2»
#                 «4G#~ 1/3♩ 1,3/2») and Node(3/2, dur=1 «~4G# 1/3♩ 1,3/2»
#                 «4G 1/3♩ 1,3/2»
#                 Node(1/1, dur=1/3 «4D 1/6♩ 1,3/2,1»
#                                   «4A~ 1/6♩ 1,3/2,1»))
# [maelzel.scoring.quant:quant.py:733:_splitWeakBeat:DEBUG] ------------ weak: «4G# 2/3♩ 1,3/2», 1
# [maelzel.scoring.quant:quant.py:802:_splitWeakBeat:DEBUG] ------------ no need to split
# [maelzel.scoring.quant:quant.py:691:_splitStrongBeat:DEBUG] split strong: «r 3♩», offset: 2
# [maelzel.scoring.quant:quant.py:733:_splitWeakBeat:DEBUG] ------------ weak: «r 3♩», 2
# [maelzel.scoring.quant:quant.py:752:_splitWeakBeat:DEBUG] No need to split since notation «r 3♩» is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring.quant:quant.py:733:_splitWeakBeat:DEBUG] ------------ weak: «r 2♩», 3
# [maelzel.scoring.quant:quant.py:752:_splitWeakBeat:DEBUG] No need to split since notation «r 2♩» is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring.quant:quant.py:885:_checkTree:DEBUG] Found superfluous tie (tied to a rest??): n0=«r 1♩», n1=«r 2♩»
# Chain([4D:2/3♩, 4G♯:2/3♩, 4G:1/3♩, 4D:1/6♩, 4A:1/2♩, 4F:1/4♩, 4D:1/2♩, 4F♯:1/2♩, 4A♯:3/4♩])

# %%
ScoreStruct((5, 4)).activate()
# Out:
# ScoreStruct(5/4, tempo=60)

# %%
from maelzel.core import *
import maelzel.scoring.quant as quant
quant.logger.setLevel("DEBUG")

# %%
ch = Chain(r"""
r:1
r:1/5
4C:6/5
""")
ch.show()
