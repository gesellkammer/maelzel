# %%
from maelzel.core import *
# logger.parent.setLevel("DEBUG")

# %%
ch = Chain(r'''
4D:0.5
4Ab:1/8
4G:3/4
4D:1/4
4A:1/2
4F:1/4
4D:1/2
4Gb:1/2
4Bb:3/4

''')
ch
# Out:
# Chain([4D:1/2♩, 4G♯:1/8♩, 4G:3/4♩, 4D:1/4♩, 4A:1/2♩, 4F:1/4♩, 4D:1/2♩, 4F♯:1/2♩, 4A♯:3/4♩])

# %%
import random

# %%
pitches = "4C 4D 4E 4F 4G 4Ab 4Bb".split()
durs = [F(1), F(7, 8), F(3, 8), F(1, 2), F(1, 4), F(1, 8), F(3, 4)]
ch = Chain([Note(random.choice(pitches), dur=random.choice(durs)) for _ in range(40)])
#for beat in range(20):
#    ch.addBreak(beat)
    
ch
# Out:
# Chain([4D:1♩, 4F:7/8♩, 4D:3/8♩, 4F:1/8♩, 4G♯:3/8♩, 4G:1/2♩, 4F:1♩, 4G:1/8♩, 4E:7/8♩, 4A♯:1/8♩, …])

# %%
ch = Chain(r'''
4D:2/3
4Ab:2/3
4G:1/3
4D:1/6
4A:1/2
4F:1/4
4D:1/2
4Gb:1/2
4Bb:3/4

''')
ch
# Out:
# Chain([4D:2/3♩, 4G♯:2/3♩, 4G:1/3♩, 4D:1/6♩, 4A:1/2♩, 4F:1/4♩, 4D:1/2♩, 4F♯:1/2♩, 4A♯:3/4♩])
