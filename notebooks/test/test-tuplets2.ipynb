# %%
from maelzel.core import *

# %%
ch = Chain([
    "4C:1/3",
    "4D:1/3",
    "4E:1/3"
])
ch
# Out:
# Chain([4C:1/3♩, 4D:1/3♩, 4E:1/3♩])

# %%
ch = Chain([
    "4C:2/3",
    "4D:2/3",
    "4E:2/3"
])
ch
# Out:
# Chain([4C:2/3♩, 4D:2/3♩, 4E:2/3♩])

# %%
w = getWorkspace()
w.scorestruct = r'''
2/4
'''

ch = Chain([
    "4C:1/3",
    "4D:1/3",
    "4E:1/3"
])
ch
# Out:
# Chain([4C:1/3♩, 4D:1/3♩, 4E:1/3♩])

# %%
w.scorestruct = r'''
2/4
'''

ch = Chain([
    "4C:2/3",
    "4D:2/3",
    "4E:2/3"
])
ch
# Out:
# Chain([4C:2/3♩, 4D:2/3♩, 4E:2/3♩])

# %%
w.scorestruct = r'''
2/8
'''

ch = Chain([
    "4C:1/3",
    "4D:1/3",
    "4E:1/3"
])
ch
# Out:
# Chain([4C:1/3♩, 4D:1/3♩, 4E:1/3♩])

# %%
from maelzel.core import *
from maelzel import scoring
from logging import getLogger
logger = getLogger("maelzel")
logger.setLevel('DEBUG')

w = getWorkspace()
w.scorestruct = r'''
4/16
'''

ch = Chain([
    "4C:1/3",
    "4D:1/3",
    "4E:1/3"
])
ch
# Out:
# [maelzel.core:mobj.py:2299:clearImageCache:INFO] Resetting image cache
# [maelzel.scoring.quant:quant.py:1815:_nodesCanMerge:DEBUG] Merging Node(3/2, dur=1/2 «4C 1/3♩ 1,3/2»
#                   «4D~ 1/6♩ 1,3/2») and Node(3/2, dur=1/2 «~4D 1/6♩ 1,3/2»
#                   «4E 1/3♩ 1,3/2»)
# [maelzel.scoring.quant:quant.py:734:_splitWeakBeat:DEBUG] ------------ weak: «4D 1/3♩ 1,3/2», 1/2
# [maelzel.scoring.quant:quant.py:803:_splitWeakBeat:DEBUG] ------------ no need to split
# [maelzel.scoring:node.py:1153:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=1/2, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/16, quarterTempo=60, tree=Node(1/1, dur=1
#     Node(3/2, dur=1 «4C 1/3♩ 1,3/2»
#                     «4D 1/3♩ 1,3/2»
#                     «4E 1/3♩ 1,3/2»)), profile=high)> negative, «4D 1/3♩ 1,3/2» will NOT be split
# [maelzel.scoring:renderlily.py:1265:write:DEBUG] Rendering lilypond '/home/em/.cache/tmpm2m8hlt5/1kji3ftf.ly' to '/home/em/.cache/tmpm2m8hlt5/1kji3ftf.png'
# [maelzel.scoring:renderlily.py:1278:write:DEBUG] Found crop file '/home/em/.cache/tmpm2m8hlt5/1kji3ftf.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1291:write:DEBUG] Moving /home/em/.cache/tmpm2m8hlt5/1kji3ftf.cropped.png to /home/em/.cache/tmpm2m8hlt5/e21gcyvv.png
# Chain([4C:1/3♩, 4D:1/3♩, 4E:1/3♩])

# %%
logger.setLevel('INFO')

ch = Chain([
    "4C:1/3",
    "4D:1/3",
    "4E:1/3"
])
ch
# Out:
# Chain([4C:1/3♩, 4D:1/3♩, 4E:1/3♩])

# %%
from maelzel.core import *
from maelzel import scoring
from logging import getLogger

w = getWorkspace()
w.setScoreStruct(r'''
7/16(4-1-2)
''')

ch1 = Chain([
    "4F/16",
    "4g/16",
    "4a/16",
    
    "4C:1/3",
    "4D:1/3",
    "4E:1/3",
    
])
ch2 = Chain(["4C/16"]*7)

sc = Score([ch1, ch2])
sc.makeGroup((sc[0], sc[1]))
sc
# Out:
# [maelzel.core:mobj.py:2299:clearImageCache:INFO] Resetting image cache
# [maelzel.core:mobj.py:2299:clearImageCache:INFO] Resetting image cache
# Score(2 voices)

# %%
from maelzel.core import *
from maelzel import scoring
from logging import getLogger
logger = getLogger("maelzel")
logger.setLevel('DEBUG')

getWorkspace().setScoreStruct("4/4")

ch1 = Chain([
    "4f:3/20",
    "4g:3/20",
    "4a:3/20",
    "4f:3/20",
    "4g:3/20",
    "4C:1/4"
    
])

ch1
# Out:
# [maelzel.core:mobj.py:2299:clearImageCache:INFO] Resetting image cache
# [maelzel.scoring.quant:quant.py:692:_splitStrongBeat:DEBUG] split strong: «r 3♩», offset: 2
# [maelzel.scoring.quant:quant.py:734:_splitWeakBeat:DEBUG] ------------ weak: «r 3♩», 2
# [maelzel.scoring.quant:quant.py:753:_splitWeakBeat:DEBUG] No need to split since notation «r 3♩» is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring:node.py:1155:_splitNotationAtBeat:DEBUG] Syncopation at 0:2 - <bound method QuantizedMeasure._splitStrongBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(5/4, dur=1 «4F 3/20♩ 1,5/4»
#                     «4G 3/20♩ 1,5/4»
#                     «4A 3/20♩ 1,5/4»
#                     «4F 3/20♩ 1,5/4»
#                     «4G 3/20♩ 1,5/4»
#                     «4C~ 1/20♩ 1,5/4 properties={'.forwardTies': {0}}»
#                     «~4C 1/5♩ 1,5/4 properties={'.backwardTies': {0}}»)
#     «r 3♩»), profile=high)> was positive, splitting
# [maelzel.scoring.quant:quant.py:734:_splitWeakBeat:DEBUG] ------------ weak: «r 2♩», 3
# [maelzel.scoring.quant:quant.py:753:_splitWeakBeat:DEBUG] No need to split since notation «r 2♩» is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring:node.py:1153:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=3, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(5/4, dur=1 «4F 3/20♩ 1,5/4»
#                     «4G 3/20♩ 1,5/4»
#                     «4A 3/20♩ 1,5/4»
#                     «4F 3/20♩ 1,5/4»
#                     «4G 3/20♩ 1,5/4»
#                     «4C~ 1/20♩ 1,5/4 properties={'.forwardTies': {0}}»
#                     «~4C 1/5♩ 1,5/4 properties={'.backwardTies': {0}}»)
#     «r 1♩»
#     «r 2♩»), profile=high)> negative, «r 2♩» will NOT be split
# [maelzel.scoring.quant:quant.py:886:_checkTree:DEBUG] Found superfluous tie (tied to a rest??): n0=«r 1♩», n1=«r 2♩»
# [maelzel.scoring:renderlily.py:1265:write:DEBUG] Rendering lilypond '/home/em/.cache/tmpm2m8hlt5/0q7u15km.ly' to '/home/em/.cache/tmpm2m8hlt5/0q7u15km.png'
# [maelzel.scoring:renderlily.py:1278:write:DEBUG] Found crop file '/home/em/.cache/tmpm2m8hlt5/0q7u15km.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1291:write:DEBUG] Moving /home/em/.cache/tmpm2m8hlt5/0q7u15km.cropped.png to /home/em/.cache/tmpm2m8hlt5/3xmh3msw.png
# Chain([4F:3/20♩, 4G:3/20♩, 4A:3/20♩, 4F:3/20♩, 4G:3/20♩, 4C:1/4♩])
