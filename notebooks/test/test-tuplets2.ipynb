# %%
from maelzel.core import *

# %%
ch = Chain([
    "4C:1/3",
    "4D:1/3",
    "4E:1/3"
])
ch
# Out:
# Chain([4C:1/3♩, 4D:1/3♩, 4E:1/3♩])

# %%
ch = Chain([
    "4C:2/3",
    "4D:2/3",
    "4E:2/3"
])
ch
# Out:
# Chain([4C:2/3♩, 4D:2/3♩, 4E:2/3♩])

# %%
w = getWorkspace()
w.scorestruct = r'''
2/4
'''

ch = Chain([
    "4C:1/3",
    "4D:1/3",
    "4E:1/3"
])
ch
# Out:
# Chain([4C:1/3♩, 4D:1/3♩, 4E:1/3♩])

# %%
w.scorestruct = r'''
2/4
'''

ch = Chain([
    "4C:2/3",
    "4D:2/3",
    "4E:2/3"
])
ch
# Out:
# Chain([4C:2/3♩, 4D:2/3♩, 4E:2/3♩])

# %%
w.scorestruct = r'''
2/8
'''

ch = Chain([
    "4C:1/3",
    "4D:1/3",
    "4E:1/3"
])
ch
# Out:
# Chain([4C:1/3♩, 4D:1/3♩, 4E:1/3♩])

# %%
from maelzel.core import *
from maelzel import scoring
from logging import getLogger
logger = getLogger("maelzel")
logger.setLevel('DEBUG')

w = getWorkspace()
w.scorestruct = r'''
4/16
'''

ch = Chain([
    "4C:1/3",
    "4D:1/3",
    "4E:1/3"
])
ch
# Out:
# [maelzel.core:mobj.py:2321:clearImageCache:INFO] Resetting image cache
# [maelzel.scoring.quant:quant.py:1814:_nodesCanMerge:DEBUG] Merging Node(3/2, dur=1/2 «4C 1/3♩ 1,3/2»
#                   «4D~ 1/6♩ 1,3/2») and Node(3/2, dur=1/2 «~4D 1/6♩ 1,3/2»
#                   «4E 1/3♩ 1,3/2»)
# [maelzel.scoring.quant:quant.py:733:_splitWeakBeat:DEBUG] ------------ weak: «4D 1/3♩ 1,3/2», 1/2
# [maelzel.scoring.quant:quant.py:802:_splitWeakBeat:DEBUG] ------------ no need to split
# [maelzel.scoring:node.py:1149:_splitNotationAtBeat:DEBUG] Syncopation at 0:1/2, <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/16, quarterTempo=60, tree=Node(1/1, dur=1
#     Node(3/2, dur=1 «4C 1/3♩ 1,3/2»
#                     «4D 1/3♩ 1,3/2»
#                     «4E 1/3♩ 1,3/2»)), profile=high)> negative, «4D 1/3♩ 1,3/2» will NOT be split
# [maelzel.scoring:renderlily.py:1265:write:DEBUG] Rendering lilypond '/home/em/.cache/tmp0bicl303/f91yojho.ly' to '/home/em/.cache/tmp0bicl303/f91yojho.png'
# [maelzel.scoring:renderlily.py:1278:write:DEBUG] Found crop file '/home/em/.cache/tmp0bicl303/f91yojho.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1291:write:DEBUG] Moving /home/em/.cache/tmp0bicl303/f91yojho.cropped.png to /home/em/.cache/tmp0bicl303/jitajbyk.png
# Chain([4C:1/3♩, 4D:1/3♩, 4E:1/3♩])

# %%
logger.setLevel('INFO')

ch = Chain([
    "4C:1/3",
    "4D:1/3",
    "4E:1/3"
])
ch
# Out:
# Chain([4C:1/3♩, 4D:1/3♩, 4E:1/3♩])

# %%
from maelzel.core import *
from maelzel import scoring
from logging import getLogger

w = getWorkspace()
w.setScoreStruct(r'''
7/16(4-1-2)
''')

ch1 = Chain([
    "4F/16",
    "4g/16",
    "4a/16",
    
    "4C:1/3",
    "4D:1/3",
    "4E:1/3",
    
])
ch2 = Chain(["4C/16"]*7)

sc = Score([ch1, ch2])
sc.makeGroup((sc[0], sc[1]))
sc
# Out:
# [maelzel.core:mobj.py:2321:clearImageCache:INFO] Resetting image cache
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 22
#      10 ch1 = Chain([
#      11     "4F/16",
#      12     "4g/16",
#    (...)     18
#      19 ])
#      20 ch2 = Chain(["4C/16"]*7)
# ---> 22 sc = Score([ch1, ch2])
#      23 sc.makeGroup((sc[0], sc[1]))
#      24 sc
#
# File ~/dev/python/maelzel/maelzel/core/score.py:57, in Score.__init__(self, voices, scorestruct, title)
#      50 def __init__(self,
#      51              voices: Sequence[Voice | Chain | MEvent] = (),
#      52              scorestruct: ScoreStruct | None = None,
#      53              title=''):
#      55     super().__init__(label=title, offset=F0)
# ---> 57     asvoices: list[Voice] = [item if isinstance(item, Voice) else _asvoice(item)
#      58                              for item in voices]
#      59     for voice in asvoices:
#      60         voice.parent = self
#
# File ~/dev/python/maelzel/maelzel/core/score.py:30, in _asvoice(o)
#      28     return Voice([o])
#      29 elif isinstance(o, Chain):
# ---> 30     return o.asVoice()
#      31 else:
#      32     raise TypeError(f"Cannot create a Voice from {o} (type: {type(o)})")
#
# File ~/dev/python/maelzel/maelzel/core/chain.py:1033, in Chain.asVoice(self, removeOffsets)
#    1031 if self.playargs:
#    1032     voice.playargs = self.playargs.copy()
# -> 1033 if self._scorestruct:
#    1034     voice.setScoreStruct(self._scorestruct)
#    1035 if self._config:
#
# AttributeError: 'Chain' object has no attribute '_scorestruct'

# %%
from maelzel.core import *
from maelzel import scoring
from logging import getLogger
logger = getLogger("maelzel")
logger.setLevel('DEBUG')

setScoreStruct(r'''
4/4
''')

ch1 = Chain([
    "4f:3/20",
    "4g:3/20",
    "4a:3/20",
    "4f:3/20",
    "4g:3/20",
    "4C:1/4"
    
])

ch1
# Out:
# [maelzel.scoring:quant.py:1364:quantizeMeasure:DEBUG] Measure 4/4 is not filled (events=[«4F 0:0.15 3/20♩», «4G 0.15:0.3 3/20♩», «4A 0.3:0.45 3/20♩», «4F 0.45:0.6 3/20♩», «4G 0.6:0.75 3/20♩», «4C 0.75:1 1/4♩»]). Filling gaps with silences
# [maelzel.scoring:quant.py:1677:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(5/4,
#   «4F 0:0.15 3/20♩ 5/4»
#   «4G~ 0.15:0.25 1/10♩ 5/4»
# )
#     Node(5/4,
#   «~4G 0.25:0.3 1/20♩ 5/4»
#   «4A 0.3:0.45 3/20♩ 5/4»
#   «4F~ 0.45:0.5 1/20♩ 5/4»
# )
# [maelzel.scoring:quant.py:1680:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(5/4,
#   «4F 0:0.15 3/20♩ 5/4»
#   «4G 0.15:0.3 3/20♩ 5/4»
#   «4A 0.3:0.45 3/20♩ 5/4»
#   «4F~ 0.45:0.5 1/20♩ 5/4»
# )
# [maelzel.scoring:quant.py:1677:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(5/4,
#   «4F 0:0.15 3/20♩ 5/4»
#   «4G 0.15:0.3 3/20♩ 5/4»
#   «4A 0.3:0.45 3/20♩ 5/4»
#   «4F~ 0.45:0.5 1/20♩ 5/4»
# )
#     Node(5/4,
#   «~4F 0.5:0.6 1/10♩ 5/4»
#   «4G 0.6:0.75 3/20♩ 5/4»
# )
# [maelzel.scoring:quant.py:1680:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(5/4,
#   «4F 0:0.15 3/20♩ 5/4»
#   «4G 0.15:0.3 3/20♩ 5/4»
#   «4A 0.3:0.45 3/20♩ 5/4»
#   «4F 0.45:0.6 3/20♩ 5/4»
#   «4G 0.6:0.75 3/20♩ 5/4»
# )
# [maelzel.scoring:quant.py:1683:_mergeSiblings:DEBUG] Nodes cannot merge:
# Node(1/1,
#   Node(5/4,
#     «4F 0:0.15 3/20♩ 5/4»
#     «4G 0.15:0.3 3/20♩ 5/4»
#     «4A 0.3:0.45 3/20♩ 5/4»
#     «4F 0.45:0.6 3/20♩ 5/4»
#     «4G 0.6:0.75 3/20♩ 5/4»
#   )
#   «4C 0.75:1 1/4♩»
# )
# Node(1/1,
#   «rest 1:2 1♩»
# )
# ----> no need to extend node over beat
# [maelzel.scoring:quant.py:1677:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(1/1,
#   «rest 1:2 1♩»
# )
#     Node(1/1,
#   «rest 2:3 1♩»
# )
# [maelzel.scoring:quant.py:1680:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(1/1,
#   «rest 1:3 2♩»
# )
# [maelzel.scoring:quant.py:1677:_mergeSiblings:DEBUG] Nodes can merge:
#     Node(1/1,
#   «rest 1:3 2♩»
# )
#     Node(1/1,
#   «rest 3:4 1♩»
# )
# [maelzel.scoring:quant.py:1680:_mergeSiblings:DEBUG] ---- Merged node:
#     Node(1/1,
#   «rest 1:4 3♩»
# )
# [maelzel.scoring:node.py:805:_splitNotationAtBoundary:DEBUG] Found a syncopation but the callback was negative, so «rest 1:4 3♩» will not be split
# [maelzel.scoring:renderlily.py:1122:write:DEBUG] Rendering lilypond '/tmp/tmp3jd8a_yg.ly' to '/tmp/tmp3jd8a_yg.png'
# DEBUG:maelzel:Rendering lilypond '/tmp/tmp3jd8a_yg.ly' to '/tmp/tmp3jd8a_yg.png'
# DEBUG:maelzel:Calling lilypond subprocess: ['/home/em/.local/bin/lilypond', '--png', '-o', '/tmp/tmp3jd8a_yg', '-dresolution=200', '/tmp/tmplbg06ze8.ly']
# DEBUG:maelzel:lilypond executed OK
# DEBUG:maelzel:stderr:
# DEBUG:maelzel: Changing working directory to: `/tmp'
#  Processing `/tmp/tmplbg06ze8.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `tmp3jd8a_yg.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1135:write:DEBUG] Found crop file /tmp/tmp3jd8a_yg.cropped.png, using that as output
# Chain([4F:0.15♩, 4G:0.15♩, 4A:0.15♩, 4F:0.15♩, 4G:0.15♩, 4C:0.25♩])
