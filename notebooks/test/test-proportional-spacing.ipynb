# %%
from maelzel.core import *

# %%
v1 = Voice(r"""
    4C:2

    r:1/5
    4D:1/5
    4E-:1/5
    4F+:1/5
    4Gb-:1/5
""")

v2 = Voice(r"""
    
    4D:1/8
    4E-:1/8
    4F+:1/8
    4Gb-:1/8
    4D:1/8
    4E-:1/8
    4F+:1/8
    4Gb-:1/8

    4C:2
""")

v3 = Voice(r"""
    4G:1
    4G:1
    4G:1
""")
    
sco = Score([v1, v2, v3])
sco.show()

# %%
with CoreConfig(showProportionalSpacing=True, showProportionalNotationDuration='1/24'):
    # try 1/32 for wider spacing, 1/20 for narrower
    sco.write('tmp/proportional.ly')
    sco.show()
