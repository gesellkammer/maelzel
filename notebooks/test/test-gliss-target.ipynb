# %%
from maelzel.core import *

# %%
ch = Chain("""
    4C:2
    4E:1
""")
ch[0].setPlay(glisstime=0.5)
ch[0].gliss = True
ch
# Out:
# Chain([4C:2♩:gliss=True, 4E:1♩])

# %%
n = ch[0]
n.glissTargetPitch()
# Out:
# 64.0

# %%
ch = Chain([
    Chord("4C,4D:0.5"),
    Chord(a
          "4E,4A:1")
])
ch[0].notes[0].gliss = True
ch
# ch[0].gliss = True
# Out:
# Chain([‹4C,4D:0.5♩:gliss›, ‹4E,4A:1♩›])

# %%
ch1 = ch[1]
# %timeit ch1.absOffset()
# Out:
# 1.88 μs ± 32.3 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
ch.synthEvents()
# Out:
# [SynthEvent(delay=0, dur=1.5, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 60 -8.8; 0.5 64 -8.8; 1.5 64 -8.8｣),
#  SynthEvent(delay=0, dur=0.5, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 62 -8.8; 0.5 62 -8.8｣),
#  SynthEvent(delay=0.5, dur=1, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 69 -8.8; 1 69 -8.8｣)]

# %%
ch.play()
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Analog Stereo: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Analog Stereo:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=3)
#     Synth(‖ preset:sin=401.0002 start=.131 dur=1.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.364286 p20=0.5 p21=64 …)
#     Synth(‖ preset:sin=401.0003 start=.131 dur=.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=62 p19=0.364286 p20=0.5 p21=62 …)
# ...

# %%
ch = Chain([
    Chord("4C:0.5:gliss"),
    Chord("4E,4A:1")
])
ch
# ch[0].gliss = True
# Out:
# Chain([‹4C :0.5♩:gliss›, ‹4E,4A:1♩›])

# %%
ch.synthEvents()
# Out:
# [SynthEvent(delay=0, dur=1.5, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 60 -5.8; 0.5 64 -8.8; 1.5 64 -8.8｣),
#  SynthEvent(delay=0.5, dur=1, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 69 -8.8; 1 69 -8.8｣)]

# %%
ch.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=2)
#     Synth(‖ preset:sin=401.0005 start=19.454 dur=1.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.515178 p20=0.5 p21=64 …)
#     Synth(‖ preset:sin=401.0006 start=19.954 dur=1 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=69 p19=0.364286 p20=1 p21=69 …)

# %%
ch.scoringEvents()
# Out:
# [‹4C:gliss:1/2♩›, ‹4E,4A:1♩ 0.5:1.5›]

# %%
ch.unquantizedScore().dump()
# Out:
# Part #0
#   firstClef: treble
#    ‹4C:gliss:1/2♩›
#    ‹4E,4A:1♩ 0.5:1.5›

# %%
ch.rec()
# Out:
# OfflineRenderer(sr=44100)

# %%
cfg = getConfig()
cfg['quant.complexity'] = 'highest'
cfg['.quant.debug'] = True
a = Chain([Note(60, "9/17", gliss=67, dynamic='f'), Note(67, 1)])
a
# Out:
# Chain([4C:9/17♩:gliss=4G, 4G:1♩])

# %%
a.scoringEvents()
# Out:
# [‹4C:gliss:7/11♩ f›, ‹4G:𝆔›, ‹4G:1♩ 0.636:1.636›]

# %%
from maelzel.core import *
ch = Chain([
    Chord("4C:0.5", gliss="4G"),
    Chord("4E,4A:1")
])
ch
# Out:
# Chain([‹4C :0.5♩:gliss=4G›, ‹4E,4A:1♩›])

# %%
cfg = getWorkspace().config
cfg['show.glissStemless'] = True
cfg['show.glissParenthesis'] = False

# %%
from maelzel.core import *
ch = Chain([
    Chord("4C:0.5", gliss=True), 
    Chord("4E,4A:1", gliss="4D 4F"),
    Chord("4Eb,4F,4F#:1/4", gliss=("4Db", 0, 70)),
])
ch
# Out:
# Chain([‹4C :0.5♩:gliss›, ‹4E,4A:1♩:gliss=4D,4F›, ‹4Eb,4F,4Gb:0.25♩:gliss=4C#,-1C,4A#›])

# %%
# Combine gliss and tie

# %%
# %timeit ch.synthEvents()
# Out:
# 288 μs ± 2.25 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
ch.play()
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Analog Stereo: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Analog Stereo:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=5)
#     Synth(‖ preset:sin=401.0002 start=.137 dur=1.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.515178 p20=0.5 p21=64 …)
#     Synth(‖ preset:sin=401.0003 start=.637 dur=1 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=69 p19=0.364286 p20=1 p21=65 …)
# ...

# %%
# %load_ext line_profiler

# %%
# %lprun -f ch.flatEvents ch.flatEvents()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.00124126 s
# File: /home/em/dev/python/maelzel/maelzel/core/chain.py
# Function: Chain.flatEvents at line 391
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#    391                                               def flatEvents(self, forcecopy=False) -> list[MEvent]:
#    392                                                   """
#    393                                                   A list of flat events, with explicit absolute offsets set
#    394
#    395                                                   If an event already has an explicit offset, then the actual
#    396                                                   event is returned. Use ``forcecopy`` to ensure that the
#    397                                                   returned events are actually a copy
#    398
#    399                                                   Args:
# ...

# %%
# %lprun -f ch[0].copy ch[0].copy()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.000249573 s
# File: /home/em/dev/python/maelzel/maelzel/core/event.py
# Function: Chord.copy at line 1118
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#   1118                                               def copy(self):
#   1119         1     127357.0 127357.0     51.0          notes = [n.copy() for n in self.notes]
#   1120         2     100826.0  50413.0     40.4          out = self.__class__(notes=notes, dur=self.dur, amp=self.amp, offset=self.offset,
#   1121         1       6828.0   6828.0      2.7                               gliss=self.gliss, label=self.label, tied=self.tied,
#   1122         1       1579.0   1579.0      0.6                               dynamic=self.dynamic,
#   1123         1       1927.0   1927.0      0.8                               _init=False)
#   1124         1       9392.0   9392.0      3.8          self._copyAttributesTo(out)
# ...
