# %%
import maelzel.core.config
# Out:
# Importing .playback

# %%
from maelzel.core import *
# Out:
# Importing .playback

# %%
import maelzel.core.playback as pl

# %%
pl.

# %%
w = Workspace.active
w.playSession(backend='?')
# Out:
# created pipewire module
# --Csound version 7.0 (double samples) Sep  3 2025
# [commit: 34766e06e640abd1d7c556f218b17353def26481]
# created pipewire module
# --Csound version 7.0 (double samples) Sep  3 2025
# [commit: 34766e06e640abd1d7c556f218b17353def26481]
# created pipewire module
# --Csound version 7.0 (double samples) Sep  3 2025
# [commit: 34766e06e640abd1d7c556f218b17353def26481]
# created pipewire module
# --Csound version 7.0 (double samples) Sep  3 2025
# [commit: 34766e06e640abd1d7c556f218b17353def26481]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 w = Workspace.active
# ----> 2 w.playSession(backend='?')
#
# File ~/dev/python/maelzel/maelzel/core/workspace.py:470, in Workspace.playSession(self, outdev, backend, numchannels, buffersize, numbuffers, **kws)
#     448 """
#     449 Get the audio Session used for playback
#     450
#    (...)    467
#     468 """
#     469 from maelzel.core import playback
# --> 470 return playback.getSession(name=self.config['play.engineName'],
#     471                            outdev=outdev,
#     472                            backend=backend,
#     473                            numchannels=numchannels,
#     474                            buffersize=buffersize,
#     475                            numbuffers=numbuffers,
#     476                            **kws)
#
# File ~/dev/python/maelzel/maelzel/core/playback.py:275, in getSession(numchannels, backend, outdev, verbose, buffersize, latency, numbuffers, ensure, name)
#     233 """
#     234 Returns / creates the audio Session
#     235
#    (...)    272 .. seealso:: :class:`csoundengine.Session <https://csoundengine.readthedocs.io/en/latest/api/csoundengine.session.Session.html>`
#     273 """
#     274 if not isSessionActive(name=name):
# --> 275     engine = _playEngine(name=name,
#     276                          numchannels=numchannels,
#     277                          backend=backend,
#     278                          outdev=outdev,
#     279                          verbose=verbose,
#     280                          buffersize=buffersize,
#     281                          latency=latency,
#     282                          numbuffers=numbuffers)
#     283     session = engine.session()
#     284     for instr in _builtinInstrs():
#
# File ~/dev/python/maelzel/maelzel/core/playback.py:168, in _playEngine(numchannels, backend, outdev, verbose, buffersize, latency, numbuffers, config, name)
#     166 logger.debug(f"Starting engine {engineName} (nchnls={numchannels})")
#     167 latency = latency if latency is not None else config['play.schedLatency']
# --> 168 engine = csoundengine.Engine(name=engineName,
#     169                              nchnls=numchannels,
#     170                              backend=backend,
#     171                              outdev=outdev,
#     172                              globalcode=presetmanager.presetManager.csoundPrelude,
#     173                              quiet=not verbose,
#     174                              latency=latency,
#     175                              buffersize=buffersize,
#     176                              a4=config['A4'],
#     177                              numbuffers=numbuffers)
#     178 # We create the session as soon as possible, to configure the engine for
#     179 # the session's reserved instrument ranges / tables
#     180 _ = engine.session()
#
# File ~/.virtualenvs/maelzel/lib/python3.12/site-packages/csoundengine/engine.py:464, in Engine.__init__(self, name, sr, ksmps, backend, outdev, indev, a4, nchnls, nchnls_i, realtime, buffersize, numbuffers, globalcode, numAudioBuses, numControlBuses, quiet, udpserver, udpport, commandlineOptions, includes, midibackend, midiin, autosync, latency, sampleAccurate, numthreads, withBusSupport, nosound, useProcessQueue)
#     461     nchnls_i = inchnls
#     463 assert nchnls is not None and nchnls > 0
# --> 464 assert nchnls_i is not None and nchnls_i >= 0
#     466 if nosound and '--nosound' not in commandlineOptions:
#     467     commandlineOptions.append('--nosound')
#
# AssertionError:

# %%
v = Voice([Note(i, F(2,3)*F(1,10)) for i in range(60, 75)])
v
# Out:
# Voice([4C:1/15♩, 4C♯:1/15♩, 4D:1/15♩, 4D♯:1/15♩, 4E:1/15♩, 4F:1/15♩, 4F♯:1/15♩, 4G:1/15♩, 4G♯:1/15♩, 4A:1/15♩, …])

# %%
# v.addSymbolAt(symbols.BeamSubdivision(minimum=8, maximum=16), 0)
v.addSymbol(symbols.BeamSubdivision(minimum=8))
v
# Out:
# Voice([4C:1/15♩, 4C♯:1/15♩, 4D:1/15♩, 4D♯:1/15♩, 4E:1/15♩, 4F:1/15♩, 4F♯:1/15♩, 4G:1/15♩, 4G♯:1/15♩, 4A:1/15♩, …])

# %%
st = get
v = Voice([Note(i, F(2,3)*F(1,7)) for i in range(60, 75)])
v
# Out:
# Voice([4C:2/21♩, 4C♯:2/21♩, 4D:2/21♩, 4D♯:2/21♩, 4E:2/21♩, 4F:2/21♩, 4F♯:2/21♩, 4G:2/21♩, 4G♯:2/21♩, 4A:2/21♩, …])

# %%
v = Voice([Note(i, F(2,3)) for i in range(60, 69)])
v
# Out:
# Voice([4C:2/3♩, 4C♯:2/3♩, 4D:2/3♩, 4D♯:2/3♩, 4E:2/3♩, 4F:2/3♩, 4F♯:2/3♩, 4G:2/3♩, 4G♯:2/3♩])

# %%
v = Voice(r"""
4C:1/3
4D:1/3
4E:2/3
4F:1/3
4G:1/3
""")
v
# Out:
# Voice([4C:1/3♩, 4D:1/3♩, 4E:2/3♩, 4F:1/3♩, 4G:1/3♩])
