# %%
from maelzel.core import *
logger.parent.setLevel('DEBUG')

# %%
cfg = getConfig()

# %%
ch = Chain(r"""
4a:1/8
4g:2/8
r:1
4f:1
""")

ch.addBreak(1)
ch.addBreak(2)
ch
# Out:
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 17 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 57 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 57 divisions in 0.000 ms
# [maelzel.scoring:renderlily.py:1363:write:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/b5buryry.ly' to '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/b5buryry.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:316:renderLily:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/b5buryry.ly' to '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/b5buryry.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:345:renderLily:DEBUG] Calling lilypond subprocess, args=['/home/em/.local/share/lilyponddist/lilypond-2.25.31/bin/lilypond', '--png', '-o', '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/b5buryry', '-dresolution=200', '/tmp/tmpv7t9v3zt.ly']
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:391:renderLily:DEBUG] lilypond executed OK
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:397:renderLily:DEBUG] stderr:
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:398:renderLily:DEBUG]  Changing working directory to: `/home/em/.cache/maelzel/maelzel-tmp4kr12p46'
#  Processing `/tmp/tmpv7t9v3zt.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `b5buryry.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1377:write:DEBUG] Found crop file '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/b5buryry.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1390:write:DEBUG] Moving /home/em/.cache/maelzel/maelzel-tmp4kr12p46/b5buryry.cropped.png to /home/em/.cache/maelzel/maelzel-tmp4kr12p46/o2yaal_b.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 54 9
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 75 32
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 6785
# Chain([4A:1/8♩, 4G:1/4♩, R:1♩, 4F:1♩])

# %%
ch = Chain(r"""
4a:2/3
4g:2/3
4f:4/3
4f#:1
""")

ch
# Out:
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 100 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 100 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 100 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 100 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:1993:_nodesCanMerge:DEBUG] Can merge at offset 1: Node⌈³⁄₂ 1♩ 4A⋮2/3♩⋮0:0.667⋮³⁄₂,4G~⋮1/3♩⋮0.667:1⋮³⁄₂⌋ and Node⌈³⁄₂ 1♩ ~4G⋮1/3♩⋮1:1.333⋮³⁄₂,4F~⋮2/3♩⋮1.333:2⋮³⁄₂⌋
# [maelzel.scoring.quant:quant.py:1889:_nodesCanMerge:DEBUG] Sum. dur: 3, 3/1
# [maelzel.scoring.quant:quant.py:1993:_nodesCanMerge:DEBUG] Can merge at offset 3: Node⌈³⁄₂ 1♩ ~4F⋮2/3♩⋮2:2.667⋮³⁄₂,4F#~⋮1/3♩⋮2.667:3⋮³⁄₂⌋ and Node⌈³⁄₂ 1♩ ~4F#⋮2/3♩⋮3:3.667⋮³⁄₂,r⋮1/3♩⋮3.667:4⋮³⁄₂⌋
# [maelzel.scoring.quant:quant.py:721:_splitWeakBeat:DEBUG] -- evaluating weak split: 4G⋮2/3♩⋮0.667:1.333⋮³⁄₂, 1
# [maelzel.scoring.quant:quant.py:800:_splitWeakBeat:DEBUG] ---- no need to split, assymmetry: 1.000, binary: False
# [maelzel.scoring:node.py:1190:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=1, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node⌈¹⁄₁ 4♩
#     Node⌈³⁄₂ 2♩ 4A⋮2/3♩⋮0:0.667⋮³⁄₂,4G⋮2/3♩⋮0.667:1.333⋮³⁄₂,4F~⋮2/3♩⋮1.333:2⋮³⁄₂⌋
#     Node⌈³⁄₂ 2♩ ~4F⋮2/3♩⋮2:2.667⋮³⁄₂,4F#⋮1♩⋮2.667:3.667⋮³⁄₂,r⋮1/3♩⋮3.667:4⋮³⁄₂⌋⌋, profile=high)> negative, 4G⋮2/3♩⋮0.667:1.333⋮³⁄₂ will NOT be split
# [maelzel.scoring.quant:quant.py:721:_splitWeakBeat:DEBUG] -- evaluating weak split: 4F#⋮1♩⋮2.667:3.667⋮³⁄₂, 3
# [maelzel.scoring.quant:quant.py:800:_splitWeakBeat:DEBUG] ---- no need to split, assymmetry: 2.000, binary: False
# [maelzel.scoring:node.py:1190:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=3, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node⌈¹⁄₁ 4♩
#     Node⌈³⁄₂ 2♩ 4A⋮2/3♩⋮0:0.667⋮³⁄₂,4G⋮2/3♩⋮0.667:1.333⋮³⁄₂,4F~⋮2/3♩⋮1.333:2⋮³⁄₂⌋
#     Node⌈³⁄₂ 2♩ ~4F⋮2/3♩⋮2:2.667⋮³⁄₂,4F#⋮1♩⋮2.667:3.667⋮³⁄₂,r⋮1/3♩⋮3.667:4⋮³⁄₂⌋⌋, profile=high)> negative, 4F#⋮1♩⋮2.667:3.667⋮³⁄₂ will NOT be split
# [maelzel.scoring:renderlily.py:1363:write:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/g20rk778.ly' to '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/g20rk778.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:316:renderLily:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/g20rk778.ly' to '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/g20rk778.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:345:renderLily:DEBUG] Calling lilypond subprocess, args=['/home/em/.local/share/lilyponddist/lilypond-2.25.31/bin/lilypond', '--png', '-o', '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/g20rk778', '-dresolution=200', '/tmp/tmpiusnbtv7.ly']
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:391:renderLily:DEBUG] lilypond executed OK
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:397:renderLily:DEBUG] stderr:
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:398:renderLily:DEBUG]  Changing working directory to: `/home/em/.cache/maelzel/maelzel-tmp4kr12p46'
#  Processing `/tmp/tmpiusnbtv7.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `g20rk778.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1377:write:DEBUG] Found crop file '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/g20rk778.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1390:write:DEBUG] Moving /home/em/.cache/maelzel/maelzel-tmp4kr12p46/g20rk778.cropped.png to /home/em/.cache/maelzel/maelzel-tmp4kr12p46/wajj26hv.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 54 9
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 75 32
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5593
# Chain([4A:2/3♩, 4G:2/3♩, 4F:4/3♩, 4F♯:1♩])

# %%
ch = Chain(r"""
4c:1.5
4a:2/3
4g:2/3
4f:4/3
4f#:1
""")

ch
# Out:
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 100 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 100 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 55 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 55 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:721:_splitWeakBeat:DEBUG] -- evaluating weak split: 4C⋮3/2♩⋮0:1.5, 1
# [maelzel.scoring.quant:quant.py:740:_splitWeakBeat:DEBUG] ---- No need to split at 1 since notation 4C⋮3/2♩⋮0:1.5 is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring:node.py:1190:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=1, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node⌈¹⁄₁ 4♩ 4C⋮3/2♩⋮0:1.5
#             4A~⋮1/2♩⋮1.5:2=1/2
#             Node⌈³⁄₂ 1/4♩ ~4A⋮1/6♩⋮2:2.167⋮³⁄₂,4G~⋮1/12♩⋮2.167:2.25⋮³⁄₂⌋
#             ~4G~⋮1/2♩⋮2.25:2.75=1/2
#             Node⌈³⁄₂ 1/4♩ ~4G⋮1/12♩⋮2.75:2.833⋮³⁄₂,4F~⋮1/6♩⋮2.833:3⋮³⁄₂⌋
#             ~4F~⋮1♩⋮3:4=1⌋, profile=high)> negative, 4C⋮3/2♩⋮0:1.5 will NOT be split
# [maelzel.scoring.quant:quant.py:666:_splitStrongBeat:DEBUG] >> split strong?: r⋮3/2♩⋮1.5:3, offset: 2, measure: 1
# [maelzel.scoring.quant:quant.py:721:_splitWeakBeat:DEBUG] -- evaluating weak split: r⋮3/2♩⋮1.5:3, 2
# [maelzel.scoring.quant:quant.py:740:_splitWeakBeat:DEBUG] ---- No need to split at 2 since notation r⋮3/2♩⋮1.5:3 is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring.quant:quant.py:711:_splitStrongBeat:DEBUG] >>>> Notation at split point is a rest, can split
# [maelzel.scoring:node.py:1192:_splitNotationAtBeat:DEBUG] Syncopation at 1:2 - <bound method QuantizedMeasure._splitStrongBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node⌈¹⁄₁ 4♩
#     Node⌈³⁄₂ 1/2♩ ~4F⋮1/6♩⋮0:0.167⋮³⁄₂,4F#~⋮1/3♩⋮0.167:0.5⋮³⁄₂⌋
#     ~4F#~⋮1/2♩⋮0.5:1=1/2
#     Node⌈³⁄₂ 1/2♩ ~4F#⋮1/6♩⋮1:1.167⋮³⁄₂,r⋮1/3♩⋮1.167:1.5⋮³⁄₂⌋
#     r⋮3/2♩⋮1.5:3=3/2
#     r⋮1♩⋮3:4=1⌋, profile=high)> was positive, splitting
# [maelzel.scoring.quant:quant.py:833:breakSyncopations:DEBUG] Split strong at beat index: 2
# [maelzel.scoring.quant:quant.py:721:_splitWeakBeat:DEBUG] -- evaluating weak split: r⋮2♩⋮2:4, 3
# [maelzel.scoring.quant:quant.py:740:_splitWeakBeat:DEBUG] ---- No need to split at 3 since notation r⋮2♩⋮2:4 is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring:node.py:1190:_splitNotationAtBeat:DEBUG] Syncopation at meas=1, offset=3, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node⌈¹⁄₁ 4♩
#     Node⌈³⁄₂ 1/2♩ ~4F⋮1/6♩⋮0:0.167⋮³⁄₂,4F#~⋮1/3♩⋮0.167:0.5⋮³⁄₂⌋
#     ~4F#~⋮1/2♩⋮0.5:1=1/2
#     Node⌈³⁄₂ 1/2♩ ~4F#⋮1/6♩⋮1:1.167⋮³⁄₂,r⋮1/3♩⋮1.167:1.5⋮³⁄₂⌋
#     r⋮1/2♩⋮1.5:2=1/2
#     r⋮2♩⋮2:4=2⌋, profile=high)> negative, r⋮2♩⋮2:4 will NOT be split
# [maelzel.scoring.quant:quant.py:887:_checkTree:DEBUG] Found superfluous tie (tied to a rest??): n0=r⋮1/2♩⋮1.5:2, n1=r⋮2♩⋮2:4
# [maelzel.scoring:renderlily.py:1363:write:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/8kgkxkru.ly' to '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/8kgkxkru.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:316:renderLily:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/8kgkxkru.ly' to '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/8kgkxkru.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:345:renderLily:DEBUG] Calling lilypond subprocess, args=['/home/em/.local/share/lilyponddist/lilypond-2.25.31/bin/lilypond', '--png', '-o', '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/8kgkxkru', '-dresolution=200', '/tmp/tmply4rok34.ly']
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:391:renderLily:DEBUG] lilypond executed OK
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:397:renderLily:DEBUG] stderr:
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:398:renderLily:DEBUG]  Changing working directory to: `/home/em/.cache/maelzel/maelzel-tmp4kr12p46'
#  Processing `/tmp/tmply4rok34.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `8kgkxkru.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1377:write:DEBUG] Found crop file '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/8kgkxkru.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1390:write:DEBUG] Moving /home/em/.cache/maelzel/maelzel-tmp4kr12p46/8kgkxkru.cropped.png to /home/em/.cache/maelzel/maelzel-tmp4kr12p46/452y01xp.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 54 9
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 75 32
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 8192
# Chain([4C:3/2♩, 4A:2/3♩, 4G:2/3♩, 4F:4/3♩, 4F♯:1♩])

# %%
from maelzel.core import *
logger.parent.setLevel('DEBUG')

ch2 = Chain(r"""
4c:1/6
4a:4/3
""")
ch2
# Out:
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 55 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 100 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:666:_splitStrongBeat:DEBUG] >> split strong?: r⋮3/2♩⋮1.5:3, offset: 2, measure: 0
# [maelzel.scoring.quant:quant.py:721:_splitWeakBeat:DEBUG] -- evaluating weak split: r⋮3/2♩⋮1.5:3, 2
# [maelzel.scoring.quant:quant.py:740:_splitWeakBeat:DEBUG] ---- No need to split at 2 since notation r⋮3/2♩⋮1.5:3 is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring.quant:quant.py:711:_splitStrongBeat:DEBUG] >>>> Notation at split point is a rest, can split
# [maelzel.scoring:node.py:1192:_splitNotationAtBeat:DEBUG] Syncopation at 0:2 - <bound method QuantizedMeasure._splitStrongBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node⌈¹⁄₁ 4♩
#     Node⌈³⁄₂ 1/2♩ 4C⋮1/6♩⋮0:0.167⋮³⁄₂,4A~⋮1/3♩⋮0.167:0.5⋮³⁄₂⌋
#     ~4A⋮1♩⋮0.5:1.5=1
#     r⋮3/2♩⋮1.5:3=3/2
#     r⋮1♩⋮3:4=1⌋, profile=high)> was positive, splitting
# [maelzel.scoring.quant:quant.py:833:breakSyncopations:DEBUG] Split strong at beat index: 2
# [maelzel.scoring.quant:quant.py:721:_splitWeakBeat:DEBUG] -- evaluating weak split: ~4A⋮1♩⋮0.5:1.5, 1
# [maelzel.scoring.quant:quant.py:800:_splitWeakBeat:DEBUG] ---- no need to split, assymmetry: 1.000, binary: True
# [maelzel.scoring:node.py:1190:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=1, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node⌈¹⁄₁ 4♩
#     Node⌈³⁄₂ 1/2♩ 4C⋮1/6♩⋮0:0.167⋮³⁄₂,4A~⋮1/3♩⋮0.167:0.5⋮³⁄₂⌋
#     ~4A⋮1♩⋮0.5:1.5=1
#     r⋮1/2♩⋮1.5:2=1/2
#     r⋮2♩⋮2:4=2⌋, profile=high)> negative, ~4A⋮1♩⋮0.5:1.5 will NOT be split
# [maelzel.scoring.quant:quant.py:721:_splitWeakBeat:DEBUG] -- evaluating weak split: r⋮2♩⋮2:4, 3
# [maelzel.scoring.quant:quant.py:740:_splitWeakBeat:DEBUG] ---- No need to split at 3 since notation r⋮2♩⋮2:4 is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring:node.py:1190:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=3, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node⌈¹⁄₁ 4♩
#     Node⌈³⁄₂ 1/2♩ 4C⋮1/6♩⋮0:0.167⋮³⁄₂,4A~⋮1/3♩⋮0.167:0.5⋮³⁄₂⌋
#     ~4A⋮1♩⋮0.5:1.5=1
#     r⋮1/2♩⋮1.5:2=1/2
#     r⋮2♩⋮2:4=2⌋, profile=high)> negative, r⋮2♩⋮2:4 will NOT be split
# [maelzel.scoring.quant:quant.py:887:_checkTree:DEBUG] Found superfluous tie (tied to a rest??): n0=r⋮1/2♩⋮1.5:2, n1=r⋮2♩⋮2:4
# [maelzel.scoring:renderlily.py:1363:write:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/brbuwc4o.ly' to '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/brbuwc4o.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:316:renderLily:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/brbuwc4o.ly' to '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/brbuwc4o.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:345:renderLily:DEBUG] Calling lilypond subprocess, args=['/home/em/.local/share/lilyponddist/lilypond-2.25.31/bin/lilypond', '--png', '-o', '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/brbuwc4o', '-dresolution=200', '/tmp/tmpasozr8lb.ly']
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:391:renderLily:DEBUG] lilypond executed OK
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:397:renderLily:DEBUG] stderr:
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:398:renderLily:DEBUG]  Changing working directory to: `/home/em/.cache/maelzel/maelzel-tmp4kr12p46'
#  Processing `/tmp/tmpasozr8lb.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `brbuwc4o.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1377:write:DEBUG] Found crop file '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/brbuwc4o.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1390:write:DEBUG] Moving /home/em/.cache/maelzel/maelzel-tmp4kr12p46/brbuwc4o.cropped.png to /home/em/.cache/maelzel/maelzel-tmp4kr12p46/_z_ck_rp.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 54 9
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 75 32
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4788
# Chain([4C:1/6♩, 4A:4/3♩])

# %%
from maelzel.core import *
logger.parent.setLevel('DEBUG')
cfg = getConfig()
cfg['quant.complexity'] = 'highest'

ch2 = Chain(r"""
4c:1/3*2/5
4d:1/3*2/5
4e:1/3*3/5
4f:4/7

""")
ch2
# Out:
# [maelzel.core:mobj.py:2299:clearImageCache:INFO] Resetting image cache
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 1 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:1248:quantizeBeat2:DEBUG] Searched perfect fits, found 0 divisions in 0.000 ms
# [maelzel.scoring.quant:quant.py:666:_splitStrongBeat:DEBUG] >> split strong?: r⋮3/2♩⋮1.5:3, offset: 2, measure: 0
# [maelzel.scoring.quant:quant.py:721:_splitWeakBeat:DEBUG] -- evaluating weak split: r⋮3/2♩⋮1.5:3, 2
# [maelzel.scoring.quant:quant.py:740:_splitWeakBeat:DEBUG] ---- No need to split at 2 since notation r⋮3/2♩⋮1.5:3 is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring.quant:quant.py:711:_splitStrongBeat:DEBUG] >>>> Notation at split point is a rest, can split
# [maelzel.scoring:node.py:1192:_splitNotationAtBeat:DEBUG] Syncopation at 0:2 - <bound method QuantizedMeasure._splitStrongBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node⌈¹⁄₁ 4♩
#     Node⌈³⁄₂ 1♩
#         Node⌈⁵⁄₄ 2/3♩ 4C⋮2/15♩⋮0:0.133⋮³⁄₂⁵⁄₄,4D⋮2/15♩⋮0.133:0.267⋮³⁄₂⁵⁄₄,4E⋮1/5♩⋮0.267:0.467⋮³⁄₂⁵⁄₄,4F~⋮1/5♩⋮0.467:0.667⋮³⁄₂⁵⁄₄⌋
#         ~4F~⋮1/3♩⋮0.667:1⋮³⁄₂=1/2⌋
#     Node⌈¹³⁄₈ 1/2♩ ~4F⋮1/26♩⋮1:1.038⋮¹³⁄₈,r⋮6/13♩⋮1.038:1.5⋮¹³⁄₈⌋
#     r⋮3/2♩⋮1.5:3=3/2
#     r⋮1♩⋮3:4=1⌋, profile=highest)> was positive, splitting
# [maelzel.scoring.quant:quant.py:833:breakSyncopations:DEBUG] Split strong at beat index: 2
# [maelzel.scoring.quant:quant.py:721:_splitWeakBeat:DEBUG] -- evaluating weak split: r⋮2♩⋮2:4, 3
# [maelzel.scoring.quant:quant.py:740:_splitWeakBeat:DEBUG] ---- No need to split at 3 since notation r⋮2♩⋮2:4 is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring:node.py:1190:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=3, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node⌈¹⁄₁ 4♩
#     Node⌈³⁄₂ 1♩
#         Node⌈⁵⁄₄ 2/3♩ 4C⋮2/15♩⋮0:0.133⋮³⁄₂⁵⁄₄,4D⋮2/15♩⋮0.133:0.267⋮³⁄₂⁵⁄₄,4E⋮1/5♩⋮0.267:0.467⋮³⁄₂⁵⁄₄,4F~⋮1/5♩⋮0.467:0.667⋮³⁄₂⁵⁄₄⌋
#         ~4F~⋮1/3♩⋮0.667:1⋮³⁄₂=1/2⌋
#     Node⌈¹³⁄₈ 1/2♩ ~4F⋮1/26♩⋮1:1.038⋮¹³⁄₈,r⋮6/13♩⋮1.038:1.5⋮¹³⁄₈⌋
#     r⋮1/2♩⋮1.5:2=1/2
#     r⋮2♩⋮2:4=2⌋, profile=highest)> negative, r⋮2♩⋮2:4 will NOT be split
# [maelzel.scoring.quant:quant.py:887:_checkTree:DEBUG] Found superfluous tie (tied to a rest??): n0=r⋮1/2♩⋮1.5:2, n1=r⋮2♩⋮2:4
# [maelzel.scoring:renderlily.py:1363:write:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/_miuyqtz.ly' to '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/_miuyqtz.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:316:renderLily:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/_miuyqtz.ly' to '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/_miuyqtz.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:345:renderLily:DEBUG] Calling lilypond subprocess, args=['/home/em/.local/share/lilyponddist/lilypond-2.25.31/bin/lilypond', '--png', '-o', '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/_miuyqtz', '-dresolution=200', '/tmp/tmpjlyhs3d7.ly']
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:391:renderLily:DEBUG] lilypond executed OK
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:397:renderLily:DEBUG] stderr:
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:398:renderLily:DEBUG]  Changing working directory to: `/home/em/.cache/maelzel/maelzel-tmp4kr12p46'
#  Processing `/tmp/tmpjlyhs3d7.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `_miuyqtz.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1377:write:DEBUG] Found crop file '/home/em/.cache/maelzel/maelzel-tmp4kr12p46/_miuyqtz.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1390:write:DEBUG] Moving /home/em/.cache/maelzel/maelzel-tmp4kr12p46/_miuyqtz.cropped.png to /home/em/.cache/maelzel/maelzel-tmp4kr12p46/w1ga1xml.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 54 9
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 75 32
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 8192
# Chain([4C:2/15♩, 4D:2/15♩, 4E:1/5♩, 4F:4/7♩])
