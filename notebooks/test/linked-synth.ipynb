# %%
from maelzel.core import *
logger.parent.setLevel('DEBUG')

# %%
cfg = getConfig()

# %%
ch = Chain(r"""
4a:1/8
4g:2/8
r:1
4f:1
""")

ch.addBreak(1)
ch.addBreak(2)
ch
# Out:
# [maelzel.scoring.quant:quant.py:684:_splitWeakBeat:DEBUG] ------------ weak: «r:3/2♩», 3
# [maelzel.scoring.quant:quant.py:753:_splitWeakBeat:DEBUG] ------------ no need to split
# [maelzel.scoring:node.py:1151:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=3, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4 «4A:1/8♩»
#                 «4G:1/4♩»
#                 «r:1/8♩»
#                 «r:1/2♩»
#                 «r:3/8♩ attachments=[Breath(horizontalPlacement=pre, placement=above)]»
#                 «4F~|:1/8♩ properties={'.forwardTies': {0}}»
#                 «~4F~|:1/2♩ properties={'.backwardTies': {0}, '.forwardTies': {0}}»
#                 «|~4F:3/8♩ attachments=[Breath(horizontalPlacement=pre, placement=above)] properties={'.backwardTies': {0}}»
#                 «r:1/8♩»
#                 «r:3/2♩»), profile=high)> negative, «r:3/2♩» will NOT be split
# [maelzel.scoring:renderlily.py:1297:write:DEBUG] Rendering lilypond '/home/em/.cache/tmp2stsa6z4/oh1uxfwr.ly' to '/home/em/.cache/tmp2stsa6z4/oh1uxfwr.png'
# [maelzel.scoring:renderlily.py:1310:write:DEBUG] Found crop file '/home/em/.cache/tmp2stsa6z4/oh1uxfwr.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1323:write:DEBUG] Moving /home/em/.cache/tmp2stsa6z4/oh1uxfwr.cropped.png to /home/em/.cache/tmp2stsa6z4/q3nj3myq.png
# Chain([4A:1/8♩, 4G:1/4♩, R:1♩, 4F:1♩])

# %%
ch = Chain(r"""
4a:2/3
4g:2/3
4f:4/3
4f#:1
""")

ch
# Out:
# Chain([4A:2/3♩, 4G:2/3♩, 4F:4/3♩, 4F♯:1♩])

# %%
ch = Chain(r"""
4c:1.5
4a:2/3
4g:2/3
4f:4/3
4f#:1
""")

ch
# Out:
# Chain([4C:3/2♩, 4A:2/3♩, 4G:2/3♩, 4F:4/3♩, 4F♯:1♩])

# %%
from maelzel.core import *
logger.parent.setLevel('DEBUG')

ch2 = Chain(r"""
4c:1/6
4a:4/3
""")
ch2
# Out:
# [maelzel.scoring.quant:quant.py:633:_splitStrongBeat:DEBUG] split strong: «r:3/2♩», offset: 2
# [maelzel.scoring.quant:quant.py:684:_splitWeakBeat:DEBUG] ------------ weak: «r:3/2♩», 2
# [maelzel.scoring.quant:quant.py:703:_splitWeakBeat:DEBUG] No need to split since notation «r:3/2♩» is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring.quant:quant.py:669:_splitStrongBeat:DEBUG] dotted and not aligned, splitting
# [maelzel.scoring:node.py:1153:_splitNotationAtBeat:DEBUG] Syncopation at 0:2 - <bound method QuantizedMeasure._splitStrongBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(3/2, dur=1/2 «4C:1/6♩ 1,3/2»
#                       «4A~:1/3♩ 1,3/2 properties={'.forwardTies': {0}}»)
#     «~4A:1♩ properties={'.backwardTies': {0}}»
#     «r:3/2♩»
#     «r:1♩»), profile=high)> was positive, splitting
# [maelzel.scoring.quant:quant.py:684:_splitWeakBeat:DEBUG] ------------ weak: «~4A:1♩ properties={'.backwardTies': {0}}», 1
# [maelzel.scoring.quant:quant.py:753:_splitWeakBeat:DEBUG] ------------ no need to split
# [maelzel.scoring:node.py:1151:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=1, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(3/2, dur=1/2 «4C:1/6♩ 1,3/2»
#                       «4A~:1/3♩ 1,3/2 properties={'.forwardTies': {0}}»)
#     «~4A:1♩ properties={'.backwardTies': {0}}»
#     «r:1/2♩»
#     «r:2♩»), profile=high)> negative, «~4A:1♩ properties={'.backwardTies': {0}}» will NOT be split
# [maelzel.scoring.quant:quant.py:684:_splitWeakBeat:DEBUG] ------------ weak: «r:2♩», 3
# [maelzel.scoring.quant:quant.py:703:_splitWeakBeat:DEBUG] No need to split since notation «r:2♩» is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring:node.py:1151:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=3, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(3/2, dur=1/2 «4C:1/6♩ 1,3/2»
#                       «4A~:1/3♩ 1,3/2 properties={'.forwardTies': {0}}»)
#     «~4A:1♩ properties={'.backwardTies': {0}}»
#     «r:1/2♩»
#     «r:2♩»), profile=high)> negative, «r:2♩» will NOT be split
# [maelzel.scoring.quant:quant.py:837:_checkTree:DEBUG] Found superfluous tie (tied to a rest??): n0=«r:1/2♩», n1=«r:2♩»
# [maelzel.scoring:renderlily.py:1297:write:DEBUG] Rendering lilypond '/home/em/.cache/tmp2stsa6z4/pgug3ime.ly' to '/home/em/.cache/tmp2stsa6z4/pgug3ime.png'
# [maelzel.scoring:renderlily.py:1310:write:DEBUG] Found crop file '/home/em/.cache/tmp2stsa6z4/pgug3ime.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1323:write:DEBUG] Moving /home/em/.cache/tmp2stsa6z4/pgug3ime.cropped.png to /home/em/.cache/tmp2stsa6z4/pzj7ghe8.png
# Chain([4C:1/6♩, 4A:4/3♩])

# %%
from maelzel.core import *
logger.parent.setLevel('DEBUG')
from maelzel.scoring import quant

ch2 = Chain(r"""
4c:1/3*2/5
4d:1/3*2/5
4e:1/3*3/5
4f:4/7

""")
ch2
# Out:
# [maelzel.scoring.quant:quant.py:684:_splitWeakBeat:DEBUG] ------------ weak: «r:2♩», 3
# [maelzel.scoring.quant:quant.py:703:_splitWeakBeat:DEBUG] No need to split since notation «r:2♩» is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring:node.py:1151:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=3, callback <bound method QuantizedMeasure._splitWeakBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(3/2, dur=1
#         Node(5/4, dur=2/3 «4C:2/15♩ 1,3/2,5/4»
#                           «4D:2/15♩ 1,3/2,5/4»
#                           «4E:1/5♩ 1,3/2,5/4»
#                           «4F~:1/5♩ 1,3/2,5/4 properties={'.forwardTies': {0}}»)
#         «~4F~:1/3♩ 1,3/2 properties={'.backwardTies': {0}, '.forwardTies': {0}}»)
#     Node(3/2, dur=1
#         Node(9/8, dur=1/3 «~4F:1/27♩ 1,3/2,9/8 properties={'.backwardTies': {0}}»
#                           «r:8/27♩ 1,3/2,9/8»)
#         «r:2/3♩ 1,3/2»)
#     «r:2♩»), profile=high)> negative, «r:2♩» will NOT be split
# [maelzel.scoring:renderlily.py:1297:write:DEBUG] Rendering lilypond '/home/em/.cache/tmp2stsa6z4/k656vsj5.ly' to '/home/em/.cache/tmp2stsa6z4/k656vsj5.png'
# [maelzel.scoring:renderlily.py:1310:write:DEBUG] Found crop file '/home/em/.cache/tmp2stsa6z4/k656vsj5.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1323:write:DEBUG] Moving /home/em/.cache/tmp2stsa6z4/k656vsj5.cropped.png to /home/em/.cache/tmp2stsa6z4/s5wwkbir.png
# Chain([4C:2/15♩, 4D:2/15♩, 4E:1/5♩, 4F:4/7♩])
