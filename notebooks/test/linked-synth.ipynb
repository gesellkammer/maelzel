# %%
from maelzel.core import *
logger.parent.setLevel('DEBUG')

# %%
cfg = getConfig()

# %%
ch = Chain(r"""
4a:1/8
4g:2/8
r:1
4f:1
""")

ch.addBreak(1)
ch.addBreak(2)
ch
# Out:
# [maelzel.scoring:renderlily.py:1356:write:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/34yqt60g.ly' to '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/34yqt60g.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:317:renderLily:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/34yqt60g.ly' to '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/34yqt60g.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:346:renderLily:DEBUG] Calling lilypond subprocess, args=['/home/em/.local/share/lilyponddist/lilypond-2.25.31/bin/lilypond', '--png', '-o', '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/34yqt60g', '-dresolution=200', '/tmp/tmpqqq05vrr.ly']
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:392:renderLily:DEBUG] lilypond executed OK
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:398:renderLily:DEBUG] stderr:
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:399:renderLily:DEBUG]  Changing working directory to: `/home/em/.cache/maelzel/maelzel-tmpillwbv9u'
#  Processing `/tmp/tmpqqq05vrr.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `34yqt60g.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1370:write:DEBUG] Found crop file '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/34yqt60g.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1383:write:DEBUG] Moving /home/em/.cache/maelzel/maelzel-tmpillwbv9u/34yqt60g.cropped.png to /home/em/.cache/maelzel/maelzel-tmpillwbv9u/xyvin6r1.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 54 9
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 75 32
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 6826
# Chain([4A:1/8♩, 4G:1/4♩, R:1♩, 4F:1♩])

# %%
ch = Chain(r"""
4a:2/3
4g:2/3
4f:4/3
4f#:1
""")

ch
# Out:
# [maelzel.scoring.quant:quant.py:1882:_nodesCanMerge:DEBUG] Merging Node(3/2, dur=1 «4A:2/3♩ 1,3/2»
#                 «4G~:1/3♩ 1,3/2») and Node(3/2, dur=1 «~4G:1/3♩ 1,3/2»
#                 «4F~:2/3♩ 1,3/2»)
# [maelzel.scoring.quant:quant.py:649:_splitStrongBeat:DEBUG] split strong: «4G:2/3♩ 1,3/2», offset: 1
# [maelzel.scoring.quant:quant.py:700:_splitWeakBeat:DEBUG] ------------ weak: «4G:2/3♩ 1,3/2», 1
# [maelzel.scoring.quant:quant.py:778:_splitWeakBeat:DEBUG] ------------ no need to split, assymmetry: 1.000, binary: False
# [maelzel.scoring.quant:quant.py:677:_splitStrongBeat:DEBUG] No need to split quarter note
# [maelzel.scoring:node.py:1094:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=1, callback <bound method QuantizedMeasure._splitStrongBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(3/2, dur=2 «4A:2/3♩ 1,3/2»
#                     «4G:2/3♩ 1,3/2»
#                     «4F~:2/3♩ 1,3/2 properties={'.forwardTies': {0}}»)
#     Node(3/2, dur=1 «~4F:2/3♩ 1,3/2 properties={'.backwardTies': {0}}»
#                     «4F#~:1/3♩ 1,3/2 properties={'.forwardTies': {0}}»)
#     Node(3/2, dur=1 «~4F#:2/3♩ 1,3/2 properties={'.backwardTies': {0}}»
#                     «r:1/3♩ 1,3/2»)), profile=high)> negative, «4G:2/3♩ 1,3/2» will NOT be split
# [maelzel.scoring:renderlily.py:1356:write:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/45obmtrb.ly' to '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/45obmtrb.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:317:renderLily:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/45obmtrb.ly' to '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/45obmtrb.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:346:renderLily:DEBUG] Calling lilypond subprocess, args=['/home/em/.local/share/lilyponddist/lilypond-2.25.31/bin/lilypond', '--png', '-o', '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/45obmtrb', '-dresolution=200', '/tmp/tmpgnsvcry5.ly']
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:392:renderLily:DEBUG] lilypond executed OK
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:398:renderLily:DEBUG] stderr:
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:399:renderLily:DEBUG]  Changing working directory to: `/home/em/.cache/maelzel/maelzel-tmpillwbv9u'
#  Processing `/tmp/tmpgnsvcry5.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `45obmtrb.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1370:write:DEBUG] Found crop file '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/45obmtrb.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1383:write:DEBUG] Moving /home/em/.cache/maelzel/maelzel-tmpillwbv9u/45obmtrb.cropped.png to /home/em/.cache/maelzel/maelzel-tmpillwbv9u/lnylti36.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 54 9
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 75 32
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5920
# Chain([4A:2/3♩, 4G:2/3♩, 4F:4/3♩, 4F♯:1♩])

# %%
ch = Chain(r"""
4c:1.5
4a:2/3
4g:2/3
4f:4/3
4f#:1
""")

ch
# Out:
# [maelzel.scoring.quant:quant.py:649:_splitStrongBeat:DEBUG] split strong: «4C:3/2♩», offset: 1
# [maelzel.scoring.quant:quant.py:700:_splitWeakBeat:DEBUG] ------------ weak: «4C:3/2♩», 1
# [maelzel.scoring.quant:quant.py:719:_splitWeakBeat:DEBUG] No need to split since notation «4C:3/2♩» is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring.quant:quant.py:685:_splitStrongBeat:DEBUG] dotted and not aligned, splitting
# [maelzel.scoring.quant:quant.py:649:_splitStrongBeat:DEBUG] split strong: «r:3/2♩», offset: 2
# [maelzel.scoring.quant:quant.py:700:_splitWeakBeat:DEBUG] ------------ weak: «r:3/2♩», 2
# [maelzel.scoring.quant:quant.py:719:_splitWeakBeat:DEBUG] No need to split since notation «r:3/2♩» is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring.quant:quant.py:685:_splitStrongBeat:DEBUG] dotted and not aligned, splitting
# [maelzel.scoring.quant:quant.py:862:_checkTree:DEBUG] Found superfluous tie (tied to a rest??): n0=«r:1/2♩», n1=«r:2♩»
# [maelzel.scoring:renderlily.py:1356:write:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/y0f5_7nf.ly' to '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/y0f5_7nf.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:317:renderLily:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/y0f5_7nf.ly' to '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/y0f5_7nf.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:346:renderLily:DEBUG] Calling lilypond subprocess, args=['/home/em/.local/share/lilyponddist/lilypond-2.25.31/bin/lilypond', '--png', '-o', '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/y0f5_7nf', '-dresolution=200', '/tmp/tmpgkk5nuv0.ly']
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:392:renderLily:DEBUG] lilypond executed OK
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:398:renderLily:DEBUG] stderr:
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:399:renderLily:DEBUG]  Changing working directory to: `/home/em/.cache/maelzel/maelzel-tmpillwbv9u'
#  Processing `/tmp/tmpgkk5nuv0.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `y0f5_7nf.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1370:write:DEBUG] Found crop file '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/y0f5_7nf.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1383:write:DEBUG] Moving /home/em/.cache/maelzel/maelzel-tmpillwbv9u/y0f5_7nf.cropped.png to /home/em/.cache/maelzel/maelzel-tmpillwbv9u/_6l4qzdh.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 54 9
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 75 32
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 8192
# Chain([4C:3/2♩, 4A:2/3♩, 4G:2/3♩, 4F:4/3♩, 4F♯:1♩])

# %%
from maelzel.core import *
logger.parent.setLevel('DEBUG')

ch2 = Chain(r"""
4c:1/6
4a:4/3
""")
ch2
# Out:
# [maelzel.scoring.quant:quant.py:649:_splitStrongBeat:DEBUG] split strong: «~4A:1♩ properties={'.backwardTies': {0}}», offset: 1
# [maelzel.scoring.quant:quant.py:700:_splitWeakBeat:DEBUG] ------------ weak: «~4A:1♩ properties={'.backwardTies': {0}}», 1
# [maelzel.scoring.quant:quant.py:778:_splitWeakBeat:DEBUG] ------------ no need to split, assymmetry: 1.000, binary: True
# [maelzel.scoring.quant:quant.py:677:_splitStrongBeat:DEBUG] No need to split quarter note
# [maelzel.scoring:node.py:1094:_splitNotationAtBeat:DEBUG] Syncopation at meas=0, offset=1, callback <bound method QuantizedMeasure._splitStrongBeat of QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(3/2, dur=1/2 «4C:1/6♩ 1,3/2»
#                       «4A~:1/3♩ 1,3/2 properties={'.forwardTies': {0}}»)
#     «~4A:1♩ properties={'.backwardTies': {0}}»
#     «r:3/2♩»
#     «r:1♩»), profile=high)> negative, «~4A:1♩ properties={'.backwardTies': {0}}» will NOT be split
# [maelzel.scoring.quant:quant.py:649:_splitStrongBeat:DEBUG] split strong: «r:3/2♩», offset: 2
# [maelzel.scoring.quant:quant.py:700:_splitWeakBeat:DEBUG] ------------ weak: «r:3/2♩», 2
# [maelzel.scoring.quant:quant.py:719:_splitWeakBeat:DEBUG] No need to split since notation «r:3/2♩» is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring.quant:quant.py:685:_splitStrongBeat:DEBUG] dotted and not aligned, splitting
# [maelzel.scoring.quant:quant.py:862:_checkTree:DEBUG] Found superfluous tie (tied to a rest??): n0=«r:1/2♩», n1=«r:2♩»
# [maelzel.scoring:renderlily.py:1356:write:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/wzxjv4yp.ly' to '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/wzxjv4yp.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:317:renderLily:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/wzxjv4yp.ly' to '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/wzxjv4yp.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:346:renderLily:DEBUG] Calling lilypond subprocess, args=['/home/em/.local/share/lilyponddist/lilypond-2.25.31/bin/lilypond', '--png', '-o', '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/wzxjv4yp', '-dresolution=200', '/tmp/tmp83o0ku4b.ly']
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:392:renderLily:DEBUG] lilypond executed OK
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:398:renderLily:DEBUG] stderr:
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:399:renderLily:DEBUG]  Changing working directory to: `/home/em/.cache/maelzel/maelzel-tmpillwbv9u'
#  Processing `/tmp/tmp83o0ku4b.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `wzxjv4yp.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1370:write:DEBUG] Found crop file '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/wzxjv4yp.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1383:write:DEBUG] Moving /home/em/.cache/maelzel/maelzel-tmpillwbv9u/wzxjv4yp.cropped.png to /home/em/.cache/maelzel/maelzel-tmpillwbv9u/6un7w9ra.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 54 9
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 75 32
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4788
# Chain([4C:1/6♩, 4A:4/3♩])

# %%
from maelzel.core import *
logger.parent.setLevel('DEBUG')
cfg = getConfig()
cfg['quant.complexity'] = 'highest'

ch2 = Chain(r"""
4c:1/3*2/5
4d:1/3*2/5
4e:1/3*3/5
4f:4/7

""")
ch2
# Out:
# [maelzel.core:mobj.py:2300:clearImageCache:INFO] Resetting image cache
# [maelzel.scoring.quant:quant.py:649:_splitStrongBeat:DEBUG] split strong: «r:3/2♩», offset: 2
# [maelzel.scoring.quant:quant.py:700:_splitWeakBeat:DEBUG] ------------ weak: «r:3/2♩», 2
# [maelzel.scoring.quant:quant.py:719:_splitWeakBeat:DEBUG] No need to split since notation «r:3/2♩» is aligned to the beat, beatoffsets=[Fraction(0, 1), Fraction(1, 1), Fraction(2, 1), Fraction(3, 1)]
# [maelzel.scoring.quant:quant.py:685:_splitStrongBeat:DEBUG] dotted and not aligned, splitting
# [maelzel.scoring.quant:quant.py:862:_checkTree:DEBUG] Found superfluous tie (tied to a rest??): n0=«r:1/2♩», n1=«r:2♩»
# [maelzel.scoring:renderlily.py:1356:write:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/cx6d1m2m.ly' to '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/cx6d1m2m.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:317:renderLily:DEBUG] Rendering lilypond '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/cx6d1m2m.ly' to '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/cx6d1m2m.png'
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:346:renderLily:DEBUG] Calling lilypond subprocess, args=['/home/em/.local/share/lilyponddist/lilypond-2.25.31/bin/lilypond', '--png', '-o', '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/cx6d1m2m', '-dresolution=200', '/tmp/tmp8ry9aney.ly']
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:392:renderLily:DEBUG] lilypond executed OK
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:398:renderLily:DEBUG] stderr:
# [/home/em/dev/python/maelzel/maelzel/music/lilytools.py:lilytools.py:399:renderLily:DEBUG]  Changing working directory to: `/home/em/.cache/maelzel/maelzel-tmpillwbv9u'
#  Processing `/tmp/tmp8ry9aney.ly'
#  Parsing...
#  Interpreting music...
#  Preprocessing graphical objects...
#  Finding the ideal number of pages...
#  Fitting music on 1 page...
#  Drawing systems...
#  Converting to PNG...
#  Layout output to `cx6d1m2m.cropped.eps'...
#  Converting to PNG...
#  Success: compilation successfully completed
#
# [maelzel.scoring:renderlily.py:1370:write:DEBUG] Found crop file '/home/em/.cache/maelzel/maelzel-tmpillwbv9u/cx6d1m2m.cropped.png', using that as output
# [maelzel.scoring:renderlily.py:1383:write:DEBUG] Moving /home/em/.cache/maelzel/maelzel-tmpillwbv9u/cx6d1m2m.cropped.png to /home/em/.cache/maelzel/maelzel-tmpillwbv9u/cd6n8qr2.png
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'sRGB' 41 1
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 54 9
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 75 32
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 8192
# Chain([4C:2/15♩, 4D:2/15♩, 4E:1/5♩, 4F:4/7♩])
