# %%
from maelzel.core import *
import logging
logger = logging.getLogger("maelzel")
# logger.setLevel("DEBUG")
cfg = getConfig()
# cfg['quant.syncopMinFraction'] = 1/8

# %%
ch = Chain([
    "4C:1",
    "4D:2/3",
    "4E:2/3",
    "4F:2/3",
    "4G:1",
])
ch
# Out:
# Chain([4C:1♩, 4D:2/3♩, 4E:2/3♩, 4F:2/3♩, 4G:1♩])

# %%
from maelzel.core import *
# logger.parent.setLevel("DEBUG")

ch = Chain(r"""
r:0.5
4C:3
4C#:2
# 4d:0.5
""")
#ch.unquantizedScore().dump()
#ch.quantizedScore()
ch.show()

# %%
ch = Chain([
    "4C:1",
    "4G:1",
    "4D:2/3",
    "4E:2/3",
    "4F:2/3",
    
])
ch
# Out:
# Chain([4C:1♩, 4G:1♩, 4D:2/3♩, 4E:2/3♩, 4F:2/3♩])

# %%
from maelzel.core import *
ch = Chain([
    "4C:1",
    "4G:1+4/7",
    "4D:2/3",
    "4E:2/3",
    "4F:2/3",
    
])
ch
# Out:
# Chain([4C:1♩, 4G:11/7♩, 4D:2/3♩, 4E:2/3♩, 4F:2/3♩])

# %%
ch.play()
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Analog Stereo: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Analog Stereo:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=5)
#     Synth(‖ preset:sin=401.0002 start=.126 dur=1 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.515178 p20=1 p21=60 …)
#     Synth(‖ preset:sin=401.0003 start=1.126 dur=1.571 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=67 p19=0.515178 p20=1.57143 p21=67 …)
#     Synth(‖ preset:sin=401.0004 start=2.697 dur=.667 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=62 p19=0.515178 p20=0.666667 p21=62 …)
#     Synth(‖ preset:sin=401.0005 start=3.364 dur=.667 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=64 p19=0.515178 p20=0.666667 p21=64 …)
#     Synth(‖ preset:sin=401.0006 start=4.031 dur=.667 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=65 p19=0.515178 p20=0.666667 p21=65 …)

# %%
from maelzel.core import *

ch = Chain([
    "4D:2/5",
    "4E:2/5",
    "4F:1/5",
    Note("4E", F(2,5)*F(2,3)),
    Note("4F", F(2,5)*F(2,3)),
    Note("4F#", F(2,5)*F(2,3)),
    "4C:1",
    
    "4G:1",
])
# logger.parent.setLevel("DEBUG")
cfg = getConfig()
# cfg['quant.debug'] = True
cfg['quant.complexity'] = 'highest'
ch
# Out:
# Chain([4D:2/5♩, 4E:2/5♩, 4F:1/5♩, 4E:4/15♩, 4F:4/15♩, 4F♯:4/15♩, 4C:1♩, 4G:1♩])

# %%
# %timeit ch.quantizedScore()
# Out:
# 96.8 ms ± 732 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
from maelzel.core import *

ch = Chain([
    "4D:3/7",
    "4E:2/7",
    "4F:2/7",
    "4g:2/5*1/3",
    "4a:2/5*1/6",
    "4g:2/5*1/3",
    "4a:2/5*1/6",
    "4g:2/5*1/3",
    "4a:2/5*1/6",
    "4g:2/5*1/3",
    "4a:2/5*1/6",
    "4g:2/5*1/3",
    "4a:2/5*1/6",
    
    
])

cfg = getConfig()
cfg['quant.debug'] = True
#cfg['quant.complexity'] = 'high'
#cfg['quant.gridWeight'] = 2
# cfg['.quant.complexityWeight'] = 2
# cfg['.quant.divisionWeight'] = 0
ch
# Out:
# Possible divs: 4896, solutions: 4, best div: (7, 7), error: 0.02357, time: 224.96ms, cache info: 0/304
# Solutions in order of eval: [(3,), (4,), (7,), (7, 7)]
# Beat: 0 - 1 (dur: 1)
# <table>
# <thead>
# <tr><th style="text-align: right;">  error</th><th>div   </th><th>slots     </th><th>info                                                                                                                                                                     </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 0.0236</td><td>(7, 7)</td><td>[0, 6, 10]</td><td>gridError=0, rhythmComplexity=0.149 (numSyncop=1, numTies=0), divPenalty=0.0141 (0.0001414, divPenalty=0.0141, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# <tr><td style="text-align: right;"> 0.0471</td><td>(7,)  </td><td>[0, 3, 5] </td><td>gridError=0, rhythmComplexity=0.298 (numSyncop=2, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)       </td></tr>
# <tr><td style="text-align: right;"> 0.2099</td><td>(4,)  </td><td>[0, 2, 3] </td><td>gridError=0.21, rhythmComplexity=0 (numSyncop=0, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)        </td></tr>
# <tr><td style="text-align: right;"> 0.2605</td><td>(3,)  </td><td>[0, 1, 2] </td><td>gridError=0.26, rhythmComplexity=0 (numSyncop=0, numTies=0), divPenalty=0 (0, divPenalty=0, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)                   </td></tr>
# </tbody>
# </table>
# Possible divs: 4896, solutions: 19, best div: (3, 3, 3, 3, 3), error: 0.00299, time: 752.45ms, cache info: 0/5674
# Solutions in order of eval: [(9,), (11,), (3, 7), (3, 11), (4, 7), (4, 8), (4, 11), (5, 7), (5, 8), (5, 11), (6, 11), (7, 11), (8, 11), (11, 8), (11, 9), (11, 11), (3, 5, 5), (5, 5, 5), (3, 3, 3, 3, 3)]
# Beat: 1 - 2 (dur: 1)
# <table>
# <thead>
# <tr><th style="text-align: right;">  error</th><th>div            </th><th>slots                              </th><th>info                                                                                                                                                                             </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 0.0030</td><td>(3, 3, 3, 3, 3)</td><td>[0, 2, 3, 5, 6, 8, 9, 11, 12, 14]  </td><td>gridError=0, rhythmComplexity=0 (numSyncop=0, numTies=0), divPenalty=0.598 (0.005975, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0.03)             </td></tr>
# <tr><td style="text-align: right;"> 0.0071</td><td>(5, 5, 5)      </td><td>[0, 2, 3, 5, 6, 8, 9, 11, 12, 14]  </td><td>gridError=0, rhythmComplexity=0.0447 (numSyncop=1, numTies=0), divPenalty=0.0346 (0.0003464, divPenalty=0.0173, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0.03)    </td></tr>
# <tr><td style="text-align: right;"> 0.1215</td><td>(3, 5, 5)      </td><td>[0, 1, 2, 3, 4, 6, 7, 9, 10, 12]   </td><td>gridError=0.121, rhythmComplexity=0.0447 (numSyncop=1, numTies=0), divPenalty=0.0332 (0.0003317, divPenalty=0.0141, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0.03)</td></tr>
# <tr><td style="text-align: right;"> 0.2116</td><td>(11, 11)       </td><td>[0, 3, 4, 7, 9, 12, 13, 16, 18, 21]</td><td>gridError=0.211, rhythmComplexity=0.0447 (numSyncop=1, numTies=0), divPenalty=0.141 (0.001414, divPenalty=0.141, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)      </td></tr>
# <tr><td style="text-align: right;"> 0.2315</td><td>(11, 8)        </td><td>[0, 3, 4, 7, 9, 12, 13, 15, 16, 18]</td><td>gridError=0.229, rhythmComplexity=0.1 (numSyncop=1, numTies=1), divPenalty=0.1 (0.001005, divPenalty=0.1, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)             </td></tr>
# <tr><td style="text-align: right;"> 0.2324</td><td>(11, 9)        </td><td>[0, 3, 4, 7, 9, 12, 13, 15, 16, 19]</td><td>gridError=0.23, rhythmComplexity=0.1 (numSyncop=1, numTies=1), divPenalty=0.108 (0.001077, divPenalty=0.108, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)          </td></tr>
# <tr><td style="text-align: right;"> 0.2387</td><td>(8, 11)        </td><td>[0, 2, 3, 5, 6, 9, 10, 13, 15, 18] </td><td>gridError=0.237, rhythmComplexity=0.1 (numSyncop=1, numTies=1), divPenalty=0.1 (0.001005, divPenalty=0.1, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)             </td></tr>
# <tr><td style="text-align: right;"> 0.2458</td><td>(7, 11)        </td><td>[0, 2, 3, 5, 6, 8, 9, 12, 14, 17]  </td><td>gridError=0.244, rhythmComplexity=0.1 (numSyncop=1, numTies=1), divPenalty=0.1 (0.001005, divPenalty=0.1, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)           </td></tr>
# <tr><td style="text-align: right;"> 0.2545</td><td>(6, 11)        </td><td>[0, 2, 2, 4, 5, 7, 8, 11, 13, 16]  </td><td>gridError=0.252, rhythmComplexity=0.1 (numSyncop=1, numTies=1), divPenalty=0.1 (0.001005, divPenalty=0.1, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)             </td></tr>
# <tr><td style="text-align: right;"> 0.2595</td><td>(5, 11)        </td><td>[0, 1, 2, 3, 4, 6, 7, 10, 12, 15]  </td><td>gridError=0.259, rhythmComplexity=0.0447 (numSyncop=1, numTies=0), divPenalty=0.1 (0.001005, divPenalty=0.1, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)        </td></tr>
# <tr><td style="text-align: right;"> 0.2740</td><td>(5, 8)         </td><td>[0, 1, 2, 3, 4, 6, 7, 9, 10, 12]   </td><td>gridError=0.272, rhythmComplexity=0.1 (numSyncop=1, numTies=1), divPenalty=0.0141 (0.0001414, divPenalty=0.0141, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)      </td></tr>
# <tr><td style="text-align: right;"> 0.2868</td><td>(5, 7)         </td><td>[0, 1, 2, 3, 4, 5, 6, 8, 9, 11]    </td><td>gridError=0.287, rhythmComplexity=0 (numSyncop=0, numTies=0), divPenalty=0.0141 (0.0001414, divPenalty=0.0141, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)      </td></tr>
# <tr><td style="text-align: right;"> 0.2976</td><td>(4, 11)        </td><td>[0, 1, 2, 3, 3, 5, 6, 9, 11, 14]   </td><td>gridError=0.296, rhythmComplexity=0.1 (numSyncop=1, numTies=1), divPenalty=0.1 (0.001005, divPenalty=0.1, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)             </td></tr>
# <tr><td style="text-align: right;"> 0.3109</td><td>(4, 8)         </td><td>[0, 1, 2, 3, 3, 5, 6, 8, 9, 11]    </td><td>gridError=0.311, rhythmComplexity=0.0447 (numSyncop=1, numTies=0), divPenalty=0.0141 (0.0001414, divPenalty=0.0141, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)   </td></tr>
# <tr><td style="text-align: right;"> 0.3160</td><td>(4, 7)         </td><td>[0, 1, 2, 3, 3, 4, 5, 7, 8, 10]    </td><td>gridError=0.316, rhythmComplexity=0 (numSyncop=0, numTies=0), divPenalty=0.0141 (0.0001414, divPenalty=0.0141, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)        </td></tr>
# <tr><td style="text-align: right;"> 0.3262</td><td>(3, 11)        </td><td>[0, 1, 1, 2, 2, 4, 5, 8, 10, 13]   </td><td>gridError=0.326, rhythmComplexity=0.0447 (numSyncop=1, numTies=0), divPenalty=0.1 (0.001, divPenalty=0.1, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)             </td></tr>
# <tr><td style="text-align: right;"> 0.3377</td><td>(3, 7)         </td><td>[0, 1, 1, 2, 2, 3, 4, 6, 7, 9]     </td><td>gridError=0.338, rhythmComplexity=0 (numSyncop=0, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)               </td></tr>
# <tr><td style="text-align: right;"> 0.3683</td><td>(11,)          </td><td>[0, 1, 2, 4, 4, 6, 7, 8, 9, 10]    </td><td>gridError=0.367, rhythmComplexity=0.0894 (numSyncop=2, numTies=0), divPenalty=0.1 (0.001, divPenalty=0.1, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)             </td></tr>
# <tr><td style="text-align: right;"> 0.3946</td><td>(9,)           </td><td>[0, 1, 2, 3, 4, 5, 5, 7, 7, 8]     </td><td>gridError=0.394, rhythmComplexity=0.0447 (numSyncop=1, numTies=0), divPenalty=0.04 (0.0004, divPenalty=0.04, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)          </td></tr>
# </tbody>
# </table>
# Chain([4D:3/7♩, 4E:2/7♩, 4F:2/7♩, 4G:2/15♩, 4A:1/15♩, 4G:2/15♩, 4A:1/15♩, 4G:2/15♩, 4A:1/15♩, 4G:2/15♩, …])

# %%
from maelzel.core import *

ch = Chain("""
    4C:1
    4D:2/5; 4E:2/5; 4F:2/5; 4E:3/5; 4F:1/5
    4G:1
""")
ch
# Out:
# Possible divs: 4896, solutions: 4, best div: (5,), error: 0.02357, time: 29.05ms, cache info: 10/5770
# Solutions in order of eval: [(3,), (4,), (5,), (5, 5)]
# Beat: 1 - 2 (dur: 1)
# <table>
# <thead>
# <tr><th style="text-align: right;">  error</th><th>div   </th><th>slots    </th><th>info                                                                                                                                                                     </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 0.0236</td><td>(5,)  </td><td>[0, 2, 4]</td><td>gridError=0, rhythmComplexity=0.149 (numSyncop=1, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)       </td></tr>
# <tr><td style="text-align: right;"> 0.0236</td><td>(5, 5)</td><td>[0, 4, 8]</td><td>gridError=0, rhythmComplexity=0.149 (numSyncop=1, numTies=0), divPenalty=0.0141 (0.0001414, divPenalty=0.0141, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# <tr><td style="text-align: right;"> 0.3005</td><td>(4,)  </td><td>[0, 2, 3]</td><td>gridError=0.3, rhythmComplexity=0 (numSyncop=0, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)         </td></tr>
# <tr><td style="text-align: right;"> 0.3352</td><td>(3,)  </td><td>[0, 1, 2]</td><td>gridError=0.335, rhythmComplexity=0 (numSyncop=0, numTies=0), divPenalty=0 (0, divPenalty=0, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)                  </td></tr>
# </tbody>
# </table>
# Possible divs: 4896, solutions: 6, best div: (5,), error: 0.02357, time: 46.53ms, cache info: 17/5959
# Solutions in order of eval: [(3,), (4,), (5,), (5, 5), (5, 1, 5), (5, 1, 1, 5)]
# Beat: 2 - 3 (dur: 1)
# <table>
# <thead>
# <tr><th style="text-align: right;">  error</th><th>div         </th><th>slots    </th><th>info                                                                                                                                                                        </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 0.0236</td><td>(5,)        </td><td>[0, 1, 4]</td><td>gridError=0, rhythmComplexity=0.149 (numSyncop=1, numTies=0), divPenalty=0.0001 (1e-06, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)         </td></tr>
# <tr><td style="text-align: right;"> 0.0236</td><td>(5, 5)      </td><td>[0, 2, 8]</td><td>gridError=0, rhythmComplexity=0.149 (numSyncop=1, numTies=0), divPenalty=0.0141 (0.0001414, divPenalty=0.0141, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)   </td></tr>
# <tr><td style="text-align: right;"> 0.0236</td><td>(5, 1, 1, 5)</td><td>[0, 4, 8]</td><td>gridError=0, rhythmComplexity=0.149 (numSyncop=1, numTies=0), divPenalty=0.0241 (0.0002414, divPenalty=0.0241, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)   </td></tr>
# <tr><td style="text-align: right;"> 0.0236</td><td>(5, 1, 5)   </td><td>[0, 3, 8]</td><td>gridError=0, rhythmComplexity=0.149 (numSyncop=1, numTies=0), divPenalty=0.0332 (0.0003317, divPenalty=0.0141, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0.03)</td></tr>
# <tr><td style="text-align: right;"> 0.2266</td><td>(4,)        </td><td>[0, 1, 3]</td><td>gridError=0.222, rhythmComplexity=0.149 (numSyncop=1, numTies=0), divPenalty=0.01 (0.0001, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)      </td></tr>
# <tr><td style="text-align: right;"> 0.4626</td><td>(3,)        </td><td>[0, 1, 2]</td><td>gridError=0.463, rhythmComplexity=0 (numSyncop=0, numTies=0), divPenalty=0 (0, divPenalty=0, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)                     </td></tr>
# </tbody>
# </table>
# Chain([4C:1♩, 4D:2/5♩, 4E:2/5♩, 4F:2/5♩, 4E:3/5♩, 4F:1/5♩, 4G:1♩])

# %%
from maelzel.core import *
ch = Chain([
    Note("4C", F(1, 5)),
    *(Note("4D", F(1,5)*F(2,7)) for _ in range(5))
])
cfg = getConfig()
cfg['.quant.debug'] = True
cfg['quant.complexity'] = 'highest'
cfg['quant.gridWeight'] = 8
ch
# ch.show(complexity='highest')
# Out:
# Possible divs: 6611, solutions: 16, best div: (1, 7, 7, 1, 1), error: 0.00234, time: 55.01ms, cache info: 267/5569
# Solutions in order of eval: [(6,), (8,), (9,), (11,), (13,), (15,), (8, 1), (5, 17, 1), (13, 7, 1), (13, 11, 1), (13, 17, 1), (17, 11, 1), (5, 17, 1, 1), (1, 7, 6, 1, 1), (1, 7, 7, 1, 1), (1, 5, 5, 5, 1, 1, 1)]
# Beat: 0 - 1 (dur: 1)
# <table>
# <thead>
# <tr><th style="text-align: right;">  error</th><th>div                  </th><th>slots                      </th><th>info                                                                                                                                                                           </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 0.0023</td><td>(1, 7, 7, 1, 1)      </td><td>[0, 1, 3, 5, 7, 9, 11]     </td><td>gridError=0, rhythmComplexity=0.128 (numSyncop=2, numTies=0), divPenalty=0.0789 (0.002495, divPenalty=0.0241, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)     </td></tr>
# <tr><td style="text-align: right;"> 0.0036</td><td>(1, 5, 5, 5, 1, 1, 1)</td><td>[0, 3, 5, 7, 9, 11, 13]    </td><td>gridError=0, rhythmComplexity=0.192 (numSyncop=3, numTies=0), divPenalty=0.16 (0.005072, divPenalty=0.0273, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)       </td></tr>
# <tr><td style="text-align: right;"> 0.1668</td><td>(1, 7, 6, 1, 1)      </td><td>[0, 1, 3, 5, 7, 9, 11]     </td><td>gridError=0.0588, rhythmComplexity=0.181 (numSyncop=2, numTies=1), divPenalty=0.0438 (0.001386, divPenalty=0.0241, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)</td></tr>
# <tr><td style="text-align: right;"> 0.1842</td><td>(5, 17, 1, 1)        </td><td>[0, 4, 5, 9, 13, 17, 21]   </td><td>gridError=0.0641, rhythmComplexity=0.0639 (numSyncop=1, numTies=0), divPenalty=1 (0.03162, divPenalty=1.01, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)       </td></tr>
# <tr><td style="text-align: right;"> 0.1973</td><td>(17, 11, 1)          </td><td>[0, 10, 13, 16, 18, 20, 22]</td><td>gridError=0.0685, rhythmComplexity=0.286 (numSyncop=2, numTies=2), divPenalty=1 (0.03162, divPenalty=1, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)           </td></tr>
# <tr><td style="text-align: right;"> 0.2082</td><td>(13, 17, 1)          </td><td>[0, 8, 10, 12, 15, 18, 21] </td><td>gridError=0.0726, rhythmComplexity=0.181 (numSyncop=2, numTies=1), divPenalty=1 (0.03162, divPenalty=1.02, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)        </td></tr>
# <tr><td style="text-align: right;"> 0.2293</td><td>(13, 11, 1)          </td><td>[0, 8, 10, 12, 14, 16, 18] </td><td>gridError=0.0809, rhythmComplexity=0.181 (numSyncop=2, numTies=1), divPenalty=0.224 (0.007072, divPenalty=0.224, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)  </td></tr>
# <tr><td style="text-align: right;"> 0.2890</td><td>(13, 7, 1)           </td><td>[0, 8, 10, 12, 14, 15, 16] </td><td>gridError=0.102, rhythmComplexity=0.181 (numSyncop=2, numTies=1), divPenalty=0.2 (0.006333, divPenalty=0.2, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)       </td></tr>
# <tr><td style="text-align: right;"> 0.2994</td><td>(5, 17, 1)           </td><td>[0, 3, 4, 5, 7, 10, 13]    </td><td>gridError=0.105, rhythmComplexity=0.0639 (numSyncop=1, numTies=0), divPenalty=1 (0.03162, divPenalty=1, cardinalityPenalty=0.1, numSubdivsPenalty=0, levelPenalty=0)           </td></tr>
# <tr><td style="text-align: right;"> 0.3354</td><td>(8, 1)               </td><td>[0, 3, 4, 5, 6, 7, 8]      </td><td>gridError=0.119, rhythmComplexity=0 (numSyncop=0, numTies=0), divPenalty=0.01 (0.0003162, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)          </td></tr>
# <tr><td style="text-align: right;"> 0.5204</td><td>(15,)                </td><td>[0, 3, 4, 5, 6, 6, 7]      </td><td>gridError=0.184, rhythmComplexity=0.0639 (numSyncop=1, numTies=0), divPenalty=0.1 (0.003162, divPenalty=0.1, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)        </td></tr>
# <tr><td style="text-align: right;"> 0.6291</td><td>(13,)                </td><td>[0, 3, 3, 4, 5, 6, 6]      </td><td>gridError=0.222, rhythmComplexity=0.0639 (numSyncop=1, numTies=0), divPenalty=0.2 (0.006325, divPenalty=0.2, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)        </td></tr>
# <tr><td style="text-align: right;"> 0.7064</td><td>(11,)                </td><td>[0, 2, 3, 3, 4, 5, 5]      </td><td>gridError=0.25, rhythmComplexity=0.0639 (numSyncop=1, numTies=0), divPenalty=0.1 (0.003162, divPenalty=0.1, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)         </td></tr>
# <tr><td style="text-align: right;"> 0.8026</td><td>(9,)                 </td><td>[0, 2, 2, 3, 3, 4, 4]      </td><td>gridError=0.284, rhythmComplexity=0.143 (numSyncop=1, numTies=1), divPenalty=0.04 (0.001265, divPenalty=0.04, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)       </td></tr>
# <tr><td style="text-align: right;"> 0.8390</td><td>(8,)                 </td><td>[0, 2, 2, 3, 3, 3, 4]      </td><td>gridError=0.297, rhythmComplexity=0 (numSyncop=0, numTies=0), divPenalty=0.01 (0.0003162, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)          </td></tr>
# <tr><td style="text-align: right;"> 0.9908</td><td>(6,)                 </td><td>[0, 1, 2, 2, 2, 3, 3]      </td><td>gridError=0.35, rhythmComplexity=0.0639 (numSyncop=1, numTies=0), divPenalty=0.01 (0.0003162, divPenalty=0.01, cardinalityPenalty=0, numSubdivsPenalty=0, levelPenalty=0)      </td></tr>
# </tbody>
# </table>
# Chain([4C:1/5♩, 4D:~1/18♩, 4D:~1/18♩, 4D:~1/18♩, 4D:~1/18♩, 4D:~1/18♩])
