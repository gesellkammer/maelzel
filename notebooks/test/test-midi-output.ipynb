# %%
from maelzel.core import *

# %%
ch = Voice(r'''
4D:0.5
4Ab:1/8
4G:3/4
4D:1/4
4A:1/2
4F:1/4
4D:1/2
4Gb:1/2
4Bb:3/4

''', name='foo')
ch
# Out:
# Voice([4D:1/2♩, 4G♯:1/8♩, 4G:3/4♩, 4D:1/4♩, 4A:1/2♩, 4F:1/4♩, 4D:1/2♩, 4F♯:1/2♩, 4A♯:3/4♩])

# %%
ch.write("~/tmp/test.mid")

# %%
v1 = Voice(r'''
4D:1/4
4Ab:1/4
4G+:1/4
4D:1/4
4A:1/4
4F-:1/4
4D:1/4
4Gb:1/4
4Bb:1/4

''', name='v1')

v2 = v1.quantizePitch(1).transpose(3)
v2
sco = Score([v1, v2])
sco
# Out:
# Score(2 voices)

# %%
sco.write("~/tmp/test2.mid")
