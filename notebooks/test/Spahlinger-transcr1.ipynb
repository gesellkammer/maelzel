# %%
from maelzel.core import *
w = getWorkspace()

# %%
cfg = w.config
cfg['quant.complexity'] = 'highest'
cfg['show.measureLabelStyle'] = 'fontsize=10'

# %% [markdown]
# ## 320

# %%
struct = ScoreStruct("""
2/4+5/16,q=123, label=320
""")

v1 = Voice("""r:0.5; 7f#:0; 6F:1/2; r:9/16""")
v2 = Voice([
    Rest(1*F(6, 7)), Note("4G#", F(1,2)*F(6,7)), "5g:0", "4F:0", "r:3/2"])
sco = Score([v1, v2], scorestruct=struct)
sco
# Out:
# Score(2 voices)

# %%
struct = ScoreStruct("""
7/16(4+3)+6/16,q=123, label=320
""")

v1 = Voice("""r:0.5; 7f#:0; 6F:1/2; r:9/16""")
v2 = Voice([
    Rest(1*F(6, 7)), Note("4G#", F(1,2)*F(6,7)), "5g:0", "4F:0", "r:3/2"])
sco = Score([v1, v2], scorestruct=struct)
sco
# Out:
# Score(2 voices)

# %%
sco.play(sustain=0.2)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=5)
#     Synth(‖ preset:.piano=401.0017 start=28.943 dur=.235 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=102 p21=0.515178 p22=0.0348432 p23=102 …)
#     Synth(‖ preset:.piano=401.0018 start=28.978 dur=.444 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=89 p21=0.515178 p22=0.243902 p23=89 …)
#     Synth(‖ preset:.piano=401.0019 start=29.152 dur=.339 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=68 p21=0.515178 p22=0.139373 p23=68 …)
# ...

# %%
sco = ScoreStruct("6/4, q=168")
v1 = Voice([Rest(1*F(6, 7)), Note("5C", 1)])
sco = Score([v1], scorestruct=sco)
sco
# Out:
# Score(1 voices)

# %%
sco = ScoreStruct("6/8, q=168")
v1 = Voice([Rest(F(1,2)*F(6, 7)), Note("4Eb", F(1,2)*F(6,7))])
v2 = Voice("C7:0.5; C7:0.5; C7:0.5; C7:0.5; C7:0.5; C7:0.5")
sco = Score([v1, v2], scorestruct=sco)
sco
# Out:
# Score(2 voices)

# %%
sco.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=7)
#     Synth(‖ preset:.piano=401.0037 start=25.367 dur=.153 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=63 p21=0.515178 p22=0.153061 p23=63 …)
#     Synth(‖ preset:.piano=401.0038 start=25.214 dur=.179 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=96 p21=0.515178 p22=0.178571 p23=96 …)
#     Synth(‖ preset:.piano=401.0039 start=25.393 dur=.179 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=96 p21=0.515178 p22=0.178571 p23=96 …)
# ...
