# %% [markdown]
# # Die Seefahrer
#
# von Joaquin

# %%
from maelzel.core import *

# %%
m1 = Chain([
    "4E/8",
    "4E/8",
    "4E/8",
    "4F/8",
    "4A/8",
    "4A/8",
    "4A/8",
    "4F/4",
    "5E/8",
    "5D/8",
    "5C/8",
    
    "4A/8",
    "4G/8",
    "4A/8",
    "4B/8",
    "4E/8",
    "4E/8",
    "4D/8",
    "4E/8",
    "4D/8",
    "4E/8",
    
    "4F/8",
    "4F/8",
    "4F/4",
    "4F/4",
    "5D/8",
    "5C/8",
    "4A/8",
    "4G/8",
    "4B/8",
    "5D/8",
    "5C/8",
    
    "4A/8",
    "4G/8",
    "4F/8",
    "4D/8",
    Rest(1),
    "4E/8",
    "4A/8",
    "4B/8",
    "4A/8",
    "5D/8",
    "5D/8",
    
    
        
])
m1
m2 = m1.timeShift(0.5).transpose(-10).timeScale(1.25)
m3 = m1.timeShift(1).transpose(4).timeScale(1.5)
# sc = Score([m3, m2, m1])
sc = Score([m1, m2, m3])
sc
# Out:
# Score(3 voices)

# %%
w = getWorkspace()
w.setScoreStruct(tempo=40)

# %%
sc.play(instr='.sing', sustain=0.15, fade=(0.1, 0.2))
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=126)
#     Synth(‖ preset:.sing=401.0128 start=47.262 dur=.9 kpos=0.5 kgain=1 idataidx_=21 inumbps=3 ibplen=3 ichan=1 ifadein=0.1 ifadeout=0.2 ipchintrp_=0 ifadekind=1 kx=0 ky=0 kvibrange=0.25 kvibfreq=4.5 ivibstart=0.5 ipitchlag=0.2 p21=0 p22=64 p23=0.515178 …)
#     Synth(‖ preset:.sing=401.0129 start=48.012 dur=.9 kpos=0.5 kgain=1 idataidx_=21 inumbps=3 ibplen=3 ichan=1 ifadein=0.1 ifadeout=0.2 ipchintrp_=0 ifadekind=1 kx=0 ky=0 kvibrange=0.25 kvibfreq=4.5 ivibstart=0.5 ipitchlag=0.2 p21=0 p22=64 p23=0.515178 …)
#     Synth(‖ preset:.sing=401.013 start=48.762 dur=.9 kpos=0.5 kgain=1 idataidx_=21 inumbps=3 ibplen=3 ichan=1 ifadein=0.1 ifadeout=0.2 ipchintrp_=0 ifadekind=1 kx=0 ky=0 kvibrange=0.25 kvibfreq=4.5 ivibstart=0.5 ipitchlag=0.2 p21=0 p22=64 p23=0.515178 …)
# ...

# %%
presetManager.definedPresets()
# Out:
# ['simplesin',
#  'sin',
#  'tri',
#  'saw',
#  'sqr',
#  'pulse',
#  '.click',
#  '.bandnoise',
#  '.sing',
#  '.piano']

# %%
presetManager.getPreset(".sing")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Preset: .sing  (Simple vowel singing simulation)
#     routing=True
#   init: gi__formantFreqs__[] fillarray \
#                 668, 1191, 2428, 3321, 4600, \  ; A
#                 327, 2157, 2754, 3630, 4600, \  ; E
#                 208, 2152, 3128, 3425, 4200, \  ; I
#                 335, 628, 2689, 3515, 4200, \   ; O
#                 254, 796, 2515, 3274, 4160      ; U
#
#             gi__formantDbs__[] fillarray   \
#                 28, 28, 22, 20, 20, \
#                 15, 25, 24, 20, 23, \
#                 10, 20, 27, 26, 20, \
#                 15, 18, 5,  7,  12, \
#                 12, 10, 6,  5,  12
#
#             gi__formantBws__[] fillarray   \
#                 80, 90, 120, 130, 140, \
#                 60, 100, 120, 150, 200, \
#                 60, 90, 100, 120, 120, \
#                 40, 80, 100, 120, 120, \
# ...
