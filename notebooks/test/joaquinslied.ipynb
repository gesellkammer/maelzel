# %% [markdown]
# # Die Seefahrer
#
# von Joaquin

# %%
from maelzel.core import *

# %%
m1 = Chain([
    "4E/8",
    "4E/8",
    "4E/8",
    "4F/8",
    "4A/8",
    "4A/8",
    "4A/8",
    "4F/4",
    "5E/8",
    "5D/8",
    "5C/8",
    
    "4A/8",
    "4G/8",
    "4A/8",
    "4B/8",
    "4E/8",
    "4E/8",
    "4D/8",
    "4E/8",
    "4D/8",
    "4E/8",
    
    "4F/8",
    "4F/8",
    "4F/4",
    "4F/4",
    "5D/8",
    "5C/8",
    "4A/8",
    "4G/8",
    "4B/8",
    "5D/8",
    "5C/8",
    
    "4A/8",
    "4G/8",
    "4F/8",
    "4D/8",
    Rest(1),
    "4E/8",
    "4A/8",
    "4B/8",
    "4A/8",
    "5D/8",
    "5D/8",
    
    
        
])
m1
m2 = m1.timeShift(1).transpose(-12).timeScale(1.)
m3 = m1.timeShift(1).transpose(4).timeScale(1.5)
# sc = Score([m3, m2, m1])
sc = Score([m1, m2, m3])
sc
# Out:
# Score(3 voices)

# %%
setScoreStruct(tempo=50)

# %%
sc.play(instr='gm-oboe', sustain=0.1, fade=0)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=126)
#     Synth(𝍪 preset:gm-oboe=501.0632 start=233.284 dur=0.700 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0 ifadein=0 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64 p18=0.515178 p19=0.6 …)
#     Synth(𝍪 preset:gm-oboe=501.0633 start=233.884 dur=0.700 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0 ifadein=0 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64 p18=0.515178 p19=0.6 …)
#     Synth(𝍪 preset:gm-oboe=501.0634 start=234.484 dur=0.700 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0 ifadein=0 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=64 p18=0.515178 p19=0.6 …)
#     Synth(𝍪 preset:gm-oboe=501.0635 start=235.084 dur=0.700 p4=0.5 kpos=1 kgain=17 idataidx_=3 inumbps=3 ibplen=1 ichan=0 ifadein=0 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=65 p18=0.515178 p19=0.6 …)
# ...

# %%
presetManager.definedPresets()
# Out:
# ['simplesin',
#  'sin',
#  'tri',
#  'saw',
#  'sqr',
#  'pulse',
#  '.sing',
#  'gm-piano',
#  'gm-clarinet',
#  'gm-oboe',
#  'gm-flute',
#  'gm-violin',
#  'gm-reedorgan',
#  '.piano',
#  'accordion',
#  'sing',
#  'piano']
