# %%
from maelzel.core import *

struct1 = ScoreStruct("4/4, q=60")
struct2 = ScoreStruct("3/4, q=60")

v1 = Voice([Note(i, 0.5) for i in range(60, 72)], scorestruct=struct1)
v2 = Voice([Note(i, 0.5) for i in range(60, 72)], scorestruct=struct2)

sco = Score([v1, v2])

# %%
sco
# Out:
# scorestruct=ScoreStruct(4/4, tempo=60)
# scorestruct=ScoreStruct(3/4, tempo=60)
# Score(2 voices)

# %%
sco.play()
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Analog Stereo: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Analog Stereo:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=24)
#     Synth(‖ preset:.piano=401.0002 start=.163 dur=.5 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=60 p21=0.515178 p22=0.5 p23=60 …)
#     Synth(‖ preset:.piano=401.0003 start=.663 dur=.5 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=61 p21=0.515178 p22=0.5 p23=61 …)
# ...

# %%
from maelzel.core import *

struct1 = ScoreStruct("2/4, q=120")
struct2 = ScoreStruct("3/8, q=120")

v1 = Voice([Note(i, 0.5) for i in range(60, 72)], scorestruct=struct1)
v2 = Voice([Note(i, 0.5) for i in range(48, 60)], scorestruct=struct2)

for i in range(v1.numMeasures()):
    n = v1.eventAt((i, 0))
    v1.replaceEvent(n, Chord([n, n + 12], dur=n.dur))

for i in range(v2.numMeasures()):
    n = v2.eventAt((i, 0))
    if n is not None:
        v2.replaceEvent(n, Chord([n, n - 12], dur=n.dur))

    
sco = Score([v1, v2])
sco
# Out:
# scorestruct=ScoreStruct(2/4, tempo=120)
# scorestruct=ScoreStruct(3/8, tempo=120)
# Score(2 voices)

# %%
sco[0].synthEvents()
# Out:
# [SynthEvent(delay=0, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 60 -5.8; 0.25 60 -5.8｣),
#  SynthEvent(delay=0, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 72 -5.8; 0.25 72 -5.8｣),
#  SynthEvent(delay=0.25, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 61 -5.8; 0.25 61 -5.8｣),
#  SynthEvent(delay=0.5, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 62 -5.8; 0.25 62 -5.8｣),
#  SynthEvent(delay=0.75, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 63 -5.8; 0.25 63 -5.8｣),
#  SynthEvent(delay=1, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 64 -5.8; 0.25 64 -5.8｣),
#  SynthEvent(delay=1, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 76 -5.8; 0.25 76 -5.8｣),
# ...

# %%
sco.synthEvents()
# Out:
# [SynthEvent(delay=0, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 60 -5.8; 0.25 60 -5.8｣),
#  SynthEvent(delay=0, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 72 -5.8; 0.25 72 -5.8｣),
#  SynthEvent(delay=0.25, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 61 -5.8; 0.25 61 -5.8｣),
#  SynthEvent(delay=0.5, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 62 -5.8; 0.25 62 -5.8｣),
#  SynthEvent(delay=0.75, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 63 -5.8; 0.25 63 -5.8｣),
#  SynthEvent(delay=1, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 64 -5.8; 0.25 64 -5.8｣),
#  SynthEvent(delay=1, dur=0.25, instr=.piano, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 76 -5.8; 0.25 76 -5.8｣),
# ...

# %%
sco.play(sustain=0.15, kwet=0.85)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=31)
#     Synth(‖ preset:.piano=401.0126 start=39.566 dur=.4 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=60 p21=0.515178 p22=0.25 p23=60 …)
#     Synth(‖ preset:.piano=401.0127 start=39.566 dur=.4 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=72 p21=0.515178 p22=0.25 p23=72 …)
#     Synth(‖ preset:.piano=401.0128 start=39.816 dur=.4 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=61 p21=0.515178 p22=0.25 p23=61 …)
# ...

# %%
from maelzel.core import *

struct1 = ScoreStruct("2/4, q=60")
struct2 = ScoreStruct("3/8, q=60")

v1 = Voice([Note(i, 0.5) for i in range(60, 72)], scorestruct=struct1)
v2 = Voice([Note(i, 0.5) for i in range(48, 60)], scorestruct=struct2)

for i in range(v1.numMeasures()):
    n = v1.eventAt((i, 0))
    v1.replaceEvent(n, Chord([n, n + 12], dur=n.dur))

for i in range(v2.numMeasures()):
    n = v2.eventAt((i, 0))
    if n is not None:
        v2.replaceEvent(n, Chord([n, n - 12], dur=n.dur))

    
sco2 = Score([v1, v2])
sco2
# Out:
# scorestruct=ScoreStruct(2/4, tempo=60)
# scorestruct=ScoreStruct(3/8, tempo=60)
# Score(2 voices)

# %%
sco2.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=31)
#     Synth(‖ preset:.piano=401.0157 start=69.315 dur=.5 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=60 p21=0.515178 p22=0.5 p23=60 …)
#     Synth(‖ preset:.piano=401.0158 start=69.315 dur=.5 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=72 p21=0.515178 p22=0.5 p23=72 …)
#     Synth(‖ preset:.piano=401.0159 start=69.815 dur=.5 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=61 p21=0.515178 p22=0.5 p23=61 …)
# ...
