# %%
from maelzel.core import *
config = getConfig()

# %%
config['.enharmonic.debug'] = True
config['enharmonic.verticalWeight'] = 0.5

# %%
Chain([
    Note("4Eb+13!", 1),
    Note("4D#+13!", 1),
    Chord("4E+!,4F#", 1),
    "4C+,4Db!:1",
    Note("4F+55", 0.5)
])
# Out:
# Single notation, «4Gb-45 0:0.5 1/2♩», fixed to ('4Gb-45',)
# Chain([4Eb+13:1♩, 4D#+13:1♩, ‹4E+ 4F# 1♩›, ‹4C+ 4Db 1♩›, 4Gb-45:0.5♩])

# %%
Chain("""
    4F#
    4F+25
    4Gb-
""")
# Out:
# Spelling: 4Gb 4F> 4Gb-, penalty= 1.077, intervalPenalty=0, groupPenalty=1.16, chordPenalty=0
# Spelling: 4Gb 4F> 4F+, penalty= 1.225, intervalPenalty=1.5, groupPenalty=0, chordPenalty=0
# Spelling: 4F# 4F> 4Gb-, penalty= 3.284, intervalPenalty=1.5, groupPenalty=9.283, chordPenalty=0
# Spelling: 4F# 4F> 4F+, penalty= 3.611, intervalPenalty=6, groupPenalty=7.038, chordPenalty=0
# DEBUG: Enharmonic spelling - orig. ['4F#', '4F>', '4F+'], horizontal solution=['4Gb', '4F>', '4Gb-']
# Chain([4F#:1♩, 4F>:1♩, 4F+:1♩])

# %%
Chain("""
    4C+/8
    4C#!/8
    4D,4F#/8
    4F#/8
    4F+25/8
    4Gb-/8
""")
# Out:
# Spelling: 4C+ 4C# 4F# 4F# 4F> 4F+, penalty= 2.798, intervalPenalty=0.7927, groupPenalty=7.038, chordPenalty=0
# Spelling: 4C+ 4C# 4Gb 4Gb 4F> 4Gb-, penalty= 2.82, intervalPenalty=5.29, groupPenalty=1.16, chordPenalty=1.5
# Spelling: 4C+ 4C# 4Gb 4Gb 4F> 4F+, penalty= 2.871, intervalPenalty=6.743, groupPenalty=0, chordPenalty=1.5
# Spelling: 4C+ 4C# 4F# 4F# 4F> 4Gb-, penalty= 3.104, intervalPenalty=0.3523, groupPenalty=9.283, chordPenalty=0
# DEBUG: Enharmonic spelling - orig. ['4C+', '4C#', '4F#', '4F#', '4F>', '4F+'], horizontal solution=['4C+', '4C#', '4F#', '4F#', '4F>', '4F+']
# DEBUG: Enharmonic spelling - chord «[4D 4F#] 1:1.5 1/2♩» - previous slots state:
#        C+
#        chords fixed slots: C+
# DEBUG: Enharmonic spelling - chord «[4D 4F#] 1:1.5 1/2♩» - solution: ('4D', '4F#')
#        fixed slots: C+, F#
#        variants: [('4D', '4F#')]
# Chain([4C+:0.5♩, 4C#:0.5♩, ‹4D 4F# 0.5♩›, 4F#:0.5♩, 4F>:0.5♩, 4F+:0.5♩])

# %%
Chain("""
    4C+/8
    4C#/8
    4D,4F#/8
    4F#/8
    4F+25/8
    # 4Gb-/8
    
""")
# Out:
# Spelling: 4C+ 4C# 4F# 4F# 4F>, penalty= 0.6757, intervalPenalty=0.4566, groupPenalty=0, chordPenalty=0
# Spelling: 4C+ 4Db 4Gb 4Gb 4F>, penalty= 1.291, intervalPenalty=0, groupPenalty=0, chordPenalty=1.667
# Spelling: 4C+ 4Db 4F# 4F# 4F>, penalty= 1.52, intervalPenalty=2.312, groupPenalty=0, chordPenalty=0
# Spelling: 4C+ 4C# 4Gb 4Gb 4F>, penalty= 2.919, intervalPenalty=6.856, groupPenalty=0, chordPenalty=1.667
# Spelling: 4Db- 4Db 4Gb 4Gb 4F>, penalty= 3.046, intervalPenalty=0.1141, groupPenalty=7.5, chordPenalty=1.667
# Spelling: 4Db- 4Db 4F# 4F# 4F>, penalty= 3.31, intervalPenalty=3.453, groupPenalty=7.5, chordPenalty=0
# DEBUG: Enharmonic spelling - orig. ['4C+', '4C#', '4F#', '4F#', '4F>'], horizontal solution=['4C+', '4C#', '4F#', '4F#', '4F>']
# DEBUG: Enharmonic spelling - chord «[4D 4F#] 1:1.5 1/2♩» - previous slots state:
#        C+, C#
#        chords fixed slots: C+, C#
# DEBUG: Enharmonic spelling - chord «[4D 4F#] 1:1.5 1/2♩» - solution: ('4D', '4F#')
# ...

# %%
Chain("""
    4C+/8
    4Db!/8
    4D,4F#/8
    4F#/8
    4F+25/8
    # 4Gb-/8
    
""")
# Out:
# Spelling: 4C+ 4Db 4Gb 4Gb 4F>, penalty= 1.225, intervalPenalty=0, groupPenalty=0, chordPenalty=1.5
# Spelling: 4C+ 4Db 4F# 4F# 4F>, penalty= 1.691, intervalPenalty=2.859, groupPenalty=0, chordPenalty=0
# Spelling: 4Db- 4Db 4Gb 4Gb 4F>, penalty= 2.764, intervalPenalty=0.1412, groupPenalty=6, chordPenalty=1.5
# Spelling: 4Db- 4Db 4F# 4F# 4F>, penalty= 3.205, intervalPenalty=4.271, groupPenalty=6, chordPenalty=0
# DEBUG: Enharmonic spelling - orig. ['4C+', '4Db', '4F#', '4F#', '4F>'], horizontal solution=['4C+', '4Db', '4Gb', '4Gb', '4F>']
# DEBUG: Enharmonic spelling - chord «[4D 4Gb] 1:1.5 1/2♩» - previous slots state:
#        C+
#        chords fixed slots: C+
# DEBUG: Enharmonic spelling - chord «[4D 4Gb] 1:1.5 1/2♩» - solution: ('4D', '4Gb')
#        fixed slots: C+, Gb
#        variants: [('4D', '4Gb')]
# Chain([4C+:0.5♩, 4Db:0.5♩, ‹4D 4F# 0.5♩›, 4F#:0.5♩, 4F>:0.5♩])
