# %%
from maelzel.core import *

# %%
# Test play fade

# %%
n = Note("4A", 4)
n.play(instr='sin', fade=(0.1, 0.5))
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset.sin:502.0002, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=-1 ifadein:11=0.1 ifadeout:12=0.5 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=69 p19=0.515178 p20=4 ...)

# %%
click = Chain([Note(80, dur=0.25, offset=i) for i in range(10)])
click
# Out:
# Chain([5G#:0.25♩:offset=0, 5G#:0.25♩:offset=1, 5G#:0.25♩:offset=2, 5G#:0.25♩:offset=3, 5G#:0.25♩:offset=4, 5G#:0.25♩:offset=5, 5G#:0.25♩:offset=6, 5G#:0.25♩:offset=7, 5G#:0.25♩:offset=8, 5G#:0.25♩:offset=9, …])

# %%
click.play(instr='sin', gain=0.1, fade=(0, 0))
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=10)
#     Synth(𝍪 preset.sin:502.0013, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=0.1 ichan:9=1 ipos:10=-1 ifadein:11=0 ifadeout:12=0 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=80 p19=0.515178 p20=0.25 ...)
#     Synth(𝍪 preset.sin:502.0014, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=0.1 ichan:9=1 ipos:10=-1 ifadein:11=0 ifadeout:12=0 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=80 p19=0.515178 p20=0.25 ...)
#     Synth(𝍪 preset.sin:502.0015, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=0.1 ichan:9=1 ipos:10=-1 ifadein:11=0 ifadeout:12=0 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=80 p19=0.515178 p20=0.25 ...)
# ...

# %%
v0 = Voice([click])
v1 = Voice([n])

v0.setPlay(position=0)
v1.setPlay(position=1)

s = Score([v0, v1])
s.play(instr='sin')
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=11)
#     Synth(𝍪 preset.sin:502.0023, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=0 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=80 p19=0.515178 p20=0.25 ...)
#     Synth(𝍪 preset.sin:502.0024, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=0 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=80 p19=0.515178 p20=0.25 ...)
#     Synth(𝍪 preset.sin:502.0025, p4=0 idataidx_:5=17 inumbps:6=2 ibplen:7=3 igain:8=1 ichan:9=1 ipos:10=0 ifadein:11=0.02 ifadeout:12=0.02 ipchintrp_:13=0 ifadekind:14=1 ktransp:15=0 klag:16=0.1 p17=0 p18=80 p19=0.515178 p20=0.25 ...)
# ...

# %%
a = render()
print(a)

# %%
with render() as r:
    print(r)
    # s.play(instr='saw', gain=0.2)
# r
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_333645/388321297.py in <module>
# ----> 1 with render() as r:
#       2     print(r)
#       3     # s.play(instr='saw', gain=0.2)
#       4 # r
#
# AttributeError: __enter__

# %%
with playback.OfflineRenderer() as r:
# Out:
# OfflineRenderer(sr=44100)

# %%
! sonic-visualiser $r.outfile
# Out:
# SV loading template file :/templates/Waveform and Melodic Range Spectrogram.svt
# MainWindowBase::openSessionTemplate(file::/templates/Waveform and Melodic Range Spectrogram.svt)
# Document::releaseModel(<none>)
# Document::releaseModel(<none>)
#
# Adding model #1 to playsource
# m_writeBuffers size = 0
# target channel count = 2
# ResamplerWrapper: Initial source rate 0 and channels 2
# ResamplerWrapper::reconstructResampler: Creating resampler with initial source rate 44100, buffer size 10240, channel count 2
# AudioCallbackPlaySource: Source sample rate changed to 44100, updating resampler wrapper
# ResamplerWrapper: Source rate changing from 0 to 44100
# ResamplerWrapper::changeApplicationSampleRate: Note: Source rate is equal to target rate, won't be resampling
# MainWindowBase::audioChannelCountIncreased
# createAudioIO: Preferred implementation = ""
# createAudioIO: Preferred playback device = ""
# createAudioIO: Preferred record device = ""
# Document::releaseModel(<none>)
# ...
