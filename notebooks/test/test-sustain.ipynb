# %%
from maelzel.core import *

# %%
n = Note(60, 1)
n.play(sustain=1)
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Analog Stereo: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Analog Stereo:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(‖ preset:sin=401.0002 start=.126 dur=2 kpos=0.5 kgain=1 idataidx_=17 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.515178 p20=1 p21=60 …)

# %%
ch = Chain([
    "4C:1/2",
    "4D:1/2"
])
ch.synthEvents(sustain=2)
# Out:
# [SynthEvent(delay=0, dur=0.5, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), sustain=2, position=0.5, bps=‹0.0s 60 0.515178; 0.5s 60 0.515178›),
#  SynthEvent(delay=0.5, dur=0.5, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), sustain=2, position=0.5, bps=‹0.0s 62 0.515178; 0.5s 62 0.515178›)]

# %%
ch.play(sustain=2)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=2)
#     Synth(‖ preset:sin=401.0003 start=5.673 dur=2.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.515178 p20=0.5 p21=60 …)
#     Synth(‖ preset:sin=401.0004 start=6.173 dur=2.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=62 p19=0.515178 p20=0.5 p21=62 …)

# %%
ch = Chain([
    "4C:1/2:gliss",
    "4D:1/2"
])
ch.play(sustain=2)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(‖ preset:sin=401.0005 start=9.651 dur=3 kpos=0.5 kgain=1 idataidx_=17 inumbps=4 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.515178 p20=0.5 p21=62 …)

# %%
from maelzel.core import *

ch = Chord("4C,4G:1")
print(ch.synthEvents(sustain=0.68))
gr = ch.play(sustain=0.68)
gr
# Out:
# [SynthEvent(delay=0, dur=1, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), sustain=0.68, position=0.5, bps=‹0.0s 60 0.364286; 1.0s 60 0.364286›), SynthEvent(delay=0, dur=1, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), sustain=0.68, position=0.5, bps=‹0.0s 67 0.364286; 1.0s 67 0.364286›)]
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=2)
#     Synth(‖ preset:sin=401.0006 start=13.811 dur=1.68 kpos=0.5 kgain=1 idataidx_=17 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.364286 p20=1 p21=60 …)
#     Synth(‖ preset:sin=401.0007 start=13.811 dur=1.68 kpos=0.5 kgain=1 idataidx_=17 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=67 p19=0.364286 p20=1 p21=67 …)

# %%
Note("4C:1").play(sustain=0.5)[0]
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# Synth(‖ preset:sin=401.0008 start=17.459 dur=1.5 kpos=0.5 kgain=1 idataidx_=17 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.515178 p20=1 p21=60 …)

# %%
gr = Chord("4C,4G", 1).play(gain=0.82, fade=(0.3, 0.4))
gr
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=2)
#     Synth(‖ preset:sin=401.0009 start=20.606 dur=1 kpos=0.5 kgain=0.82 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.3 ifadeout=0.4 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60 p19=0.364286 p20=1 p21=60 …)
#     Synth(‖ preset:sin=401.001 start=20.606 dur=1 kpos=0.5 kgain=0.82 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.3 ifadeout=0.4 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=67 p19=0.364286 p20=1 p21=67 …)
