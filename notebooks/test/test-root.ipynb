# %%
from maelzel.core import *
# Out:
# end of score.		   overall amps:      0.0
# 	   overall samples out of range:        0
# 0 errors in performance

# %%
v = Voice([
    "4C:1",
    Chain("4D 4E 4F")
])
v
# Out:
# Voice([4C:1♩, Chain([4D:1♩, 4E:1♩, 4F:1♩])])

# %%
s = Score([v])

# %%
s[0][1][0].parent
# Out:
# Chain([4D:1♩, 4E:1♩, 4F:1♩])

# %%
v2 = v.copy()

# %%
v2.parent is None
# Out:
# True

# %%
v2.root() is v2
# Out:
# True

# %%
s[0].firstEvent().root()
# Out:
# Score(1 voices)

# %%
s[0][1][0].root()
# Out:
# Score(1 voices)

# %%
Note(60).root() is None
# Out:
# True
