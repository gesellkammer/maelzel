# %%
from maelzel.core import *

# %%
w = ws()

# %%
w.config.edit()
# Out:
# **Notify** Config Edit: maelzel:core: Modify the values as needed. Save the file to accept the changes or press ctrl-c at the python prompt to cancel (path: /tmp/tmpd8f4zjdq.yaml)
# **Notify** Edit: Editing finished, any further modifications will have no effect

# %%
w.config['play.instr']
# Out:
# '.piano'

# %%
w.config.save()

# %%
config = w.config

# %%
c = config.makeDynamicCurve()
c
# Out:
# DynamicCurve(shape=expon(0.3), mindb=-60.0, maxdb=0.0)

# %%
c is config.makeDynamicCurve()
# Out:
# True

# %%
config['dynamicCurveShape'] = 'expon(0.4)'
