# %%
from maelzel.core import *
cfg = getConfig()

# %%
cfg['show.measureLabelStyle'] = 'fontsize=9'
cfg['quant.complexity'] = 'medium'

# %%
struct = ScoreStruct("""
5/16+4/16, q=168, ticks=(5/4, 1)
4/16+5/16, ticks=1 5/4
3/16+2/4, ticks=3/4 1 1
7/16
7/16
6/16
2/4
3/16+4/16
2/4
5/8(2+3), ticks=1 3/2
3/8, label="11", ticks=3/4 3/4
3/16+4/16, ticks=3/4 1
4/16+3/16, ticks=1 3/4
2/4
4/16+3/16, ticks=1 3/4
4/16+7/32, ticks=1 7/8
5/16+4/16, ticks=5/4 1
4/16+5/16, ticks=1 5/4
4/16+5/16, ticks=1 5/4
2/4
20?, 2/4
.
.
2/4+3/8, ticks=1 1 3/2
3/16+4/16, ticks=3/4 1
4/16+6/16, ticks=1 3/2
5/16+4/16, ticks=5/4 1
2/4
.
4/8, ticks=1 1 
.
.
5/16+5/16, ticks=5/4 5/4
4/8, q=210, ticks=1 1, label="Schneller, etwas beiläufig"
4/8, ticks=1 1
3/8, ticks=3/2
4/8, ticks=1 1
.
38?, 3/16+4/16, q=168, label="a tempo"
5/16, ticks=5/4
2/4
3/8+5/16, ticks=(3/2 5/4)
1/4
3/8+1/4, ticks=(3/2 1)
2/4
.
3/8, ticks=3/2
2/4
.
49?, 2/4
.
3/8+3/8+3/8, ticks=3/2 3/2 3/2
5/16+4/16, ticks=5/4 1
7/16
2/4
3/8, ticks=3/2
4/16+5/16, ticks=1 5/4, label="Orig: 3/8+3/16"
2/4
7/16, label="59"
4/16+5/16, ticks=1 5/4
7/16
9/8, ticks=3/2 3/2 3/2
5/16, ticks=5/4
2/4
6/16, q=144, ticks=1/4 1/4 1/4 1/4! 1/4 1/4    # 14/32(3+4+3+4), ticks=7/8 7/8 # 7/32+7/32(3-4-3-4), ticks=7/8 7/8
3/8+1/4, q=168, ticks=3/2 1
4/4, label="67"
3/8+3/8+3/16, ticks=3/2 3/2 3/4
2/4
4/4
3/4
5/8(2+3), ticks=1 3/2
7/8, ticks=3/2 1 1
5/8(2+3), ticks=1 3/2
5/8(3+2), ticks=3/2 1
4/16+5/16, ticks=1 5/4
5/8(3+2), ticks=3/2 1
3/4
3/8, ticks=3/2
5/16, ticks=5/4
3/4
7/16
2/4
.
.
85?, 5/16+5/16, ticks=5/4 5/4
2/4
7/8(3+2+2), ticks=3/2 1 1
5/8(3+2), ticks=3/2 1
7/16(3+4), ticks=3/4 1
9/8(2+2+3+2), ticks=1 1 3/2 1
2/4
9/8(2+2+3+2), ticks=1 1 3/2 1
5/4
5/16, ticks=5/4
3/16
1/4, ticks=1
6/8(3+3), ticks=3/2 3/2
98?, 5/16, ticks=5/4
5/16, ticks=5/4, label="100"
5/16, ticks=5/4
5/16, ticks=5/4
9/8(3+3+3), ticks=3/2 3/2 3/2
9/8(3+3+3), ticks=3/2 3/2 3/2
5/16, ticks=5/4
2/4
.
.
.
.
2/4+3/16, ticks=1 1 3/4, label=111
3/16+2/4, ticks=3/4 1 1
5/8(2+3), ticks=1 3/2
5/16+3/8, ticks=5/4 3/2
6/8(3+3), ticks=3/2 3/2
4/16+5/16+3/8, ticks=1 5/4 3/2
116?, 15/16(2+3+2+3+2+3), ticks=5/4 5/4 5/4
117?, 5/8(2+3), ticks=1 3/2
.
.
5/16+3/16+3/16, ticks=5/4 3/4 3/4
4/16+3/16+3/16, ticks=1 3/4 3/4
6/16+5/16, ticks=3/2 5/4
123?, 5/8(2+3), ticks=1 3/2
2/4
125?, 4/4
5/16, ticks=5/4
5/16+6/16, ticks=5/4 3/2
4/16+5/16+5/16, ticks=1 5/4 5/4
1/4+5/32, ticks=1 5/8
5/16+5/16, ticks=5/4 5/4
5/8(3+2), ticks=3/2 1
132?, 3/16+2/4, q=120, ticks=3/4 1 1, label="Deutlich langsamer"
3/16, ticks=3/4
134?, 2/8, q=144, ticks=1
5/16(2+3), ticks=1/2 3/4
.
3/32+3/16, ticks=3/8 3/4
2/8, ticks=1/2 1/2
139?, 5/16+3/8, q=168, ticks=5/4 3/2, label="a tempo"
3/8+5/16, ticks=3/2 5/4
3/4, label="Orig: 7/32+5/32"
142?, 2/4
2/4
3/8, ticks=3/2
5/16+3/8, ticks=5/4 3/2
11/16(3+3+3+2), ticks=3/2 5/4
3/4+3/8, ticks=1 1 1 1/2! 1/2 1/2
4/4
149?, 5/16+4/16, ticks=5/4 1
2/4
7/8(3+2+2), ticks=3/2 1 1, label="Repeat"
3/8, ticks=3/2
.
7/8(3+2+2), ticks=3/2 1 1, label="ff sub"
.
.
157?, 7/8(3+2+2), ticks=3/2 1 1
.
.
.
161?, 3/4
162?, 7/8(3+2+2), ticks=3/2 1 1
.
4/4
5/8(3+2), ticks=3/2 1, label="2/4??"
7/8(3+2+2), ticks=3/2 1 1
.
168?, 2/4
169?, 5/8(3+2), ticks=3/2 1
9/8(3+3+3)+3/16, ticks=3/2 3/2 3/2 3/4
5/8(2+3), ticks=1 1 1/2
3/16+4/16+5/16, ticks=3/4 1 5/4
2/4
7/16, ticks=1 3/4
5/16+2/4+5/16+5/16+3/8, ticks=5/4 1 1 5/4 5/4 3/2
176?, 1/4+7/16, ticks=1 3/4! 1/2 1/2
5/16+4/16+3/16, ticks=5/4 1 3/4
5/8, ticks=1 3/2
179?, 5/16+7/16+5/16, ticks=5/4 7/4 5/4
4/4
.
7/8(2+3+2), ticks=1 3/2 1
4/4
3/4
3/8, ticks=3/2
5/8(2+3), ticks=1 3/2
4/4
7/8(2+3+2), ticks=1 3/2 1
189?, 5/16+4/16, ticks=5/4 1
190?, 4/16+5/16+5/16+6/16+5/16, ticks=1 5/4 5/4 3/2 5/4
9/8(3+3+3)+3/16, ticks=3/2 3/2 3/2 3/4
5/16+6/16+4/16, ticks=5/4 3/2 1
2/4
194?, 2/4
.
.
.
.
.
200?, 12/8(3+3+3+3), q.=112, ticks=3/2 3/2 3/2 3/2, label="molto ritardando"
3/4, q=81, ticks=1 1 1
2/4, q=56, ticks=1 1
2/8, 8=88, ticks=1/2 1/2
204?, 7/8, 2..=78, ticks=3/2 2
.
206?, 7/8, 2..=69, ticks=3/2 2
.
.
209?, 7/8, 2..=58, ticks=3/2 1 1
.
.
q=168, ticks=3/2 1 1
213?, 1/4+7/32, ticks=1 7/8
4/8, q=134, ticks=1/2 1/2 1/2 1/2, label="2x5/16"
5/16, q=168, ticks=1/2 3/4
3/16+2/4+5/16, ticks=3/4 1 1 5/4, label="*** 3:2 unterteilen??"  # <--------------
3/4, label="5+3+4=4+4+4"
11/32+1/4, ticks=11/8 1, label="~5/8(3+2)"
10/8(3+3+2+2), ticks=3/2 3/2 1 1
220?, 5/8(3+2), ticks=3/2 1
2/4
5/8(2+3), ticks=1 3/2
2/4
5/8(3+2), ticks=3/2 1
2/4
5/8(2+3), ticks=1 3/2
.
3/8, ticks=3/2
229?, 10/8(3+2+2+3), ticks=3/2 1 1 3/2
10/8(3+2+2+3), ticks=3/2 1 1 3/2
3/8+3/4, ticks=3/2 1 1 1
9/8(3+3+3), ticks=3/2 3/2 3/2
233?, 5/8+5/8, ticks=1 3/2 1! 3/2
.
.
.
.
5/8+2/4, ticks=1 3/2 1! 1
239?, 5/8+5/8, ticks=1 3/2 1! 3/2
.
.
.
.
.
245?, 5/8+5/8+5/8, ticks=1 3/2 1! 3/2 1! 3/2
5/8+5/8, ticks=1 3/2 1 3/2
(2+2+3)/8, ticks=1 1 3/2
(3+2+2)/8, ticks=3/2 1 1
249?, 7/8, ticks=3/2 1 1, label="249!"
13/16, ticks=1 1 5/4, label="249b"
17/16, ticks=1 1 1 5/4, label="249c"
7/8, ticks=1 1 3/2
11/16, ticks=1 3/4 1
254?, 6/8, ticks=3/2 3/2, label="250"
4/4
(2+2+3)/8, ticks=1 1 3/2
4/16+3/16+6/16, ticks=1 3/4 3/2
4/16+5/16+5/16, ticks=1 5/4 5/4
(2+2+3)/8, ticks=1 1 3/2
.
4/4
5/8(2+3), ticks=1 3/2
.
.
265?, 2/4
5/8(2+3), ticks=1 3/2
(2+2+3)/8, ticks=1 1 3/2
(2+3)/8, ticks=1 3/2
2/4
(2+2+3)/8, ticks=1 1 3/2
(3+3+3+3+3+3)/16, 8=230, ticks=3/4 3/4 3/4 3/4 3/4 3/4  # 269 * 6 / 7
272?, 6/4, q=168
(2+3+2)/8, ticks=1 3/2 1
1/4+9/32, ticks=1 9/8
9/8, ticks=3/2 3/2 3/2
(2+2+3)/8, ticks=1 1 3/2
6/8, ticks=3/2 3/2
3/8, ticks=3/2
5/16(2+3)+5/16(3+2), ticks=5/4 5/4
6/8, ticks=3/2 3/2
281?, 9/8, ticks=3/2 3/2 3/2
3/8+5/16+5/16, ticks=3/2 5/4 5/4
3/16+4/16+3/16+4/16, ticks=3/4 1 3/4 1
6/8, ticks=3/2 3/2, label="*"
9/16(3+3+3)+1/4, ticks=3/4 3/4 3/4 1
5/8, ticks=1 3/2
5/16+2/4, ticks=5/4 1 1
288?, 4/4
(3+2+2)/8, ticks=3/2 1 1
5/8, ticks=1 3/2
291?, 4/4
.
.
3/4+3/8, ticks=1 1 1 3/2
295?, 2/4+3/8, ticks=1 1 3/2
.
.
.
299?, 5/16+4/16+5/16+5/16, ticks=5/4 1 5/4 5/4
300?, 4/4
.
.
.
.
.
.
307?, 6/4
.
.
.
311?, 4/4
.
6/4
2/4
4/4
2/4
317?, 4/4
8/4
(2+3+2)/16, ticks=1/2 3/4 1/2
(3+2+3+2)/16, ticks=3/4 1/2 3/4 1/2
2/4+3/8, ticks=1 1 3/2
.
323?, (2+2+3)/8, q=143, ticks=1 1 3/2
324?, 2/4+5/16, q=123, ticks=1 1 5/4
7/8, ticks=1 1 3/2
3/8+3/8+2/4, q=164, ticks=3/2 3/2 1 1
7/32+5/8(2+3), q=103, ticks=7/8 1 1/2! 1/2 1/2
328?, 3/4, q=86.5, label=324
7/32+3/4, q=106, ticks=7/8 1 1 1
1/4+3/16+2/4, q=99.5, ticks=1 3/4 1 1
1/4+3/16+3/4, q=108.75, ticks=1 3/4 1 1 1 
3/4+5/16, q=87.25, ticks=1 1 1 5/4, label="(5+7+5)/16"
3/8+1/4+5/16+1/4, q=87.5, ticks=1/2 1/2 1/2 1! 5/4 1
5/4, q=84.5
11/32(4+3+4)+4/4, q=83, ticks=1/2 3/8 1/2 1! 1 1 1
1/4+3/8+3/4, q=78, ticks=1 3/4! 3/4 1! 1 1
5/16(2+3)+3/4, q=55, ticks=1/2 3/4 1! 1 1, barline=final
""")
struct
# Out:
# ScoreStruct([5/16+4/16@168, 4/16+5/16, 3/16+2/4, 7/16, 7/16, 6/16, 2/4, 3/16+4/16, 2/4, 5/8 …])

# %%
track = struct.clickTrack(strongPitch="6C", weakPitch="6G", compoundPitch="6E")

# %%
track.show()

# %%
qs = track.quantizedScore()

# %%
ratios = [F(1), F(4, 5), F(3, 5), F(2, 5), F(1, 5)]
for r in ratios:
    qs2 = qs.tempoTransform(factor=r)
    qs2.write(f"/home/em/proj/spahlinger-click/click-{r.numerator}:{r.denominator}.mid")

# %%
qs.write("/home/em/proj/spahlinger-click/click-1.mid")

# %%
qs2 = qs.tempoTransform(factor=F(4, 5))
qs2.write("/home/em/proj/spahlinger-click/click-0.8.mid")

# %%
qs3 = qs.tempoTransform(factor=F(3, 5))
qs3.write("/home/em/proj/spahlinger-click/click-0.6.mid")

# %%
qs4 = qs.tempoTransform(factor=F(2, 5))
qs4.write("/home/em/proj/spahlinger-click/click-0.4.mid")

# %%
w = getWorkspace()
w.config['quant.complexity'] = 'highest'
# %prun qsco = track.quantizedScore()
# Out:
#          1065335 function calls (1049562 primitive calls) in 1.526 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.096    0.096    0.096    0.096 {built-in method _pickle.load}
#      2967    0.074    0.000    0.409    0.000 quant.py:1124(quantizeBeatBinary)
#         1    0.058    0.058    0.154    0.154 _util.py:54(loadPickle)
#      7712    0.055    0.000    0.085    0.000 quantutils.py:1019(divisionFitsPerfectly)
# 156452/156448    0.051    0.000    0.052    0.000 {built-in method builtins.isinstance}
#       328    0.050    0.000    0.133    0.000 __init__.py:1749(enharmonic_variations)
#     19066    0.042    0.000    0.085    0.000 {built-in method builtins.all}
# 22830/21429    0.040    0.000    0.078    0.000 {built-in method builtins.sum}
#      7239    0.037    0.000    0.099    0.000 notation.py:101(__init__)
# ...

# %%
click = struct.clickTrack(strongPitch="6C", weakPitch="6G", compoundPitch="6E")
click.show()

# %%
click.play()
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 512 sample-frame blocks
# reading 4096-byte blks of shorts from adc:ALC257 Analog: (RAW)
# writing 1024 sample blks of 64-bit floats to dac:ALC257 Analog:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=934)
#     Synth(▶ preset:.click=401.0002 start=.158 dur=.446 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0003 start=.604 dur=.357 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0004 start=.962 dur=.357 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0005 start=1.319 dur=.446 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
# ...

# %%
click.write("~/tmp/spahl-orig.mid")

# %%
click2 = click.tempoTransform(0.5)
click2.play()
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=33)
#     Synth(‖ preset:.click=401.0035 start=13.385 dur=.893 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0036 start=14.278 dur=.714 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0037 start=14.992 dur=.714 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0038 start=15.706 dur=.357 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0039 start=16.063 dur=.536 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.004 start=16.599 dur=.536 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0041 start=17.135 dur=.714 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
# ...

# %%
click2.activeScorestruct

# %%
click2.scorestruct = click2.scorestruct.tempoTransform(0.5)
click2.setScoreStruct(click2.scorestruct().tempoTransform(0.5))
# Out:
# ScoreStruct([5/16+4/16@84, 4/16+5/16, 3/16+4/16+4/16, 7/16, 7/16, 6/16, 2/4, 3/16+4/16, 2/4, 4/16+6/16 …])

# %%
click2.setScoreStruct(s3)
click2
# Out:
# Score(1 voices)

# %%
click2.play()
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 512 sample-frame blocks
# reading 4096-byte blks of shorts from adc:ALC257 Analog: (RAW)
# writing 1024 sample blks of 64-bit floats to dac:ALC257 Analog:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=33)
#     Synth(‖ preset:.click=401.0002 start=.211 dur=.893 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0003 start=1.104 dur=.714 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0004 start=1.818 dur=.714 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
#     Synth(‖ preset:.click=401.0005 start=2.533 dur=.357 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0 …)
# ...

# %%
struct.write("~/tmp/timesig.ly")
# Out:
# ***************** Compound timesig: 5/16+4/16
# ***************** Compound timesig: 5/16+3/8

# %%
struct.makeClickTrack()
# Out:
# Score(1 voices)

# %%
m0 = struct[0]

# %%
m0.timesig
# Out:
# TimeSignature(5+4/16)

# %%
m0.timesig.parts
# Out:
# ((5, 16), (4, 16))

# %%
m0.subdivisionStructure()
# Out:
# (16, (2, 3, 2, 2))

# %%
m0.subdivisions()
# Out:
# [Fraction(1, 2), Fraction(3, 4), Fraction(1, 2), Fraction(1, 2)]

# %%
print(struct.render().render())
# Out:
# \version "2.25.31"
#
# \header {
#   tagline = ##f
# }
# #(set-global-staff-size 12.0)
# #(set-default-paper-size "a4" 'portrait)
# \paper {
#   left-margin = 4\mm
#   right-margin = 4\mm
#   top-margin = 4\mm
#   bottom-margin = 4\mm
# }
#
# glissandoSkipOn = {
#   \override NoteColumn.glissando-skip = ##t
#   \override Voice.NoteHead.transparent = ##t
#   \override NoteHead.no-ledgers = ##t
#   \omit Accidental
# }
#
# glissandoSkipOff = {
#   \revert NoteColumn.glissando-skip
#   \revert Voice.NoteHead.transparent
#   \revert NoteHead.no-ledgers
#   \undo \omit Accidental
# }
#
# beamBreak =  \tweak stencil ##f \breathe
#
# % adapted from http://lsr.di.unimi.it/LSR/Item?id=784
#
# % Define the alterations as fraction of the equal-tempered whole tone.
# #(define-public SEVEN-E-SHARP  7/8)
# #(define-public SHARP-RAISE    5/8)
# #(define-public SHARP-LOWER    3/8)
# #(define-public NATURAL-RAISE  1/8)
# #(define-public NATURAL-LOWER -1/8)
# #(define-public FLAT-RAISE    -3/8)
# ...
