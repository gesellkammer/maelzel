# %%
import csoundengine as ce

# %%
e = ce.Engine()
# Out:
# --Csound version 6.19 (double samples) Jan 13 2024
# [commit: c53556fbbb69d14554a4a4bd91efa441a1701d70]
# libsndfile-1.2.0
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Pro: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Pro:
# SECTION 1:

# %%
e.testAudio()
# Out:
# Testaudio: pink noise mode
# Channel: 1 / 2
# 25.0002
# Channel: 2 / 2
# Channel: 1 / 2
# Channel: 2 / 2

# %%
s = ce.Session(engine=e, dynamicArgsSlots=20000, dynamicArgsPerInstr=8)

# %%
s.defInstr('foo0', r'''
|imidi=60, iamp=0.1|
outch 1, oscili:a(iamp, mtof:k(imidi))
''')
# Out:
# Instr(foo0, imidi:5=60, iamp:6=0.1)

# %%
sy = s.sched('foo0', imidi=61, iamp=0.2)
sy
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# Synth(▶ foo0=501.0002 start=3.662 dur=-1.000 p4=61 imidi=0.2)

# %%
s.defInstr('foo', r'''
|kmidi=60, kamp=0.1|
outch 1, vco2:a(kamp, mtof:k(kmidi))
''')
# Out:
# Instr(foo, kmidi:5=60, kamp:6=0.1)

# %%
for j in range(10):
    for i in range(100):
        sy = s.sched('foo', dur=0.01, kmidi=36+i*0.1, delay=j*0.5, kamp=0.01)

# %%
s.engine.extraLatency = 0.2
J = 10
N = 80
delayfact = .5
    
with s.engine.lockedClock(): 
    for j in range(J):
        for i in range(N): 
            sy = s.sched('foo', dur=0.01, kmidi=24+i*0.25, delay=j*delayfact, kamp=0.6/N)

# %%
with s.rendering(verbose=False) as r:
    for j in range(J):
        for i in range(N):
            sy = r.sched('foo', dur=0.005, kmidi=48+i*0.1, delay=j*delayfact, kamp=0.01)
r
# Out:
# <strong>Renderer</strong>(sr=<code style="color:#9090FF">44100</code>, renderedJobs=<code style="color:#9090FF">[RenderJob(outfile='/tmp/tmpfrrxm8br.wav', samplerate=44100, encoding='', starttime=0.0, endtime=4.505, process=<Popen: returncode: 0 args: ['/usr/local/bin/csound', '-o', '/tmp/tmpfrrxm8b...>)]</code>)<br><b>Soundfile</b>: '/tmp/tmpfrrxm8br.wav', duration: <code>4.5</code>, sr: <code>44100</code>, numchannels: <code>2</code>)<br>
#         <img style="display:inline; padding:10px;
# margin-top:14px;
# width:1923.0"
#              src="data:image/png;base64,..."/><br>
#                 <audio controls style="width: 100%; max-width: 1200px;" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
s.defInstr('ifoo', r'''
|imidi=60, iamp=0.1|
outch 1, oscili:a(iamp, mtof(imidi))
''')
# Out:
# Instr(ifoo, imidi:5=60, iamp:6=0.1)

# %%
s.engine.extraLatency = 0.5
with s.engine.lockedClock():
    for j in range(10):
        for i in range(80):
            sy = s.sched('ifoo', dur=0.01, imidi=36+i*0.1, delay=j*0.5, iamp=0.01)

# %%
with s.rendering(verbose=False) as r:
    for j in range(10):
        for i in range(80):
            sy = s.sched('ifoo', dur=0.005, imidi=36+i*0.1, delay=j*0.5, iamp=0.01)
r
# Out:
# <strong>Renderer</strong>(sr=<code style="color:#9090FF">44100</code>, renderedJobs=<code style="color:#9090FF">[RenderJob(outfile='/tmp/tmp16b4m68d.wav', samplerate=44100, encoding='', starttime=0.0, endtime=4.505, process=<Popen: returncode: 0 args: ['/usr/local/bin/csound', '-o', '/tmp/tmp16b4m68...>)]</code>)<br><b>Soundfile</b>: '/tmp/tmp16b4m68d.wav', duration: <code>4.5</code>, sr: <code>44100</code>, numchannels: <code>2</code>)<br>
#         <img style="display:inline; padding:10px;
# margin-top:14px;
# width:1911.0"
#              src="data:image/png;base64,..."/><br>
#                 <audio controls style="width: 100%; max-width: 1200px;" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
r.renderedJobs[-1].openOutfile()
# Out:
# QSocketNotifier: Can only be used with threads started with QThread
# Gtk-Message: 19:20:11.201: Failed to load module "appmenu-gtk-module"
# QSocketNotifier: Can only be used with threads started with QThread
