# %%
from maelzel.core import *
logger.parent.setLevel("DEBUG")

# %%
ch = Chain(r"""
r:2/8
4C:1/8
r:1/8
r:1/8
r:1/8
r:1/8
r:1/8

""")
ch
# Out:
# [maelzel.scoring:quant.py:1528:quantizeMeasure:DEBUG] Measure 4/4 is not filled (events=[«rest 0:0.25 1/4♩», «4C 0.25:0.375 1/8♩», «rest 0.375:0.5 1/8♩», «rest 0.5:0.625 1/8♩», «rest 0.625:0.75 1/8♩», «rest 0.75:0.875 1/8♩», «rest 0.875:1 1/8♩»]). Filling gaps with silences
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(1, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(2, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(3, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:2134:resolveEnharmonics:DEBUG] Resolving enharmonics for measure 0
# [maelzel.scoring:renderlily.py:1181:write:DEBUG] Rendering lilypond '/home/em/.cache/tmpjykuki6a/qrdypo5h.ly' to '/home/em/.cache/tmpjykuki6a/qrdypo5h.png'
# ...

# %%
tr = ch.quantizedScore()[0].measures[0].tree
# Out:
# [maelzel.scoring:quant.py:1528:quantizeMeasure:DEBUG] Measure 4/4 is not filled (events=[«rest 0:0.25 1/4♩», «4C 0.25:0.375 1/8♩», «rest 0.375:0.5 1/8♩», «rest 0.5:0.625 1/8♩», «rest 0.625:0.75 1/8♩», «rest 0.75:0.875 1/8♩», «rest 0.875:1 1/8♩»]). Filling gaps with silences
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(1, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(2, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(3, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:2134:resolveEnharmonics:DEBUG] Resolving enharmonics for measure 0

# %%
with ScoreStruct((5, 4)):
    ch = Chain(r"""
    r:1
    r:1/5
    4C:6/5
    """)
    ch.show()
# Out:
# [maelzel.scoring:quant.py:1528:quantizeMeasure:DEBUG] Measure 5/4 is not filled (events=[«rest 0:1 1♩», «rest 1:1.2 1/5♩», «4C 1.2:2.4 6/5♩»]). Filling gaps with silences
# [maelzel.scoring:quant.py:1883:_mergeSiblings:DEBUG] Nodes cannot merge (Joining these nodes would result in a syncopation across a beat with a weight of 1, but the current quantization profile sets a min. level of 1):
# Node(5/4, dur=1 «rest 1:1.2 1/5♩ 5/4»
#                 «4C~ 1.2:2 4/5♩ 5/4»)
# Node(5/4, dur=1 «~4C 2:2.4 2/5♩ 5/4»
#                 «rest 2.4:3 3/5♩ 5/4»)
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(1, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(2, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(3, 1), beat.duration=Fraction(1, 1), minWeight=1
# ...

# %%
tr = ch.quantizedScore()[0].measures[0].tree
print(tr)
tr.items[1].symbolicDuration()
# Out:
# [maelzel.scoring:quant.py:1528:quantizeMeasure:DEBUG] Measure 4/4 is not filled (events=[«rest 0:1 1♩», «rest 1:1.2 1/5♩», «4C 1.2:2.4 6/5♩»]). Filling gaps with silences
# [maelzel.scoring:quant.py:1883:_mergeSiblings:DEBUG] Nodes cannot merge (Joining these nodes would result in a syncopation across a beat with a weight of 1, but the current quantization profile sets a min. level of 1):
# Node(5/4, dur=1 «rest 1:1.2 1/5♩ 5/4»
#                 «4C~ 1.2:2 4/5♩ 5/4»)
# Node(5/4, dur=1 «~4C 2:2.4 2/5♩ 5/4»
#                 «rest 2.4:3 3/5♩ 5/4»)
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(1, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(2, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(3, 1), beat.duration=Fraction(1, 1), minWeight=1
# ...

# %%
sc = ScoreStruct((7, 4))
m0 = sc.getMeasureDef(0)
m0.beatStructure()
# Out:
# [BeatDef(offset=Fraction(0, 1), duration=Fraction(1, 1), weight=1),
#  BeatDef(offset=Fraction(1, 1), duration=Fraction(1, 1), weight=0),
#  BeatDef(offset=Fraction(2, 1), duration=Fraction(1, 1), weight=1),
#  BeatDef(offset=Fraction(3, 1), duration=Fraction(1, 1), weight=0),
#  BeatDef(offset=Fraction(4, 1), duration=Fraction(1, 1), weight=1),
#  BeatDef(offset=Fraction(5, 1), duration=Fraction(1, 1), weight=0),
#  BeatDef(offset=Fraction(6, 1), duration=Fraction(1, 1), weight=0)]

# %%
with sc:
    ch = Chain(r"""
    r:1/4
    4C#<:1/2*2/3
    4D-:1/2
    """)
    ch.show()
# Out:
# [maelzel.scoring:quant.py:1528:quantizeMeasure:DEBUG] Measure 7/4 is not filled (events=[«rest 0:0.25 1/4♩», «4Db< 0.25:0.583 1/3♩», «4D- 0.583:1.083 1/2♩»]). Filling gaps with silences
# [maelzel.scoring:quant.py:1749:_nodesCanMerge:DEBUG] acrossBeat=1, syncopated=True, beatWeight=0, profile.breakSyncopationsMinWeight()=1
# [maelzel.scoring:quant.py:1883:_mergeSiblings:DEBUG] Nodes cannot merge (The syncopation asymmetry is too big: item1=«~4D-~ 0.667:1 1/3♩ 1/1,3/2», item2=«~4D- 1:1.083 1/12♩ 1/1,3/2», syncopationAsymmetry=Fraction(4, 1)):
# Node(3/2, dur=1/2 «~4Db< 0.5:0.583 1/12♩ 1/1,3/2»
#                   «4D-~ 0.583:0.667 1/12♩ 1/1,3/2»
#                   «~4D-~ 0.667:1 1/3♩ 1/1,3/2»)
# Node(3/2, dur=1/2 «~4D- 1:1.083 1/12♩ 1/1,3/2»
#                   «rest 1.083:1.167 1/12♩ 1/1,3/2»
#                   «rest 1.167:1.5 1/3♩ 1/1,3/2»)
# ...

# %%
from maelzel.core import *
ch = Chain(r"""
r:1/3
4C:3/5
r:4/3
4D:2/5

""")
ch
# Out:
# [maelzel.scoring:quant.py:1528:quantizeMeasure:DEBUG] Measure 4/4 is not filled (events=[«rest 0:0.333 1/3♩», «4C 0.333:0.933 3/5♩», «rest 0.933:2.267 4/3♩», «4D 2.267:2.667 2/5♩»]). Filling gaps with silences
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(1, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(2, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(3, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:2134:resolveEnharmonics:DEBUG] Resolving enharmonics for measure 0
# [maelzel.scoring:renderlily.py:1181:write:DEBUG] Rendering lilypond '/home/em/.cache/tmpjykuki6a/3_0k4b1j.ly' to '/home/em/.cache/tmpjykuki6a/3_0k4b1j.png'
# ...

# %%
tr = ch.quantizedScore()[0].measures[0].tree
print(tr)
tr[0][2].symbolicDuration()
# Out:
# [maelzel.scoring:quant.py:1528:quantizeMeasure:DEBUG] Measure 4/4 is not filled (events=[«rest 0:0.333 1/3♩», «4C 0.333:0.933 3/5♩», «rest 0.933:2.267 4/3♩», «4D 2.267:2.667 2/5♩»]). Filling gaps with silences
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(1, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(2, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:766:breakSyncopations:DEBUG] Evaluating split at beat.offset=Fraction(3, 1), beat.duration=Fraction(1, 1), minWeight=1
# [maelzel.scoring:quant.py:2134:resolveEnharmonics:DEBUG] Resolving enharmonics for measure 0
# Node(1/1, dur=4
#     Node(3/2, dur=1 «rest 0:0.333 1/3♩ 3/2»
#                     «4C~ 0.333:0.667 1/3♩ 3/2 properties={'.forwardTies': {0}}»
#                     Node(5/4, dur=1/3 «~4C 0.667:0.933 4/15♩ 3/2,5/4 properties={'.backwardTies': {0}}»
# ...

# %%
w =getWorkspace()

# %%
w.config
# Out:
# 20 36
# Config: maelzel:core
# -------------------------------  -------------------  ------------------------------------
# A4                               442                  between 10 - 10000
#                                                       Freq. of A4. Normal values are
#                                                       between 440-443, but any value can
#                                                       be used
# chordAdjustGain                  True                 type: bool
#                                                       Adjust the gain of a chord according
#                                                       to the number of notes, to prevent
#                                                       clipping
# dynamicCurveDynamics             ppp pp p mp mf f ff  type: str
#                                  fff
#                                                       Possible dynamic steps. A string
# ...

# %%
getW
