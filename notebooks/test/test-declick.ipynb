# %%
from maelzel.core import *
w = getWorkspace()

# %%
n = Note(60.5,10)

# %%
ev = n.play(instr='sin', fade=(0.1, 0.05), fadeshape='cos')
ev.stop(2)
ev
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Analog Stereo: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Analog Stereo:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(‖ preset:sin=401.0002 start=.153 dur=10 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.1 ifadeout=0.05 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60.5 p19=0.515178 p20=10 p21=60.5 …)

# %%
n = Note(60.5, 10)
ev = n.play(instr='.piano', fade=(0., 0.05), fadeshape='cos')
ev.set(transpose=0.5, delay=1)
ev.stop(4)
ev
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(‖ preset:.piano=402.0002 start=2.939 dur=10 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0 ifadeout=0.05 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=60.5 p21=0.515178 p22=10 p23=60.5 …)

# %%
w = getWorkspace()
n = Note(60.5, 6)
w.setReverb(decay=4, gaindb=-3, delayms=50)
with render(tail=4) as r:
    ev = n.play(instr='.piano', fade=(0.01, 0.02), fadeshape='cos', kwet=0.3)
    ev.automate('position', (0, 0, 0.5, 0, 1.5, 1))
    Note(61, 3, offset=1.5).play(instr='.piano', position=0, kwet=0.5).automate('transpose', (1, 0, 1.5, 1))
r
# Out:
# time range: scorestart=0.0, renderend=10.0, endtime=0.0
# OfflineRenderer(sr=44100)

# %%
w.reverbSynth()

# %%
w._reverbSettings
# Out:
# {'gaindb': -3, 'decay': 4, 'delayms': 50}

# %%
n.play(fade=0.2)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset:sin=501.0002 start=12.584 dur=6.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.2 ifadein=0.2 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=60.5 p18=0.515178 p19=6 p20=60.5 …)

# %%
getPreset('sin').getInstr()
# Out:
# Instr(preset:sin, position(kpos):5=0, gain(kgain):6=0, idataidx_:7=0, inumbps:8=0, ibplen:9=0, ichan:10=0, ifadein:11=0, ifadeout:12=0, ipchintrp_:13=0, ifadekind:14=0, ktransp:15=0, klag:16=0.1)
