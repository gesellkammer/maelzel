# %%
from maelzel.core import *

# %%
n = Note(60.5,10)

# %%
ev = n.play(instr='sin', fade=(0.1, 0.05), fadeshape='cos')
ev.stop(1)
ev
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Analog Stereo: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Analog Stereo:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(‖ preset:sin=401.0002 start=.137 dur=10 kpos=0.5 kgain=1 idataidx_=17 inumbps=2 ibplen=3 ichan=1 ifadein=0.1 ifadeout=0.05 ipchintrp_=0 ifadekind=1 ktransp=0 klag=0.1 p17=0 p18=60.5 p19=0.515178 p20=10 p21=60.5 …)

# %%
n = Note(60.5, 10)
ev = n.play(instr='.piano', fade=(0., 0.05), fadeshape='cos')
ev.set(transpose=0.5, delay=1)
ev.stop(4)
ev
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset:.piano=502.0003 start=16.398 dur=10.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0 ifadein=0.05 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=0 p17=60.5 p18=0.515178 p19=10 …)

# %%
preset = getPreset('.piano')
preset
# Out:
# Preset: .piano  (Default piano sound)
#     routing=True, properties={'sfpath': PosixPath('/home/em/dev/python/maelzel/maelzel/data/sf2/SalC5Light2.sf2')}
#   init: i__SfTable__ sfloadonce "/home/em/dev/python/maelzel/maelzel/data/sf2/SalC5Light2.sf2"
#   |ktransp=0.0, ipitchlag=0.1|
#
#   ipresetidx sfPresetIndex "/home/em/dev/python/maelzel/maelzel/data/sf2/SalC5Light2.sf2", 0, 0
#   inote0_ = round(p(idataidx_ + 1))
#   ivel_ = p(idataidx_ + 2) * 127
#   kpitch2 = lag:k(kpitch+ktransp, ipitchlag)
#   aout1, aout2 sfplay ivel_, inote0_, kamp/16384, mtof:k(kpitch2), ipresetidx, 1
#
#   epilogue:
#     turnoffWhenSilent aout1

# %%
n = Note(60.5, 6)
with render() as r:
    ev = n.play(instr='.piano', fade=(0, 0.02), fadeshape='cos')
    ev.stop(1.5)
    ev.automate('position', (0, 0, 1, 1))
    ev2 = Note(61, 3, offset=1.5).play(instr='.piano')
    ev2.automate('transpose', (1, 0, 1.5, 1))
r
# Out:
# OfflineRenderer(sr=44100)

# %%
r.openLastOutfile()
# Out:
# '/home/em/.local/share/maelzel/recordings/rec-2024-03-08T15:09:25.141.wav'
# QSocketNotifier: Can only be used with threads started with QThread
# Gtk-Message: 15:09:35.621: Failed to load module "appmenu-gtk-module"

# %%
n.play(fade=0.2)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset:sin=501.0002 start=12.584 dur=6.000 p4=0.5 kpos=1 kgain=17 idataidx_=2 inumbps=3 ibplen=1 ichan=0.2 ifadein=0.2 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 klag=0 p17=60.5 p18=0.515178 p19=6 p20=60.5 …)

# %%
getPreset('sin').getInstr()
# Out:
# Instr(preset:sin, position(kpos):5=0, gain(kgain):6=0, idataidx_:7=0, inumbps:8=0, ibplen:9=0, ichan:10=0, ifadein:11=0, ifadeout:12=0, ipchintrp_:13=0, ifadekind:14=0, ktransp:15=0, klag:16=0.1)
