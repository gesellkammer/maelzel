# %%
from maelzel.core import *
w = ws()
w.config['quant.complexity'] = 'high'

# %%
# w.config['quant.exactFactor'] = 0

v = Voice("""
    4c:1/4*6/7
    4d:1/4*6/7
    4e:1/4*6/7
    4f:1/4*6/7
    4g:1/4*6/7
    4c:1/4*6/7
    4d:1/4*6/7
    r:1/2
    4c:1/4*5/6
    4d:1/4*5/6
    4e:1/4*5/6
    4f:1/4*5/6
    4g:1/4*5/6
    4a:1/4*5/6
    r:3/4
    4c:1/4*7/8
    4d:1/4*7/8
    4e:1/4*7/8
    4f:1/4*7/8
    4g:1/4*7/8
    4a:1/4*7/8
    4b:1/4*7/8
    5c:1/4*7/8
    # r:1/4
    4c:1/4*5/6
    4d:1/4*5/6
    4e:1/4*5/6
    4f:1/4*5/6
    4g:1/4*5/6
    4a:1/4*5/6
""")
v
# Out:
# Voice([4C:3/14♩, 4D:3/14♩, 4E:3/14♩, 4F:3/14♩, 4G:3/14♩, 4C:3/14♩, 4D:3/14♩, R:1/2♩, 4C:5/24♩, 4D:5/24♩, …])

# %%
w.clearCache()

w.config['.quant.debug'] = True

v2 = Voice("""
4c:1/4*7/8
    4d:1/4*7/8
    4e:1/4*7/8
    4f:1/4*7/8
    4g:1/4*7/8
    4a:1/4*7/8
    4b:1/4*7/8
    5c:1/4*7/8
    r:1/4
    4c:1/4*5/6
    4d:1/4*5/6
    4e:1/4*5/6
    4f:1/4*5/6
    4g:1/4*5/6
    4a:1/4*5/6
""")
v2
# Out:
# Skipping (6,), weightedGridError: 0.318496, minError: 0.298103
# Skipping (7,), weightedGridError: 0.303145, minError: 0.298103
# Skipping (7, 15), totalError: 0.110332, minError: 0.1014
# Skipping (3, 3, 3), weightedGridError: 0.0841534, minError: 0.0835006
# Skipping (3, 3, 8), totalError: 0.0863004, minError: 0.0834942
# Skipping (3, 7, 8), weightedGridError: 0.0731859, minError: 0.0712203
# Skipping (8, 3, 8), weightedGridError: 0.0782143, minError: 0.0712203
# Skipping (11, 3, 11), weightedGridError: 0.075103, minError: 0.0712203
# Skipping (11, 7, 8), weightedGridError: 0.0742534, minError: 0.0712203
# Skipping (5, 7, 8, 2), weightedGridError: 0.0763018, minError: 0.0712203
# Skipping (7, 3, 8, 2), weightedGridError: 0.0746278, minError: 0.0712203
# Skipping (7, 4, 3, 9), weightedGridError: 0.0776432, minError: 0.0712203
# Skipping (7, 4, 3, 11), weightedGridError: 0.0717586, minError: 0.0712203
# Skipping (7, 4, 5, 9), weightedGridError: 0.0774409, minError: 0.0712203
# ...

# %%
w.config['.quant.debug'] = True

v3 = Voice("""
4c:1/4*7/8
    4d:1/4*7/8
    4e:1/4*7/8
    4f:1/4*7/8
    4g:1/4*7/8
    4a:1/4*7/8
    4b:1/4*7/8
    5c:1/4*7/8
    # r:1/4
    4c:1/4*5/6
    4d:1/4*5/6
    4e:1/4*5/6
    4f:1/4*5/6
    4g:1/4*5/6
    4a:1/4*5/6
""")
v3
# Out:
# Skipping (6,), weightedGridError: 0.318496, minError: 0.298103
# Skipping (7,), weightedGridError: 0.303145, minError: 0.298103
# Skipping (7, 15), totalError: 0.110332, minError: 0.1014
# Skipping (3, 3, 3), weightedGridError: 0.0841534, minError: 0.0835006
# Skipping (3, 3, 8), totalError: 0.0863004, minError: 0.0834942
# Skipping (3, 7, 8), weightedGridError: 0.0731859, minError: 0.0712203
# Skipping (8, 3, 8), weightedGridError: 0.0782143, minError: 0.0712203
# Skipping (11, 3, 11), weightedGridError: 0.075103, minError: 0.0712203
# Skipping (11, 7, 8), weightedGridError: 0.0742534, minError: 0.0712203
# Skipping (5, 7, 8, 2), weightedGridError: 0.0763018, minError: 0.0712203
# Skipping (7, 3, 8, 2), weightedGridError: 0.0746278, minError: 0.0712203
# Skipping (7, 4, 3, 9), weightedGridError: 0.0776432, minError: 0.0712203
# Skipping (7, 4, 3, 11), weightedGridError: 0.0717586, minError: 0.0712203
# Skipping (7, 4, 5, 9), weightedGridError: 0.0774409, minError: 0.0712203
# ...
