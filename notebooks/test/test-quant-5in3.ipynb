# %%
from maelzel.core import *

# %%
st = ScoreStruct("""
5/8, q=120
5/16
3/16
7/8(3+2+2)
11/16(5+6)
""")
st
# Out:
# ScoreStruct([5/8@120, 5/16, 3/16, 7/8, 11/16])

# %%
track = st.clickTrack()

# %%
track.show()
# Out:
# ---- [QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«5C~:1/2♩»], beatDuration=1/2, beatOffset=0, quantizationError=0, weight=0), QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«~5C~:1/2♩»], beatDuration=1/2, beatOffset=1/2, quantizationError=0, weight=0), QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«~5C:1/4♩»], beatDuration=1/4, beatOffset=1, quantizationError=0, weight=0)]
# ---- [QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«5C~:1/2♩»], beatDuration=1/2, beatOffset=0, quantizationError=0, weight=0), QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«~5C~:1/2♩»], beatDuration=1/2, beatOffset=1/2, quantizationError=0, weight=0), QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«~5C:1/4♩»], beatDuration=1/4, beatOffset=1, quantizationError=0, weight=0)]

# %%
st.activate()
# Out:
# ScoreStruct([5/8@120, 5/16, 3/16, 7/8, 11/16])

# %%
ch = Chain("""
4C:0.75
4D:1.75
4E:0.5
4F:0.75
4G:3/4*1/5
4A:3/4*1/5
4B:3/4*1/5
4g:3/4*1/5
4A:3/4*1/5
4C:1



""")
ch
# Out:
# ---- [QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«4E:1/2♩»], beatDuration=1/2, beatOffset=0, quantizationError=0, weight=0), QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«4F~:1/2♩»], beatDuration=1/2, beatOffset=1/2, quantizationError=0, weight=0), QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«~4F:1/4♩»], beatDuration=1/4, beatOffset=1, quantizationError=0, weight=0)]
# Chain([4C:3/4♩, 4D:7/4♩, 4E:1/2♩, 4F:3/4♩, 4G:3/20♩, 4A:3/20♩, 4B:3/20♩, 4G:3/20♩, 4A:3/20♩, 4C:1♩, …])

# %%
ch.play(kwet=0.7, gain=1.5, sustain=0.12)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=10)
#     Synth(‖ preset:.piano=401.0056 start=50.387 dur=.495 kpos=0.5 kgain=1.5 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.7 p19=0 p20=60 p21=0.515178 p22=0.375 p23=60 …)
#     Synth(‖ preset:.piano=401.0057 start=50.762 dur=.995 kpos=0.5 kgain=1.5 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.7 p19=0 p20=62 p21=0.515178 p22=0.875 p23=62 …)
#     Synth(‖ preset:.piano=401.0058 start=51.637 dur=.37 kpos=0.5 kgain=1.5 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.7 p19=0 p20=64 p21=0.515178 p22=0.25 p23=64 …)
# ...

# %%
ch.write("~/tmp/53.ly")
# Out:
# ---- [QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«4E:1/2♩»], beatDuration=1/2, beatOffset=0, quantizationError=0, weight=0), QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«4F~:1/2♩»], beatDuration=1/2, beatOffset=1/2, quantizationError=0, weight=0), QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«~4F:1/4♩»], beatDuration=1/4, beatOffset=1, quantizationError=0, weight=0)]

# %%
qs = ch.quantizedScore()
p1 = qs[0]
# Out:
# ---- [QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«4E:1/2♩»], beatDuration=1/2, beatOffset=0, quantizationError=0, weight=0), QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«4F~:1/2♩»], beatDuration=1/2, beatOffset=1/2, quantizationError=0, weight=0), QuantizedBeat(divisions: (1,), assignedSlots=[0], notations=[«~4F:1/4♩»], beatDuration=1/4, beatOffset=1, quantizationError=0, weight=0)]

# %%
p1.measures[2].tree
# Out:
# Node(1/1, dur=3/4
#     Node(5/4, dur=1/4 «4G:3/20♩ 1,5/4»
#                       «4A~:1/10♩ 1,5/4 properties={'.forwardTies': {0}}»)
#     Node(5/4, dur=1/4 «~4A:1/20♩ 1,5/4 properties={'.backwardTies': {0}}»
#                       «4B:3/20♩ 1,5/4»
#                       «4G~:1/20♩ 1,5/4 properties={'.forwardTies': {0}}»)
#     Node(5/4, dur=1/4 «~4G:1/10♩ 1,5/4 properties={'.backwardTies': {0}}»
#                       «4A:3/20♩ 1,5/4»))
