# %%
from maelzel.core import *

# %%
ch = Chain(r'''
4C,4E~
4E,4G~
4D,4G
''')
for ev in ch.synthEvents():
    print(ev)
ch
# Out:
# SynthEvent(delay=0, dur=1, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 60 -8.8; 1 60 -8.8｣)
# SynthEvent(delay=0, dur=2, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 64 -8.8; 1 64 -8.8; 2 64 -8.8｣)
# SynthEvent(delay=1, dur=2, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 67 -8.8; 1 67 -8.8; 2 67 -8.8｣)
# SynthEvent(delay=2, dur=1, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 62 -8.8; 1 62 -8.8｣)
# Chain([‹4C,4E~:1♩›, ‹4E,4G~:1♩›, ‹4D,4G:1♩›])

# %%
ch.play(instr='.piano')
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=4)
#     Synth(‖ preset:.piano=402.001 start=18.846 dur=1 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=60 p21=0.364286 p22=1 p23=60 …)
#     Synth(‖ preset:.piano=402.0011 start=18.846 dur=2 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=64 p21=0.364286 p22=1 p23=64 …)
#     Synth(‖ preset:.piano=402.0012 start=19.846 dur=2 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=67 p21=0.364286 p22=1 p23=67 …)
# ...

# %%
ch.copy().synthEvents()
# Out:
# [SynthEvent(delay=0, dur=1, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 60 -8.8; 1 60 -8.8｣),
#  SynthEvent(delay=0, dur=2, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 64 -8.8; 1 64 -8.8; 2 64 -8.8｣),
#  SynthEvent(delay=1, dur=2, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 67 -8.8; 1 67 -8.8; 2 67 -8.8｣),
#  SynthEvent(delay=2, dur=1, instr=sin, gain=1, chan=1, fade=(0.02, 0.02), position=0.5, bps=｢0 62 -8.8; 1 62 -8.8｣)]

# %%
ch.dump()
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0, offset: None, dur: 3</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset  dur     name   gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  (0,0)     0      -       1       4C,4E~ -     -    -                   -</span></code><br><code><span style="color:#9090FF;font-size:85%">  (0,1)     1      -       1       4E,4G~ -     -    -                   -</span></code><br><code><span style="color:#9090FF;font-size:85%">  (0,2)     2      -       1       4D,4G  -     -    -                   -</span></code>
