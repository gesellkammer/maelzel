# %%
from maelzel.core import *

v1 = Voice([
    "C4:1",
    "4D:0.5",
    "4E:0.5"
], name='v1')
v2 = Voice([
    "3A:1",
    "3G:0.5",
    "3Bb:0.5"
])
v3 = Voice([
    "3E:1",
    "3D:0.5",
    "3F:0.5"
])


s = Score([v1,v2, v3])

s.addGroup([v1, v2], name='bar', showPartNames=False)

s
# s
# Out:
# Setting groupid 72cdf07ab230 for parts: [UnquantizedPart(notations=[‹4C:1♩›, ‹4D:1/2♩ 1:1.5›, ‹4E:1/2♩ 1.5:2›], name=v1, showName=True)]
# Setting groupid 72cdf07ab230 for parts: [UnquantizedPart(notations=[‹3A:1♩›, ‹3G:1/2♩ 1:1.5›, ‹3A#:1/2♩ 1.5:2›], showName=True)]
# Score(3 voices)

# %%
s = Score([v1, v3, v2])
s.addGroup([v1, v2], name='bar', showPartNames=False)

s
# Out:
# Setting groupid 72cdf0082c10 for parts: [UnquantizedPart(notations=[‹4C:1♩›, ‹4D:1/2♩ 1:1.5›, ‹4E:1/2♩ 1.5:2›], name=v1, showName=True)]
# Setting groupid 72cdf0082c10 for parts: [UnquantizedPart(notations=[‹3A:1♩›, ‹3G:1/2♩ 1:1.5›, ‹3A#:1/2♩ 1.5:2›], showName=True)]
# Score(3 voices)

# %%
s = Score()
s.addGroup([v1, v2], name='bar', showPartNames=False)
# s.append(v3)
s
# Out:
# Setting groupid 72cdf0083610 for parts: [UnquantizedPart(notations=[‹4C:1♩›, ‹4D:1/2♩ 1:1.5›, ‹4E:1/2♩ 1.5:2›], name=v1, showName=True)]
# Setting groupid 72cdf0083610 for parts: [UnquantizedPart(notations=[‹3A:1♩›, ‹3G:1/2♩ 1:1.5›, ‹3A#:1/2♩ 1.5:2›], showName=True)]
# Score(2 voices)

# %%
from maelzel.core import *

w = ws()
cfg = w.config
cfg['show.voiceMaxStaves'] = 2

v1 = Voice([
    "2G,3F,4A,5C#:1",
    "4G#,4A-:0.5",
    "3F+,3Gb,6C#,6F-:0.5",
    "2D:1/4",
    "7E:1/4"
], name='foo', )
v1[0].addSpanner('slur', v1[2])
v1
# Out:
# Voice([‹2G,3F,4A,5C#:1♩›, ‹4G#,4A-:0.5♩›, ‹3F+,3Gb,6Db,6F-:0.5♩›, 2D:1/4♩, 7E:1/4♩])

# %%
from maelzel.core import *
v1 = Voice([
    "2G,3F,4A,5C#:1",
    "3F+,3Gb,6C#,6F-:0.5",
    "4G#,4A-:0.5",
    "2D:1/4",
    "7E:1/4"
], maxStaves=2, name='foo', )
v1[0].addSpanner('slur', v1[1])
v1
# Out:
# Voice([‹2G,3F,4A,5C#:1♩›, ‹3F+,3Gb,6Db,6F-:0.5♩›, ‹4G#,4A-:0.5♩›, 2D:1/4♩, 7E:1/4♩])

# %%
import numpy as np
v1 = Voice([Chord([p+12, p, p-12, p-24], 0.25) for p in range(48, 84, 2)])
v1.addSpanner('slur', (0, 1.25), (1, 0.5))
v1
# Out:
# Voice([‹1C,2C,3C,4C:0.25♩›, ‹1D,2D,3D,4D:0.25♩›, ‹1E,2E,3E,4E:0.25♩›, ‹1F#,2F#,3F#,4F#:0.25♩›, ‹1Ab,2Ab,3Ab,4Ab:0.25♩›, ‹1A#,2A#,3A#,4A#:0.25♩›, ‹2C,3C,4C,5C:0.25♩›, ‹2D,3D,4D,5D:0.25♩›, ‹2E,3E,4E,5E:0.25♩›, ‹2F#,3F#,4F#,5F#:0.25♩›, …])

# %%
from maelzel.core import *

v1 = Voice("""
5C:1/3
5D:1/3
5E:1/3
5F:1/2
5G:1/2
""")

v2 = Voice("""
4E:1/2
4F:1/2
4G:1/3
4A:1/3
4B:1/3
""")

s = Score()
# s = Score([v1, v2])
s.addPart([v1, v2])
s.show()
# Out:
# Setting groupid 72cde40ec510 for parts: [UnquantizedPart(notations=[‹5C:1/3♩›, ‹5D:1/3♩ 0.333:0.667›, ‹5E:1/3♩ 0.667:1›, ‹5F:1/2♩ 1:1.5›, ‹5G:1/2♩ 1.5:2›], showName=True)]
# Setting groupid 72cde40ec510 for parts: [UnquantizedPart(notations=[‹4E:1/2♩›, ‹4F:1/2♩ 0.5:1›, ‹4G:1/3♩ 1:1.333›, ‹4A:1/3♩ 1.333:1.667›, ‹4B:1/3♩ 1.667:2›], showName=True)]

# %%
s.fusedParts
# Out:
# [VoiceGroup((Voice([5C:1/3♩, 5D:1/3♩, 5E:1/3♩, 5F:1/2♩, 5G:1/2♩]), Voice([4E:1/2♩, 4F:1/2♩, 4G:1/3♩, 4A:1/3♩, 4B:1/3♩])), name='', abbrev='', groupid=72cde40ec510)]
