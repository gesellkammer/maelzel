# %%
from maelzel.core import *

v1 = Voice([
    "C4:1",
    "4D:0.5",
    "4E:0.5"
], name='v1')
v2 = Voice([
    "3A:1",
    "3G:0.5",
    "3Bb:0.5"
])
v3 = Voice([
    "3E:1",
    "3D:0.5",
    "3F:0.5"
])


s = Score([v1,v2, v3])

s.addGroup([v1, v2], name='bar', showPartNames=False)

s
# s
# Out:
# Score(3 voices)

# %%
s.play(kwet=0.8, gain=8)
# Out:
# using libsndfile-1.2.2
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 512 sample-frame blocks
# reading 4096-byte blks of shorts from adc:ALC257 Analog: (RAW)
# writing 1024 sample blks of 64-bit floats to dac:ALC257 Analog:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=9)
#     Synth(‖ preset:.piano=401.0002 start=.283 dur=1 kpos=0.5 kgain=8 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.8 p19=0 p20=60 p21=0.515178 p22=1 p23=60 …)
#     Synth(‖ preset:.piano=401.0003 start=1.283 dur=.5 kpos=0.5 kgain=8 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.8 p19=0 p20=62 p21=0.515178 p22=0.5 p23=62 …)
#     Synth(‖ preset:.piano=401.0004 start=1.783 dur=.5 kpos=0.5 kgain=8 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.8 p19=0 p20=64 p21=0.515178 p22=0.5 p23=64 …)
#     Synth(‖ preset:.piano=401.0005 start=.283 dur=1 kpos=0.5 kgain=8 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.8 p19=0 p20=57 p21=0.515178 p22=1 p23=57 …)
#     Synth(‖ preset:.piano=401.0006 start=1.283 dur=.5 kpos=0.5 kgain=8 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.8 p19=0 p20=55 p21=0.515178 p22=0.5 p23=55 …)
#     Synth(‖ preset:.piano=401.0007 start=1.783 dur=.5 kpos=0.5 kgain=8 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.8 p19=0 p20=58 p21=0.515178 p22=0.5 p23=58 …)
#     Synth(‖ preset:.piano=401.0008 start=.283 dur=1 kpos=0.5 kgain=8 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.8 p19=0 p20=52 p21=0.515178 p22=1 p23=52 …)
#     Synth(‖ preset:.piano=401.0009 start=1.283 dur=.5 kpos=0.5 kgain=8 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.8 p19=0 p20=50 p21=0.515178 p22=0.5 p23=50 …)
#     Synth(‖ preset:.piano=401.001 start=1.783 dur=.5 kpos=0.5 kgain=8 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.8 p19=0 p20=53 p21=0.515178 p22=0.5 p23=53 …)

# %%
s = Score()
s.addGroup([v1, v2], name='bar', showPartNames=False)
# s.append(v3)
s
# Out:
# Score(2 voices)

# %%
from maelzel.core import *

w = ws()
cfg = w.config
cfg['show.voiceMaxStaves'] = 2

v1 = Voice([
    "2G,3F,4A,5C#:1",
    "4G#,4A-:0.5",
    "3F+,3Gb,6C#,6F-:0.5",
    "2D:1/4",
    "7E:1/4"
], name='foo', )
v1[0].addSpanner('slur', v1[2])
v1
# Out:
# Voice([‹2G,3F,4A,5C#:1♩›, ‹4G#,4A-:0.5♩›, ‹3F+,3Gb,6Db,6F-:0.5♩›, 2D:1/4♩, 7E:1/4♩])

# %%
from maelzel.core import *
v1 = Voice([
    "2G,3F,4A,5C#:1",
    "3F+,3Gb,6C#,6F-:0.5",
    "4G#,4A-:0.5",
    "2D:1/4",
    "7E:1/4"
], maxStaves=2, name='', )
v1[0].addSpanner('slur', v1[1])
v1
# Out:
# Voice([‹2G,3F,4A,5C#:1♩›, ‹3F+,3Gb,6Db,6F-:0.5♩›, ‹4G#,4A-:0.5♩›, 2D:1/4♩, 7E:1/4♩])

# %%
import numpy as np
v1 = Voice([Chord([p+12, p, p-12, p-24], 0.25) for p in range(48, 84, 2)])
v1.addSpanner('slur', (0, 1.25), (1, 0.5))
v1
# Out:
# Voice([‹1C,2C,3C,4C:0.25♩›, ‹1D,2D,3D,4D:0.25♩›, ‹1E,2E,3E,4E:0.25♩›, ‹1F#,2F#,3F#,4F#:0.25♩›, ‹1G#,2G#,3G#,4G#:0.25♩›, ‹1Bb,2Bb,3Bb,4Bb:0.25♩›, ‹2C,3C,4C,5C:0.25♩›, ‹2D,3D,4D,5D:0.25♩›, ‹2E,3E,4E,5E:0.25♩›, ‹2F#,3F#,4F#,5F#:0.25♩›, …])

# %%
from maelzel.core import *

v1 = Voice("""
5C:1/3
5D:1/3
5E:1/3
5F:1/2
5G:1/2
5C:1/3
5D:1/3
5E:1/3
5F:1/2
5G:1/2

5C:1/3
5D:1/3
5E:1/3
5F:1/2
5G:1/2
5C:1/3
5D:1/3
5E:1/3
5F:1/2
5G:1/2

""", name='v1')

v2 = Voice("""
4E:1/2
4F:1/2
4G:1/3
4A:1/3
4B:1/3
""", name='v2')

s = Score()
# s = Score([v1, v2])
s.append(v1)
s.append(v2)
s.append(v1.transpose(-3))
s.append(v2.transpose(-3))
v1.addSpanner('slur')
v2.addSpanner(symbols.Slur(linetype='dashed'))
s.addPart([v1, v2], name="foo")

s.addGroup(s.voices[0:3], name='bar')
# s.addGroup(s.voices[0:4])
# s.addGroup([v1, v2])
s.show()

# %%
s.play(kwet=0.85, sustain=0.12)
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=50)
#     Synth(‖ preset:.piano=401.0252 start=68.105 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=72 p21=0.515178 p22=0.333333 p23=72 …)
#     Synth(‖ preset:.piano=401.0253 start=68.438 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=74 p21=0.515178 p22=0.333333 p23=74 …)
#     Synth(‖ preset:.piano=401.0254 start=68.771 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=76 p21=0.515178 p22=0.333333 p23=76 …)
#     Synth(‖ preset:.piano=401.0255 start=69.105 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=77 p21=0.515178 p22=0.5 p23=77 …)
#     Synth(‖ preset:.piano=401.0256 start=69.605 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=79 p21=0.515178 p22=0.5 p23=79 …)
#     Synth(‖ preset:.piano=401.0257 start=70.105 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=72 p21=0.515178 p22=0.333333 p23=72 …)
#     Synth(‖ preset:.piano=401.0258 start=70.438 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=74 p21=0.515178 p22=0.333333 p23=74 …)
#     Synth(‖ preset:.piano=401.0259 start=70.771 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=76 p21=0.515178 p22=0.333333 p23=76 …)
#     Synth(‖ preset:.piano=401.026 start=71.105 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=77 p21=0.515178 p22=0.5 p23=77 …)
#     Synth(‖ preset:.piano=401.0261 start=71.605 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=79 p21=0.515178 p22=0.5 p23=79 …)
#     Synth(‖ preset:.piano=401.0262 start=72.105 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=72 p21=0.515178 p22=0.333333 p23=72 …)
#     Synth(‖ preset:.piano=401.0263 start=72.438 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=74 p21=0.515178 p22=0.333333 p23=74 …)
#     Synth(‖ preset:.piano=401.0264 start=72.771 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=76 p21=0.515178 p22=0.333333 p23=76 …)
#     Synth(‖ preset:.piano=401.0265 start=73.105 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=77 p21=0.515178 p22=0.5 p23=77 …)
#     Synth(‖ preset:.piano=401.0266 start=73.605 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=79 p21=0.515178 p22=0.5 p23=79 …)
#     Synth(‖ preset:.piano=401.0267 start=74.105 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=72 p21=0.515178 p22=0.333333 p23=72 …)
#     Synth(‖ preset:.piano=401.0268 start=74.438 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=74 p21=0.515178 p22=0.333333 p23=74 …)
#     Synth(‖ preset:.piano=401.0269 start=74.771 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=76 p21=0.515178 p22=0.333333 p23=76 …)
#     Synth(‖ preset:.piano=401.027 start=75.105 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=77 p21=0.515178 p22=0.5 p23=77 …)
#     Synth(‖ preset:.piano=401.0271 start=75.605 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=79 p21=0.515178 p22=0.5 p23=79 …)
#     Synth(‖ preset:.piano=401.0272 start=68.105 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=64 p21=0.515178 p22=0.5 p23=64 …)
#     Synth(‖ preset:.piano=401.0273 start=68.605 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=65 p21=0.515178 p22=0.5 p23=65 …)
#     Synth(‖ preset:.piano=401.0274 start=69.105 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=67 p21=0.515178 p22=0.333333 p23=67 …)
#     Synth(‖ preset:.piano=401.0275 start=69.438 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=69 p21=0.515178 p22=0.333333 p23=69 …)
#     Synth(‖ preset:.piano=401.0276 start=69.771 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=71 p21=0.515178 p22=0.333333 p23=71 …)
#     Synth(‖ preset:.piano=401.0277 start=68.105 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=69 p21=0.515178 p22=0.333333 p23=69 …)
#     Synth(‖ preset:.piano=401.0278 start=68.438 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=71 p21=0.515178 p22=0.333333 p23=71 …)
#     Synth(‖ preset:.piano=401.0279 start=68.771 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=73 p21=0.515178 p22=0.333333 p23=73 …)
#     Synth(‖ preset:.piano=401.028 start=69.105 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=74 p21=0.515178 p22=0.5 p23=74 …)
#     Synth(‖ preset:.piano=401.0281 start=69.605 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=76 p21=0.515178 p22=0.5 p23=76 …)
#     Synth(‖ preset:.piano=401.0282 start=70.105 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=69 p21=0.515178 p22=0.333333 p23=69 …)
#     Synth(‖ preset:.piano=401.0283 start=70.438 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=71 p21=0.515178 p22=0.333333 p23=71 …)
#     Synth(‖ preset:.piano=401.0284 start=70.771 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=73 p21=0.515178 p22=0.333333 p23=73 …)
#     Synth(‖ preset:.piano=401.0285 start=71.105 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=74 p21=0.515178 p22=0.5 p23=74 …)
#     Synth(‖ preset:.piano=401.0286 start=71.605 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=76 p21=0.515178 p22=0.5 p23=76 …)
#     Synth(‖ preset:.piano=401.0287 start=72.105 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=69 p21=0.515178 p22=0.333333 p23=69 …)
#     Synth(‖ preset:.piano=401.0288 start=72.438 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=71 p21=0.515178 p22=0.333333 p23=71 …)
#     Synth(‖ preset:.piano=401.0289 start=72.771 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=73 p21=0.515178 p22=0.333333 p23=73 …)
#     Synth(‖ preset:.piano=401.029 start=73.105 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=74 p21=0.515178 p22=0.5 p23=74 …)
#     Synth(‖ preset:.piano=401.0291 start=73.605 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=76 p21=0.515178 p22=0.5 p23=76 …)
#     Synth(‖ preset:.piano=401.0292 start=74.105 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=69 p21=0.515178 p22=0.333333 p23=69 …)
#     Synth(‖ preset:.piano=401.0293 start=74.438 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=71 p21=0.515178 p22=0.333333 p23=71 …)
#     Synth(‖ preset:.piano=401.0294 start=74.771 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=73 p21=0.515178 p22=0.333333 p23=73 …)
#     Synth(‖ preset:.piano=401.0295 start=75.105 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=74 p21=0.515178 p22=0.5 p23=74 …)
#     Synth(‖ preset:.piano=401.0296 start=75.605 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=76 p21=0.515178 p22=0.5 p23=76 …)
#     Synth(‖ preset:.piano=401.0297 start=68.105 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=61 p21=0.515178 p22=0.5 p23=61 …)
#     Synth(‖ preset:.piano=401.0298 start=68.605 dur=.62 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=62 p21=0.515178 p22=0.5 p23=62 …)
#     Synth(‖ preset:.piano=401.0299 start=69.105 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=64 p21=0.515178 p22=0.333333 p23=64 …)
#     Synth(‖ preset:.piano=401.03 start=69.438 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=66 p21=0.515178 p22=0.333333 p23=66 …)
#     Synth(‖ preset:.piano=401.0301 start=69.771 dur=.453 kpos=0.5 kgain=1 idataidx_=19 inumbps=3 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0.85 p19=0 p20=68 p21=0.515178 p22=0.333333 p23=68 …)

# %%
s.quantizedScore().partTree()
# Out:
# PartNode()
#   PartNode(group, name=bar)
#     PartNode(part, name=foo)
#     QuantizedPart(measures=[QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(3/2, dur=1 «5C:1/3♩ 1,3/2 spanners=[Slur(kind=start, linetype=solid, nestingLevel=1, uuid=mlt12sud)]»
#                     «5D:1/3♩ 1,3/2»
#                     «5E:1/3♩ 1,3/2»)
#     «5F:1/2♩»
#     «5G:1/2♩»
#     Node(3/2, dur=1 «5C:1/3♩ 1,3/2»
#                     «5D:1/3♩ 1,3/2»
#                     «5E:1/3♩ 1,3/2»)
#     «5F:1/2♩»
#     «5G:1/2♩»), profile=high), QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(3/2, dur=1 «5C:1/3♩ 1,3/2»
#                     «5D:1/3♩ 1,3/2»
#                     «5E:1/3♩ 1,3/2»)
#     «5F:1/2♩»
#     «5G:1/2♩»
#     Node(3/2, dur=1 «5C:1/3♩ 1,3/2»
#                     «5D:1/3♩ 1,3/2»
#                     «5E:1/3♩ 1,3/2»)
#     «5F:1/2♩»
#     «5G:1/2♩ spanners=[Slur(kind=end, linetype=solid, nestingLevel=1, uuid=mlt12sud)]»), profile=high)], name=v1, quantProfile=QuantizationProfile(high), struct=ScoreStruct(4/4, tempo=60))
#     QuantizedPart(measures=[QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4 «4E:1/2♩ spanners=[Slur(kind=start, linetype=dashed, nestingLevel=1, uuid=kbt6e7wc)]»
#                 «4F:1/2♩»
#                 Node(3/2, dur=1 «4G:1/3♩ 1,3/2»
#                                 «4A:1/3♩ 1,3/2»
#                                 «4B:1/3♩ 1,3/2 spanners=[Slur(kind=end, linetype=dashed, nestingLevel=1, uuid=kbt6e7wc)]»)
#                 «r:2♩»), profile=high)], name=v2, quantProfile=QuantizationProfile(high), struct=ScoreStruct(4/4, tempo=60))
#   QuantizedPart(measures=[QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(3/2, dur=1 «4A:1/3♩ 1,3/2»
#                     «4B:1/3♩ 1,3/2»
#                     «5C#:1/3♩ 1,3/2»)
#     «5D:1/2♩»
#     «5E:1/2♩»
#     Node(3/2, dur=1 «4A:1/3♩ 1,3/2»
#                     «4B:1/3♩ 1,3/2»
#                     «5C#:1/3♩ 1,3/2»)
#     «5D:1/2♩»
#     «5E:1/2♩»), profile=high), QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4
#     Node(3/2, dur=1 «4A:1/3♩ 1,3/2»
#                     «4B:1/3♩ 1,3/2»
#                     «5C#:1/3♩ 1,3/2»)
#     «5D:1/2♩»
#     «5E:1/2♩»
#     Node(3/2, dur=1 «4A:1/3♩ 1,3/2»
#                     «4B:1/3♩ 1,3/2»
#                     «5C#:1/3♩ 1,3/2»)
#     «5D:1/2♩»
#     «5E:1/2♩»), profile=high)], name=v1, quantProfile=QuantizationProfile(high), struct=ScoreStruct(4/4, tempo=60))
# QuantizedPart(measures=[QuantizedMeasure(timesig=4/4, quarterTempo=60, tree=Node(1/1, dur=4 «4C#:1/2♩»
#                 «4D:1/2♩»
#                 Node(3/2, dur=1 «4E:1/3♩ 1,3/2»
#                                 «4F#:1/3♩ 1,3/2»
#                                 «4G#:1/3♩ 1,3/2»)
#                 «r:2♩»), profile=high)], name=v2, quantProfile=QuantizationProfile(high), showName=True, struct=ScoreStruct(4/4, tempo=60))
