# %%
from maelzel.core import *

v1 = Voice([
    "C4:1",
    "4D:0.5",
    "4E:0.5"
], name='v1')
v2 = Voice([
    "3E:1",
    "3D:0.5",
    "3F:0.5"
])
v3 = Voice([
    "3E:1",
    "3D:0.5",
    "3F:0.5"
])


s = Score([v1,v2, v3])

s.makeGroup([v1, v2], name='bar', shortname='b', showPartNames=False)


# s

# %%
s
# Out:
# Score(3 voices)

# %%
from maelzel.core import *
v1 = Voice([
    "2G,3F,4A,5C#:1",
    "4G#,4A-:0.5",
    "3F+,3Gb,6C#,6F-:0.5",
    "2D:1/4",
    "7E:1/4"
], maxstaves=2, name='foo', )
v1[0].addSpanner('slur', v1[2])
v1
# Out:
# Voice([‹2G 3F 4A 5C# 1♩›, ‹4G# 4A- 0.5♩›, ‹3F+ 3Gb 6Db 6F- 0.5♩›, 2D:1/4♩, 7E:1/4♩])

# %%
from maelzel.core import *
v1 = Voice([
    "2G,3F,4A,5C#:1",
    "3F+,3Gb,6C#,6F-:0.5",
    "4G#,4A-:0.5",
    "2D:1/4",
    "7E:1/4"
], maxstaves=2, name='foo', )
v1[0].addSpanner('slur', v1[1])
v1
# Out:
# Voice([‹2G 3F 4A 5C# 1♩›, ‹3F+ 3Gb 6Db 6F- 0.5♩›, ‹4G# 4A- 0.5♩›, 2D:1/4♩, 7E:1/4♩])

# %%
import numpy as np
v1 = Voice([Chord([p+12, p, p-12, p-24], 0.25) for p in range(48, 84, 2)])
v1.addSpanner('slur', (0, 1.25), (1, 0.5))
v1
# Out:
# Voice([‹1C 2C 3C 4C 0.25♩›, ‹1D 2D 3D 4D 0.25♩›, ‹1E 2E 3E 4E 0.25♩›, ‹1F# 2F# 3F# 4F# 0.25♩›, ‹1Ab 2Ab 3Ab 4Ab 0.25♩›, ‹1Bb 2Bb 3Bb 4Bb 0.25♩›, ‹2C 3C 4C 5C 0.25♩›, ‹2D 3D 4D 5D 0.25♩›, ‹2E 3E 4E 5E 0.25♩›, ‹2Gb 3Gb 4Gb 5Gb 0.25♩›, …])
