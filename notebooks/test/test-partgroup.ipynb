# %%
from maelzel.core import *

v1 = Voice([
    "C4:1",
    "4D:0.5",
    "4E:0.5"
], name='v1')
v2 = Voice([
    "3E:1",
    "3D:0.5",
    "3F:0.5"
])
v3 = Voice([
    "3E:1",
    "3D:0.5",
    "3F:0.5"
])


s = Score([v1,v2, v3])

s.makeGroup([v1, v2], name='bar', shortname='b', showPartNames=False)


# s

# %%
s
# Out:
# Score(3 voices)

# %%
v1 = Voice([
    "2G,3F,4A,5C#:1",
    "4G#,4A-:0.5",
    "3F+,3Gb,6C#,6F-:0.5",
    "2D:1/4",
    "7E:1/4"
], maxstaves=2, name='foo')
v1[0].addSpanner('slur', v1[2])
v1
# Out:
# Voice([‹2G 3F 4A 5C# 1♩›, ‹4G# 4A- 0.5♩›, ‹3F+ 3Gb 6Db 6F- 0.5♩›, 2D:0.25♩, 7E:0.25♩], offset=0)

# %%
v1= Voice(["2G,2F:1"])
v1
# Out:
# Voice([‹2F 2G 1♩›], offset=0)

# %%
v1.maxstaves
# Out:
# 1
