# %%
from maelzel import scorestruct

# %%
t = scorestruct.TimeSignature.parse("3/4+3/8")
t
# Out:
# TimeSignature(3/4+3/8)

# %%
t = scorestruct.TimeSignature.parse("5/8(3-2)")
t
# Out:
# TimeSignature(5/8(3-2))

# %%
m = scorestruct.MeasureDef(timesig=scorestruct.TimeSignature.parse("3/16"), tempo=30)
print(m)
print(m.subdivisions())
# Out:
# MeasureDef(3/16, 𝅘𝅥=30, const✓)
# [Fraction(3, 16)]

# %%
m = scorestruct.MeasureDef(timesig=scorestruct.TimeSignature.parse("4/4+3/8"), tempo=60)
print(m)
print(m.subdivisions())
# Out:
# MeasureDef(4/4+3/8, 𝅘𝅥=60, const✓)
# [Fraction(1, 1), Fraction(1, 1), Fraction(1, 1), Fraction(1, 1), Fraction(3, 2)]

# %%
from maelzel.core import *
cfg = Workspace.active.config
cfg['reprUnicodeFractions'] = True

# %%
w = Workspace.active
w.scorestruct = r'''
4/4
5/8
3/8
6/16(2-2-2)
'''

ch = Chain([Note(m, 1/2) for m in range(60, 80)])
ch
# Out:
# Chain([4C:¹⁄₂♩, 4C♯:¹⁄₂♩, 4D:¹⁄₂♩, 4D♯:¹⁄₂♩, 4E:¹⁄₂♩, 4F:¹⁄₂♩, 4F♯:¹⁄₂♩, 4G:¹⁄₂♩, 4G♯:¹⁄₂♩, 4A:¹⁄₂♩, …])

# %%
w.scorestruct = r'''
5/8(3-2)
'''

ch = Chain([Note(m, 1/2) for m in range(60, 80)])
ch
# Out:
# Chain([4C:¹⁄₂♩, 4C♯:¹⁄₂♩, 4D:¹⁄₂♩, 4D♯:¹⁄₂♩, 4E:¹⁄₂♩, 4F:¹⁄₂♩, 4F♯:¹⁄₂♩, 4G:¹⁄₂♩, 4G♯:¹⁄₂♩, 4A:¹⁄₂♩, …])

# %%
w.setScoreStruct(r'''
5/8(2-3)
''')

ch = Chain([Note(m, 1/2) for m in range(60, 80)])
ch
# Out:
# Chain([4C:¹⁄₂♩, 4C♯:¹⁄₂♩, 4D:¹⁄₂♩, 4D♯:¹⁄₂♩, 4E:¹⁄₂♩, 4F:¹⁄₂♩, 4F♯:¹⁄₂♩, 4G:¹⁄₂♩, 4G♯:¹⁄₂♩, 4A:¹⁄₂♩, …])

# %%
from maelzel.core import *
w = getWorkspace()
w.setScoreStruct(r'''
9/16 , 16=60
''')

ch = Chain([Note(m, 3/8) for m in range(60, 80)])
w.scorestruct.dump()
ch
# Out:
# <p><strong>ScoreStruct</strong></p><table><thead><tr><th style="text-align:left">Meas. Index</th><th style="text-align:left">Timesig</th><th style="text-align:left">Tempo</th><th style="text-align:left">Label</th><th style="text-align:left">Rehearsal</th><th style="text-align:left">Barline</th><th style="text-align:left">Beats</th></tr></thead><tbody><tr><td style="text-align:left"><span style="font-size: small;">0</span></td><td style="text-align:left"><span style="font-size: small;">9/16</span></td><td style="text-align:left"><span style="font-size: small;">𝅘𝅥𝅯=60</span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;">9×𝅘𝅥𝅯</span></td></tr><tr><td style="text-align:left"><span style="font-size: small;">...</span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td></tr></tbody></table>
# Chain([4C:3/8♩, 4C♯:3/8♩, 4D:3/8♩, 4D♯:3/8♩, 4E:3/8♩, 4F:3/8♩, 4F♯:3/8♩, 4G:3/8♩, 4G♯:3/8♩, 4A:3/8♩, …])

# %%
from maelzel.core import *
w = getWorkspace()
w.setScoreStruct(r'''
9/16+2/16, 8.=60
''')

ch = Chain([Note(m, 1/2) for m in range(60, 85)])
w.scorestruct.dump()
ch
# Out:
# <p><strong>ScoreStruct</strong></p><table><thead><tr><th style="text-align:left">Meas. Index</th><th style="text-align:left">Timesig</th><th style="text-align:left">Tempo</th><th style="text-align:left">Label</th><th style="text-align:left">Rehearsal</th><th style="text-align:left">Barline</th><th style="text-align:left">Beats</th></tr></thead><tbody><tr><td style="text-align:left"><span style="font-size: small;">0</span></td><td style="text-align:left"><span style="font-size: small;">9+2/16</span></td><td style="text-align:left"><span style="font-size: small;">𝅘𝅥𝅮𝅭=60</span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;">𝅘𝅥𝅮𝅭+𝅘𝅥𝅮𝅭+𝅘𝅥𝅮𝅭+𝅘𝅥𝅮</span></td></tr><tr><td style="text-align:left"><span style="font-size: small;">...</span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td><td style="text-align:left"><span style="font-size: small;"></span></td></tr></tbody></table>
# Chain([4C:1/2♩, 4C♯:1/2♩, 4D:1/2♩, 4D♯:1/2♩, 4E:1/2♩, 4F:1/2♩, 4F♯:1/2♩, 4G:1/2♩, 4G♯:1/2♩, 4A:1/2♩, …])

# %%
ch.play(instr='.piano')
# Out:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=25)
#     Synth(‖ preset:.piano=402.0052 start=56.238 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=60 p21=0.515178 p22=0.666667 p23=60 …)
#     Synth(‖ preset:.piano=402.0053 start=56.905 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=61 p21=0.515178 p22=0.666667 p23=61 …)
#     Synth(‖ preset:.piano=402.0054 start=57.571 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=62 p21=0.515178 p22=0.666667 p23=62 …)
#     Synth(‖ preset:.piano=402.0055 start=58.238 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=63 p21=0.515178 p22=0.666667 p23=63 …)
#     Synth(‖ preset:.piano=402.0056 start=58.905 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=64 p21=0.515178 p22=0.666667 p23=64 …)
#     Synth(‖ preset:.piano=402.0057 start=59.571 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=65 p21=0.515178 p22=0.666667 p23=65 …)
#     Synth(‖ preset:.piano=402.0058 start=60.238 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=66 p21=0.515178 p22=0.666667 p23=66 …)
#     Synth(‖ preset:.piano=402.0059 start=60.905 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=67 p21=0.515178 p22=0.666667 p23=67 …)
#     Synth(‖ preset:.piano=402.006 start=61.571 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=68 p21=0.515178 p22=0.666667 p23=68 …)
#     Synth(‖ preset:.piano=402.0061 start=62.238 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=69 p21=0.515178 p22=0.666667 p23=69 …)
#     Synth(‖ preset:.piano=402.0062 start=62.905 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=70 p21=0.515178 p22=0.666667 p23=70 …)
#     Synth(‖ preset:.piano=402.0063 start=63.571 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=71 p21=0.515178 p22=0.666667 p23=71 …)
#     Synth(‖ preset:.piano=402.0064 start=64.238 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=72 p21=0.515178 p22=0.666667 p23=72 …)
#     Synth(‖ preset:.piano=402.0065 start=64.905 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=73 p21=0.515178 p22=0.666667 p23=73 …)
#     Synth(‖ preset:.piano=402.0066 start=65.571 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=74 p21=0.515178 p22=0.666667 p23=74 …)
#     Synth(‖ preset:.piano=402.0067 start=66.238 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=75 p21=0.515178 p22=0.666667 p23=75 …)
#     Synth(‖ preset:.piano=402.0068 start=66.905 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=76 p21=0.515178 p22=0.666667 p23=76 …)
#     Synth(‖ preset:.piano=402.0069 start=67.571 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=77 p21=0.515178 p22=0.666667 p23=77 …)
#     Synth(‖ preset:.piano=402.007 start=68.238 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=78 p21=0.515178 p22=0.666667 p23=78 …)
#     Synth(‖ preset:.piano=402.0071 start=68.905 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=79 p21=0.515178 p22=0.666667 p23=79 …)
#     Synth(‖ preset:.piano=402.0072 start=69.571 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=80 p21=0.515178 p22=0.666667 p23=80 …)
#     Synth(‖ preset:.piano=402.0073 start=70.238 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=81 p21=0.515178 p22=0.666667 p23=81 …)
#     Synth(‖ preset:.piano=402.0074 start=70.905 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=82 p21=0.515178 p22=0.666667 p23=82 …)
#     Synth(‖ preset:.piano=402.0075 start=71.571 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=83 p21=0.515178 p22=0.666667 p23=83 …)
#     Synth(‖ preset:.piano=402.0076 start=72.238 dur=.667 kpos=0.5 kgain=1 idataidx_=19 inumbps=2 ibplen=3 ichan=1 ifadein=0.02 ifadeout=0.02 ipchintrp_=0 ifadekind=1 ktransp=0 ipitchlag=0.1 ivel=-1 kwet=0 p19=0 p20=84 p21=0.515178 p22=0.666667 p23=84 …)

# %%
from maelzel.core import *
w = getWorkspace()
w.setScoreStruct(r'''
15/16
3/8
''')

ch = Chain([Note(m, "4/7") for m in range(60, 80)])
ch
# Out:
# Chain([4C:4/7♩, 4C♯:4/7♩, 4D:4/7♩, 4D♯:4/7♩, 4E:4/7♩, 4F:4/7♩, 4F♯:4/7♩, 4G:4/7♩, 4G♯:4/7♩, 4A:4/7♩, …])

# %%
w.setScoreStruct(r'''
3/4+3/16, 4=56
''')

ch = Chain([Note(m, "4/7") for m in range(60, 80)])
ch
# Out:
# Chain([4C:4/7♩, 4C♯:4/7♩, 4D:4/7♩, 4D♯:4/7♩, 4E:4/7♩, 4F:4/7♩, 4F♯:4/7♩, 4G:4/7♩, 4G♯:4/7♩, 4A:4/7♩, …])
