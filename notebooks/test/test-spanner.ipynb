# %%
from maelzel.core import *
from maelzel.music import lilytools

# %%
Workspace.clearCache()

ch = Chain([
    "4C:1.5",
    "4F:0.5",
    
    
])
ch[0].addSpanner('slur', ch[1])
ch
# Out:
# Chain([4C:3/2♩:symbols=[Slur(anchor=4C, kind=start, uuid=5r9bbm81)], 4F:1/2♩:symbols=[Slur(anchor=4F, kind=end, uuid=5r9bbm81)]])

# %%
Workspace.clearCache()

ch = Chain([
    "4C:1.5:gliss",
    "4E:0:stemless",
    "4d:0.5:gliss=4f",
])
ch[0].addSpanner('slur', ch[2])
ch
# Out:
# Chain([4C:3/2♩:gliss=True:symbols=[Slur(anchor=4C, kind=start, uuid=7yki1lql)], 4E:symbols=[Stem(hidden=True)], 4D:1/2♩:gliss=4F:symbols=[Slur(anchor=4D, kind=end, uuid=7yki1lql)]])

# %%
ch2 = ch.copy()
graces = ch2.convertGlissTargetsToGracenotes()
ch2.dump()
ch2
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0, offset: None, dur: 2</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0       0      (0)         1.5         4C        T (64.0)     None                -</span></code><br><code>      <span style="color:#8080E0;font-size:85%">[Slur(anchor=4C, kind=start, uuid=7yki1lql)]</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.5     1.5    (1.5)       0           4E        F          None                -</span></code><br><code>      <span style="color:#8080E0;font-size:85%">[Stem(hidden=True)]</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.5     1.5    (1.5)       0.5         4D        T (65.0)     None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:2       2      (2)         0           4F        F          None                -</span></code><br><code>      <span style="color:#8080E0;font-size:85%">[Slur(anchor=4F, kind=end, uuid=7yki1lql)]</span></code>
# Chain([4C:3/2♩:gliss=True:symbols=[Slur(anchor=4C, kind=start, uuid=7yki1lql)], 4E:symbols=[Stem(hidden=True)], 4D:1/2♩:gliss=True, 4F:symbols=[Slur(anchor=4F, kind=end, uuid=7yki1lql)]])

# %%
ch = Chain([
    "4C:1.5:gliss",
    "4E:0:stemless",
    "4d:0.5:gliss",
    Note.grace("4f", stemless=True, )
])
ch[0].addSpanner('slur', ch[2])
ch.write("~/tmp/test1.ly")
ch
# Out:
# Chain([4C:3/2♩:gliss=True:symbols=[Slur(anchor=4C, kind=start, uuid=yaca5vzs)], 4E:symbols=[Stem(hidden=True)], 4D:1/2♩:gliss=True:symbols=[Slur(anchor=4D, kind=end, uuid=yaca5vzs)], 4F:symbols=[Stem(hidden=True)]])

# %%
from maelzel.core import *

ch = Chain([Note(p, 0.5) for p in range(50, 80)])
ch
# Out:
# Chain([3D:1/2♩, 3D♯:1/2♩, 3E:1/2♩, 3F:1/2♩, 3F♯:1/2♩, 3G:1/2♩, 3G♯:1/2♩, 3A:1/2♩, 3A♯:1/2♩, 3B:1/2♩, …])

# %%
from maelzel.core import *

ch = Chain([Note(p, 0.5) for p in range(50, 80)])
ch[5].addSpanner(symbols.NoteheadLine(color='#990000'), ch[10])
ch[3].addSpanner('slur', ch[8])
ch
# Out:
# Chain([3D:1/2♩, 3D♯:1/2♩, 3E:1/2♩, 3F:1/2♩:symbols=[Slur(anchor=3F, kind=start, uuid=zt8keetc)], 3F♯:1/2♩, 3G:1/2♩:symbols=[NoteheadLine(anchor=3G, color=#990000, kind=start, uuid=76d7d1ux)], 3G♯:1/2♩, 3A:1/2♩, 3A♯:1/2♩:symbols=[Slur(anchor=3A#, kind=end, uuid=zt8keetc)], 3B:1/2♩, …])

# %%
ch = Chain([Note(p, 0.25) for p in range(48, 72)])
ch[1].addSpanner(symbols.NoteheadLine(color='blue'), ch[3])
ch[5].addSpanner(symbols.Beam(), ch[9])
ch[10].addSpanner(symbols.Bracket(), ch[13])
ch[0].addSpanner('slur', ch[7])
ch
# Out:
# Chain([3C:1/4♩:symbols=[Slur(anchor=3C, kind=start, uuid=7i0bkoxq)], 3C♯:1/4♩:symbols=[NoteheadLine(anchor=3C#, color=blue, kind=start, uuid=8qego50g)], 3D:1/4♩, 3D♯:1/4♩:symbols=[NoteheadLine(anchor=3D#, color=blue, kind=end, uuid=8qego50g)], 3E:1/4♩, 3F:1/4♩:symbols=[Beam(anchor=3F, kind=start, uuid=a23uz3y2)], 3F♯:1/4♩, 3G:1/4♩:symbols=[Slur(anchor=3G, kind=end, uuid=7i0bkoxq)], 3G♯:1/4♩, 3A:1/4♩:symbols=[Beam(anchor=3A, kind=end, uuid=a23uz3y2)], …])

# %%
ch = Chain([Note(p, 0.25) for p in range(48, 72)])
ch[0].addSpanner('slur', ch[9])
ch[4].addSpanner('bracket', ch[13])
ch[7].addSpanner(symbols.Slur(placement='below', color="red"), ch[16])
ch
# Out:
# Chain([3C:1/4♩:symbols=[Slur(anchor=3C, kind=start, uuid=w0vv98fv)], 3C♯:1/4♩, 3D:1/4♩, 3D♯:1/4♩, 3E:1/4♩:symbols=[Bracket(anchor=3E, kind=start, uuid=k39f3xq8)], 3F:1/4♩, 3F♯:1/4♩, 3G:1/4♩:symbols=[Slur(anchor=3G, color=red, kind=start, placement=below, uuid=sino2mat)], 3G♯:1/4♩, 3A:1/4♩:symbols=[Slur(anchor=3A, kind=end, uuid=w0vv98fv)], …])
