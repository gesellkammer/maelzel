# %%
from maelzel.core import *
from maelzel.music import lilytools

# %%
resetImageCache()
ch = Chain([
    "4C:1.5",
    "4F:0.5",
    
    
])
ch[0].addSpanner('slur', ch[1])
ch
# Out:
# Chain([4C:1.5♩:symbols=[Slur(anchor=Slur, kind=start, linetype=solid, partnerSpanner=Slur, uuid=zultjqj7)], 4F:0.5♩:symbols=[Slur(anchor=Slur, kind=end, linetype=solid, partnerSpanner=Slur, uuid=zultjqj7)]])

# %%
resetImageCache()
ch = Chain([
    "4C:1.5:gliss",
    "4E:0:stemless",
    "4F:0.5",
    
    
])
ch[0].addSpanner('slur', ch[1])
ch
# Out:
# Chain([4C:1.5♩:gliss=True:symbols=[Slur(anchor=Slur, kind=start, linetype=solid, partnerSpanner=Slur, uuid=40gkewgs)], 4E:symbols=[Stem(hidden=True), Slur(anchor=Slur, kind=end, linetype=solid, partnerSpanner=Slur, uuid=40gkewgs)], 4F:0.5♩])

# %%
ch = Chain([Note(p, 0.25) for p in range(48, 72)])
ch[1].addSpanner(symbols.NoteheadLine(color='blue'), ch[3])
ch[5].addSpanner(symbols.Beam(), ch[9])
ch[10].addSpanner(symbols.Bracket(), ch[13])
ch[0].addSpanner('slur', ch[7])
ch
# Out:
# Chain([3C:0.25♩:symbols=[Slur(anchor=Slur, kind=start, linetype=solid, partnerSpanner=Slur, uuid=dha256ij)], 3C#:0.25♩:symbols=[NoteheadLine(anchor=NoteheadLine, color=blue, kind=start, linetype=solid, partnerSpanner=NoteheadLine, uuid=2xxpqxr7)], 3D:0.25♩, 3D#:0.25♩:symbols=[NoteheadLine(anchor=NoteheadLine, color=blue, kind=end, linetype=solid, partnerSpanner=NoteheadLine, uuid=2xxpqxr7)], 3E:0.25♩, 3F:0.25♩:symbols=[Beam(anchor=Beam, kind=start, linetype=solid, partnerSpanner=Beam, uuid=hfc0zya2)], 3F#:0.25♩, 3G:0.25♩:symbols=[Slur(anchor=Slur, kind=end, linetype=solid, partnerSpanner=Slur, uuid=dha256ij)], 3G#:0.25♩, 3A:0.25♩:symbols=[Beam(anchor=Beam, kind=end, linetype=solid, partnerSpanner=Beam, uuid=hfc0zya2)], …])
