# %%
from maelzel.core import *
# Out:
# WARNING: Csound 7 support is experimental. Proceed at yout own risk

# %%
ch = Chain(r'''
    4C:0.5
    4D:1
    4E:1
    4F:2
''')
ch
# Out:
# Chain([4C:0.5♩, 4D:1♩, 4E:1♩, 4F:2♩])

# %%
ch.itemsBetween(0.25, 3)
# Out:
# [4C:0.5♩, 4D:1♩, 4E:1♩, 4F:2♩]

# %%
events = ch.eventsBetween(0.25, 3)
for ev in events:
    print(f"{str(ev).ljust(10)}{ev.parent}")
# Out:
# 4C:0.5♩   Chain([4C:0.5♩, 4D:1♩, 4E:1♩, 4F:2♩])
# 4D:1♩     Chain([4C:0.5♩, 4D:1♩, 4E:1♩, 4F:2♩])
# 4E:1♩     Chain([4C:0.5♩, 4D:1♩, 4E:1♩, 4F:2♩])
# 4F:2♩     Chain([4C:0.5♩, 4D:1♩, 4E:1♩, 4F:2♩])

# %%
cropped = ch.cropped(0.5, 3)
cropped.dump()
cropped
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0.5, offset: 0.5, dur: 2.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0.5     0.5    (0)         1           4D        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.5     1.5    (1)         1           4E        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:2.5     2.5    (2)         0.5         4F        F          None                -</span></code>
# Chain([4D:1♩, 4E:1♩, 4F:0.5♩], offset=1/2)

# %%
cropped.timeShift(-F(1, 4))
# Out:
# Chain([4D:1♩, 4E:1♩, 4F:0.5♩], offset=1/4)

# %%
cropped2 = cropped.copy()
cropped2.timeShiftInPlace(-F(1, 4))
cropped2
# Out:
# Chain([4D:1♩:offset=0, 4E:1♩:offset=1, 4F:0.5♩:offset=2], offset=1/4)

# %%
cropped2.quantizedScore().dump()
# Out:
# Part #0:
#   Measure #0
#     Timesig: 4/4(quarter=60)
#     Node ratio: 1/1, offset=0, end=4, dur=4, symbolicdur=4
#       «rest 0:0.25 1/4♩»
#       «4D~ 0.25:1 3/4♩ properties={'.forwardTies': {0}}»
#       «~4D 1:1.25 1/4♩ properties={'.backwardTies': {0}}»
#       «4E~ 1.25:2 3/4♩ properties={'.forwardTies': {0}}»
#       «~4E 2:2.25 1/4♩ properties={'.backwardTies': {0}}»
#       «4F 2.25:2.75 1/2♩»
#       «rest 2.75:3 1/4♩»
#       «rest 3:4 1♩»

# %%
cropped.timeShift(F(1, 4))
# Out:
# Chain([4D:1♩, 4E:1♩, 4F:0.5♩], offset=3/4)

# %%
cropped2 = cropped.copy()
cropped2.timeShiftInPlace(F(1, 4))
cropped2
# Out:
# Chain([4D:1♩, 4E:1♩, 4F:0.5♩], offset=3/4)

# %%
cropped2 = cropped.copy()
cropped2.dump()
cropped2.absorbInitialOffset()
cropped2.dump()
cropped2
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0.5, offset: 0.5, dur: 2.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0.5     0.5    (0)         1           4D        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.5     1.5    (1)         1           4E        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:2.5     2.5    (2)         0.5         4F        F          None                -</span></code>
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0.5, offset: 0.5, dur: 2.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0.5     0.5    (0)         1           4D        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.5     1.5    (1)         1           4E        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:2.5     2.5    (2)         0.5         4F        F          None                -</span></code>
# Chain([4D:1♩, 4E:1♩, 4F:0.5♩], offset=1/2)

# %%
ch2 = Chain([
    "4C:0.5",
    "4D:1",
    Chain([
        "4E:1:offset=1",
        "4F:2"
    ], offset=3)
])
ch2
# Out:
# Chain([4C:0.5♩, 4D:1♩, Chain([4E:1♩:offset=1, 4F:2♩], offset=3)])

# %%
ch3 = ch2.cropped(0.75, (1, 0.5))
ch3.dump()
ch3.show()
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0.75, offset: 0.75, dur: 3.75</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0.75    0.75   (0)         0.75        4D        F          None                -</span></code><br><code><span style="font-size: 85%">  <b>Chain</b> - beat: 4, offset: 3.25, dur: 0.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">    location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">    1:0       4      (0)         0.5         4E        F          None                -</span></code>

# %%
ch3.asVoice()
# Out:
# Voice([4D:0.75♩:offset=0.75, Chain([4E:0.5♩], offset=4)])

# %%
ch3.show()
ch3.dump()
print(ch3[0].absOffset())
ch4 = ch3.timeShift(-ch3[0].absOffset())
ch4.removeRedundantOffsets()
ch4.dump()
ch4
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0.75, offset: 0.75, dur: 3.75</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0.75    0.75   (0)         0.75        4D        F          None                -</span></code><br><code><span style="font-size: 85%">  <b>Chain</b> - beat: 4, offset: 3.25, dur: 0.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">    location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">    1:0       4      (0)         0.5         4E        F          None                -</span></code>
# 3/4
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0, offset: None, dur: 3.75</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0       0      (0)         0.75        4D        F          None                -</span></code><br><code><span style="font-size: 85%">  <b>Chain</b> - beat: 4, offset: 3.25, dur: 0.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">    location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">    0:3.25    3.25   (0)         0.5         4E        F          None                -</span></code>
# Chain([4D:0.75♩, Chain([4E:0.5♩], offset=13/4)])

# %%
from maelzel.core import *
v = Chain([
    "4C:0.5",
    "4D:1",
    "4E:1",
    Chain("""
    4F:1
    4G:1
    """)# .addSpanner('slur')
])
v
# Out:
# Chain([4C:0.5♩, 4D:1♩, 4E:1♩, Chain([4F:1♩, 4G:1♩])])

# %%
v[-1].cropped(F(5, 2), F(3))
# Out:
# Chain([4F:0.5♩], offset=5/2)

# %%
v.cropped(1, 3)
# Out:
# Chain([4D:0.5♩, 4E:1♩, Chain([4F:0.5♩])], offset=1)

# %%
v = Chain([
    "4F:1",
    "4G:1"
], offset=F(5, 2))
v
# Out:
# Chain([4F:1♩, 4G:1♩], offset=5/2)

# %%
v.cropped(F(5, 2), F(3))
# Out:
# Chain([4F:0.5♩], offset=5/2)

# %%
v.cropped(0.25, 3.)
# Out:
# Chain([4F:0.5♩:offset=2.25], offset=1/4)

# %%
from maelzel.core import *
v = Voice([
    "4C:0.5",
    "4D:1",
    "4E:1",
    Chain("""
    4F:1
    4G:1
    """).addSpanner('slur')
        
    
])
v
# Out:
# Voice([4C:0.5♩, 4D:1♩, 4E:1♩, Chain([4F:1♩:symbols=[Slur(anchor=Slur, kind=start, linetype=solid, partnerSpanner=Slur, uuid=ftw6nrf2)], 4G:1♩:symbols=[Slur(anchor=Slur, kind=end, linetype=solid, partnerSpanner=Slur, uuid=ftw6nrf2)]])])

# %%
v2 = v.cropped(0.25, 3.)
v2
# Out:
# Chain([4C:0.25♩, 4D:1♩, 4E:1♩, Chain([4F:0.5♩:symbols=[Slur(anchor=Slur, kind=start, linetype=solid, partnerSpanner=Slur, uuid=ftw6nrf2)]])], offset=1/4)

# %%
ch = Chain([
    Note("4D~", 1, amp=0.1),
    Note("4D", 2, amp=1).setPlay(fade=(0, 1))
])
print(ch.synthEvents())
ch.play()
# Out:
# [SynthEvent(delay=0, dur=3, instr=.piano, gain=1, chan=1, fade=(0.02, 1), position=0.5, bps=‹0.0s 62 0.1; 1.0s 62 1; 3.0s 62 1›)]
# --Csound version 6.19 (double samples) May  8 2024
# [commit: 937aa495e250d758efaa28e9697a8b75237c80cd]
# libsndfile-1.2.0
# sr = 48000.0, kr = 750.000, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# reading 2048-byte blks of shorts from adc:Built-in Audio Analog Stereo: (RAW)
# writing 512 sample blks of 64-bit floats to dac:Built-in Audio Analog Stereo:
# SECTION 1:
# Button(description='Stop', style=ButtonStyle())
# Output()
# SynthGroup(n=1)
#     Synth(𝍪 preset:.piano=501.0002 start=0.785 dur=3.000 p4=0.5 kpos=1 kgain=18 idataidx_=3 inumbps=3 ibplen=1 ichan=0.02 ifadein=1 ifadeout=0 ipchintrp_=1 ifadekind=0 ktransp=0.1 ipitchlag=-1 ivel=0 p18=62 p19=0.1 …)

# %%
ch = Chain([
    "4C:1:offset=0.5",
    "4E:1",
    "4G:1"
])
ch.dump()
ch.absorbInitialOffset()
ch.dump()
# Out:
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0, offset: None, dur: 3.5</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0.5     0.5    0.5         1           4C        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.5     1.5    (1.5)       1           4E        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:2.5     2.5    (2.5)       1           4G        F          None                -</span></code>
# <code><span style="font-size: 85%"><b>Chain</b> - beat: 0.5, offset: 0.5, dur: 3</span></code><br><code><span style="color:#BBBBBB;font-size:85%">  location  beat   offset      dur         name      gliss dyn  playargs            info                </span></code><br><code><span style="color:#9090FF;font-size:85%">  0:0.5     0.5    (0)         1           4C        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:1.5     1.5    (1)         1           4E        F          None                -</span></code><br><code><span style="color:#9090FF;font-size:85%">  0:2.5     2.5    (2)         1           4G        F          None                -</span></code>
